# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Get the dataset

# %%
# !cp /content/gdrive/MyDrive/AI_PROJECTS/STRAWBERRY_MASKRCNN/DATASET/StrawDI_Db1.zip .

# %%
# !unzip /content/StrawDI_Db1.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: StrawDI_Db1/train/img/180.png
#   inflating: StrawDI_Db1/train/img/1800.png
#   inflating: StrawDI_Db1/train/img/1801.png
#   inflating: StrawDI_Db1/train/img/1802.png
#   inflating: StrawDI_Db1/train/img/1804.png
#   inflating: StrawDI_Db1/train/img/1805.png
#   inflating: StrawDI_Db1/train/img/1806.png
#   inflating: StrawDI_Db1/train/img/1807.png
#   inflating: StrawDI_Db1/train/img/1808.png
#   inflating: StrawDI_Db1/train/img/1809.png
#   inflating: StrawDI_Db1/train/img/181.png
#   inflating: StrawDI_Db1/train/img/1810.png
#   inflating: StrawDI_Db1/train/img/1811.png
#   inflating: StrawDI_Db1/train/img/1812.png
#   inflating: StrawDI_Db1/train/img/1814.png
#   inflating: StrawDI_Db1/train/img/1815.png
#   inflating: StrawDI_Db1/train/img/1816.png
#   inflating: StrawDI_Db1/train/img/1817.png
#   inflating: StrawDI_Db1/train/img/1818.png
#   inflating: StrawDI_Db1/train/img/1819.png
#   inflating: StrawDI_Db1/train/img/182.png
#   inflating: StrawDI_Db1/train/img/1820.png
#   inflating: StrawDI_Db1/train/img/1821.png
#   inflating: StrawDI_Db1/train/img/1822.png
#   inflating: StrawDI_Db1/train/img/1823.png
#   inflating: StrawDI_Db1/train/img/1824.png
#   inflating: StrawDI_Db1/train/img/1825.png
#   inflating: StrawDI_Db1/train/img/1826.png
#   inflating: StrawDI_Db1/train/img/1827.png
#   inflating: StrawDI_Db1/train/img/1828.png
#   inflating: StrawDI_Db1/train/img/1829.png
#   inflating: StrawDI_Db1/train/img/183.png
#   inflating: StrawDI_Db1/train/img/1830.png
#   inflating: StrawDI_Db1/train/img/1831.png
#   inflating: StrawDI_Db1/train/img/1832.png
#   inflating: StrawDI_Db1/train/img/1833.png
#   inflating: StrawDI_Db1/train/img/1834.png
#   inflating: StrawDI_Db1/train/img/1835.png
#   inflating: StrawDI_Db1/train/img/1836.png
#   inflating: StrawDI_Db1/train/img/1837.png
#   inflating: StrawDI_Db1/train/img/1839.png
#   inflating: StrawDI_Db1/train/img/184.png
#   inflating: StrawDI_Db1/train/img/1840.png
#   inflating: StrawDI_Db1/train/img/1841.png
#   inflating: StrawDI_Db1/train/img/1842.png
#   inflating: StrawDI_Db1/train/img/1843.png
#   inflating: StrawDI_Db1/train/img/1844.png
#   inflating: StrawDI_Db1/train/img/1845.png
#   inflating: StrawDI_Db1/train/img/1846.png
#   inflating: StrawDI_Db1/train/img/1847.png
#   inflating: StrawDI_Db1/train/img/1848.png
#   inflating: StrawDI_Db1/train/img/1849.png
#   inflating: StrawDI_Db1/train/img/185.png
#   inflating: StrawDI_Db1/train/img/1850.png
#   inflating: StrawDI_Db1/train/img/1851.png
#   inflating: StrawDI_Db1/train/img/1853.png
#   inflating: StrawDI_Db1/train/img/1854.png
#   inflating: StrawDI_Db1/train/img/1855.png
#   inflating: StrawDI_Db1/train/img/1856.png
#   inflating: StrawDI_Db1/train/img/1857.png
#   inflating: StrawDI_Db1/train/img/1858.png
#   inflating: StrawDI_Db1/train/img/1859.png
#   inflating: StrawDI_Db1/train/img/186.png
#   inflating: StrawDI_Db1/train/img/1860.png
#   inflating: StrawDI_Db1/train/img/1861.png
#   inflating: StrawDI_Db1/train/img/1862.png
#   inflating: StrawDI_Db1/train/img/1864.png
#   inflating: StrawDI_Db1/train/img/1865.png
#   inflating: StrawDI_Db1/train/img/1866.png
#   inflating: StrawDI_Db1/train/img/1867.png
#   inflating: StrawDI_Db1/train/img/1868.png
#   inflating: StrawDI_Db1/train/img/1869.png
#   inflating: StrawDI_Db1/train/img/187.png
#   inflating: StrawDI_Db1/train/img/1870.png
#   inflating: StrawDI_Db1/train/img/1871.png
#   inflating: StrawDI_Db1/train/img/1872.png
#   inflating: StrawDI_Db1/train/img/1874.png
#   inflating: StrawDI_Db1/train/img/1875.png
#   inflating: StrawDI_Db1/train/img/1876.png
#   inflating: StrawDI_Db1/train/img/1877.png
#   inflating: StrawDI_Db1/train/img/1878.png
#   inflating: StrawDI_Db1/train/img/1879.png
#   inflating: StrawDI_Db1/train/img/188.png
#   inflating: StrawDI_Db1/train/img/1880.png
#   inflating: StrawDI_Db1/train/img/1881.png
#   inflating: StrawDI_Db1/train/img/1882.png
#   inflating: StrawDI_Db1/train/img/1883.png
#   inflating: StrawDI_Db1/train/img/1885.png
#   inflating: StrawDI_Db1/train/img/1886.png
#   inflating: StrawDI_Db1/train/img/1887.png
#   inflating: StrawDI_Db1/train/img/1888.png
#   inflating: StrawDI_Db1/train/img/1889.png
#   inflating: StrawDI_Db1/train/img/189.png
#   inflating: StrawDI_Db1/train/img/1890.png
#   inflating: StrawDI_Db1/train/img/1891.png
#   inflating: StrawDI_Db1/train/img/1892.png
#   inflating: StrawDI_Db1/train/img/1893.png
#   inflating: StrawDI_Db1/train/img/1894.png
#   inflating: StrawDI_Db1/train/img/1895.png
#   inflating: StrawDI_Db1/train/img/1896.png
#   inflating: StrawDI_Db1/train/img/1897.png
#   inflating: StrawDI_Db1/train/img/1898.png
#   inflating: StrawDI_Db1/train/img/19.png
#   inflating: StrawDI_Db1/train/img/190.png
#   inflating: StrawDI_Db1/train/img/1900.png
#   inflating: StrawDI_Db1/train/img/1901.png
#   inflating: StrawDI_Db1/train/img/1902.png
#   inflating: StrawDI_Db1/train/img/1903.png
#   inflating: StrawDI_Db1/train/img/1904.png
#   inflating: StrawDI_Db1/train/img/1905.png
#   inflating: StrawDI_Db1/train/img/1906.png
#   inflating: StrawDI_Db1/train/img/1908.png
#   inflating: StrawDI_Db1/train/img/1909.png
#   inflating: StrawDI_Db1/train/img/191.png
#   inflating: StrawDI_Db1/train/img/1910.png
#   inflating: StrawDI_Db1/train/img/1911.png
#   inflating: StrawDI_Db1/train/img/1912.png
#   inflating: StrawDI_Db1/train/img/1913.png
#   inflating: StrawDI_Db1/train/img/1914.png
#   inflating: StrawDI_Db1/train/img/1915.png
#   inflating: StrawDI_Db1/train/img/1916.png
#   inflating: StrawDI_Db1/train/img/1917.png
#   inflating: StrawDI_Db1/train/img/1918.png
#   inflating: StrawDI_Db1/train/img/1919.png
#   inflating: StrawDI_Db1/train/img/1920.png
#   inflating: StrawDI_Db1/train/img/1921.png
#   inflating: StrawDI_Db1/train/img/1923.png
#   inflating: StrawDI_Db1/train/img/1924.png
#   inflating: StrawDI_Db1/train/img/1925.png
#   inflating: StrawDI_Db1/train/img/1926.png
#   inflating: StrawDI_Db1/train/img/1927.png
#   inflating: StrawDI_Db1/train/img/1929.png
#   inflating: StrawDI_Db1/train/img/193.png
#   inflating: StrawDI_Db1/train/img/1930.png
#   inflating: StrawDI_Db1/train/img/1931.png
#   inflating: StrawDI_Db1/train/img/1932.png
#   inflating: StrawDI_Db1/train/img/1933.png
#   inflating: StrawDI_Db1/train/img/1934.png
#   inflating: StrawDI_Db1/train/img/1935.png
#   inflating: StrawDI_Db1/train/img/1936.png
#   inflating: StrawDI_Db1/train/img/1937.png
#   inflating: StrawDI_Db1/train/img/1938.png
#   inflating: StrawDI_Db1/train/img/1939.png
#   inflating: StrawDI_Db1/train/img/194.png
#   inflating: StrawDI_Db1/train/img/1940.png
#   inflating: StrawDI_Db1/train/img/1942.png
#   inflating: StrawDI_Db1/train/img/1944.png
#   inflating: StrawDI_Db1/train/img/1945.png
#   inflating: StrawDI_Db1/train/img/1947.png
#   inflating: StrawDI_Db1/train/img/1949.png
#   inflating: StrawDI_Db1/train/img/195.png
#   inflating: StrawDI_Db1/train/img/1950.png
#   inflating: StrawDI_Db1/train/img/1951.png
#   inflating: StrawDI_Db1/train/img/1952.png
#   inflating: StrawDI_Db1/train/img/1953.png
#  extracting: StrawDI_Db1/train/img/1954.png
#   inflating: StrawDI_Db1/train/img/1955.png
#   inflating: StrawDI_Db1/train/img/1956.png
#   inflating: StrawDI_Db1/train/img/1958.png
#   inflating: StrawDI_Db1/train/img/1959.png
#   inflating: StrawDI_Db1/train/img/196.png
#   inflating: StrawDI_Db1/train/img/1960.png
#   inflating: StrawDI_Db1/train/img/1961.png
#   inflating: StrawDI_Db1/train/img/1962.png
#   inflating: StrawDI_Db1/train/img/1963.png
#   inflating: StrawDI_Db1/train/img/1964.png
#   inflating: StrawDI_Db1/train/img/1965.png
#   inflating: StrawDI_Db1/train/img/1966.png
#   inflating: StrawDI_Db1/train/img/1967.png
#   inflating: StrawDI_Db1/train/img/1968.png
#   inflating: StrawDI_Db1/train/img/1969.png
#   inflating: StrawDI_Db1/train/img/197.png
#   inflating: StrawDI_Db1/train/img/1970.png
#   inflating: StrawDI_Db1/train/img/1971.png
#   inflating: StrawDI_Db1/train/img/1972.png
#   inflating: StrawDI_Db1/train/img/1973.png
#   inflating: StrawDI_Db1/train/img/1974.png
#   inflating: StrawDI_Db1/train/img/1975.png
#   inflating: StrawDI_Db1/train/img/1976.png
#   inflating: StrawDI_Db1/train/img/1977.png
#   inflating: StrawDI_Db1/train/img/1978.png
#   inflating: StrawDI_Db1/train/img/198.png
#   inflating: StrawDI_Db1/train/img/1980.png
#   inflating: StrawDI_Db1/train/img/1981.png
#   inflating: StrawDI_Db1/train/img/1982.png
#   inflating: StrawDI_Db1/train/img/1983.png
#   inflating: StrawDI_Db1/train/img/1984.png
#   inflating: StrawDI_Db1/train/img/1985.png
#   inflating: StrawDI_Db1/train/img/1986.png
#   inflating: StrawDI_Db1/train/img/1987.png
#   inflating: StrawDI_Db1/train/img/1988.png
#   inflating: StrawDI_Db1/train/img/1989.png
#   inflating: StrawDI_Db1/train/img/199.png
#   inflating: StrawDI_Db1/train/img/1990.png
#   inflating: StrawDI_Db1/train/img/1991.png
#   inflating: StrawDI_Db1/train/img/1993.png
#   inflating: StrawDI_Db1/train/img/1994.png
#   inflating: StrawDI_Db1/train/img/1995.png
#   inflating: StrawDI_Db1/train/img/1997.png
#   inflating: StrawDI_Db1/train/img/1998.png
#   inflating: StrawDI_Db1/train/img/1999.png
#   inflating: StrawDI_Db1/train/img/2.png
#   inflating: StrawDI_Db1/train/img/20.png
#   inflating: StrawDI_Db1/train/img/200.png
#   inflating: StrawDI_Db1/train/img/2000.png
#   inflating: StrawDI_Db1/train/img/2001.png
#   inflating: StrawDI_Db1/train/img/2002.png
#   inflating: StrawDI_Db1/train/img/2003.png
#   inflating: StrawDI_Db1/train/img/2004.png
#   inflating: StrawDI_Db1/train/img/2005.png
#   inflating: StrawDI_Db1/train/img/2006.png
#   inflating: StrawDI_Db1/train/img/2007.png
#   inflating: StrawDI_Db1/train/img/2008.png
#   inflating: StrawDI_Db1/train/img/2009.png
#   inflating: StrawDI_Db1/train/img/201.png
#   inflating: StrawDI_Db1/train/img/2010.png
#   inflating: StrawDI_Db1/train/img/2011.png
#   inflating: StrawDI_Db1/train/img/2012.png
#   inflating: StrawDI_Db1/train/img/2014.png
#   inflating: StrawDI_Db1/train/img/2015.png
#   inflating: StrawDI_Db1/train/img/2016.png
#   inflating: StrawDI_Db1/train/img/2017.png
#   inflating: StrawDI_Db1/train/img/2018.png
#   inflating: StrawDI_Db1/train/img/2019.png
#   inflating: StrawDI_Db1/train/img/202.png
#   inflating: StrawDI_Db1/train/img/2020.png
#   inflating: StrawDI_Db1/train/img/2021.png
#   inflating: StrawDI_Db1/train/img/2022.png
#   inflating: StrawDI_Db1/train/img/2023.png
#   inflating: StrawDI_Db1/train/img/2025.png
#   inflating: StrawDI_Db1/train/img/2026.png
#   inflating: StrawDI_Db1/train/img/2027.png
#   inflating: StrawDI_Db1/train/img/2028.png
#   inflating: StrawDI_Db1/train/img/2029.png
#   inflating: StrawDI_Db1/train/img/203.png
#   inflating: StrawDI_Db1/train/img/2030.png
#   inflating: StrawDI_Db1/train/img/2031.png
#   inflating: StrawDI_Db1/train/img/2032.png
#   inflating: StrawDI_Db1/train/img/2033.png
#   inflating: StrawDI_Db1/train/img/2034.png
#   inflating: StrawDI_Db1/train/img/2035.png
#   inflating: StrawDI_Db1/train/img/2036.png
#   inflating: StrawDI_Db1/train/img/2037.png
#   inflating: StrawDI_Db1/train/img/2038.png
#   inflating: StrawDI_Db1/train/img/2039.png
#   inflating: StrawDI_Db1/train/img/204.png
#   inflating: StrawDI_Db1/train/img/2040.png
#   inflating: StrawDI_Db1/train/img/2041.png
#   inflating: StrawDI_Db1/train/img/2042.png
#   inflating: StrawDI_Db1/train/img/2043.png
#   inflating: StrawDI_Db1/train/img/2044.png
#   inflating: StrawDI_Db1/train/img/2045.png
#   inflating: StrawDI_Db1/train/img/2046.png
#   inflating: StrawDI_Db1/train/img/2047.png
#   inflating: StrawDI_Db1/train/img/2048.png
#   inflating: StrawDI_Db1/train/img/2049.png
#   inflating: StrawDI_Db1/train/img/205.png
#   inflating: StrawDI_Db1/train/img/2050.png
#   inflating: StrawDI_Db1/train/img/2051.png
#   inflating: StrawDI_Db1/train/img/2052.png
#   inflating: StrawDI_Db1/train/img/2053.png
#   inflating: StrawDI_Db1/train/img/2054.png
#   inflating: StrawDI_Db1/train/img/2055.png
#   inflating: StrawDI_Db1/train/img/2056.png
#   inflating: StrawDI_Db1/train/img/2057.png
#   inflating: StrawDI_Db1/train/img/2058.png
#   inflating: StrawDI_Db1/train/img/206.png
#   inflating: StrawDI_Db1/train/img/2060.png
#   inflating: StrawDI_Db1/train/img/2061.png
#   inflating: StrawDI_Db1/train/img/2062.png
#   inflating: StrawDI_Db1/train/img/2063.png
#   inflating: StrawDI_Db1/train/img/2064.png
#   inflating: StrawDI_Db1/train/img/2065.png
#   inflating: StrawDI_Db1/train/img/2066.png
#   inflating: StrawDI_Db1/train/img/2068.png
#   inflating: StrawDI_Db1/train/img/2069.png
#   inflating: StrawDI_Db1/train/img/207.png
#   inflating: StrawDI_Db1/train/img/2070.png
#   inflating: StrawDI_Db1/train/img/2071.png
#   inflating: StrawDI_Db1/train/img/2072.png
#   inflating: StrawDI_Db1/train/img/2073.png
#   inflating: StrawDI_Db1/train/img/2074.png
#   inflating: StrawDI_Db1/train/img/2075.png
#   inflating: StrawDI_Db1/train/img/2076.png
#   inflating: StrawDI_Db1/train/img/2077.png
#   inflating: StrawDI_Db1/train/img/2078.png
#   inflating: StrawDI_Db1/train/img/2079.png
#  extracting: StrawDI_Db1/train/img/208.png
#   inflating: StrawDI_Db1/train/img/2080.png
#   inflating: StrawDI_Db1/train/img/2081.png
#   inflating: StrawDI_Db1/train/img/2082.png
#   inflating: StrawDI_Db1/train/img/2083.png
#   inflating: StrawDI_Db1/train/img/2084.png
#   inflating: StrawDI_Db1/train/img/2086.png
#   inflating: StrawDI_Db1/train/img/2087.png
#   inflating: StrawDI_Db1/train/img/2088.png
#   inflating: StrawDI_Db1/train/img/2089.png
#   inflating: StrawDI_Db1/train/img/209.png
#   inflating: StrawDI_Db1/train/img/2090.png
#   inflating: StrawDI_Db1/train/img/2091.png
#   inflating: StrawDI_Db1/train/img/2092.png
#   inflating: StrawDI_Db1/train/img/2095.png
#   inflating: StrawDI_Db1/train/img/2096.png
#   inflating: StrawDI_Db1/train/img/2097.png
#   inflating: StrawDI_Db1/train/img/2098.png
#   inflating: StrawDI_Db1/train/img/2099.png
#   inflating: StrawDI_Db1/train/img/21.png
#   inflating: StrawDI_Db1/train/img/210.png
#   inflating: StrawDI_Db1/train/img/2100.png
#   inflating: StrawDI_Db1/train/img/2101.png
#   inflating: StrawDI_Db1/train/img/2102.png
#   inflating: StrawDI_Db1/train/img/2103.png
#   inflating: StrawDI_Db1/train/img/2104.png
#   inflating: StrawDI_Db1/train/img/2106.png
#   inflating: StrawDI_Db1/train/img/2107.png
#   inflating: StrawDI_Db1/train/img/2109.png
#   inflating: StrawDI_Db1/train/img/211.png
#   inflating: StrawDI_Db1/train/img/2110.png
#   inflating: StrawDI_Db1/train/img/2111.png
#   inflating: StrawDI_Db1/train/img/2112.png
#   inflating: StrawDI_Db1/train/img/2113.png
#   inflating: StrawDI_Db1/train/img/2115.png
#   inflating: StrawDI_Db1/train/img/2117.png
#   inflating: StrawDI_Db1/train/img/2118.png
#   inflating: StrawDI_Db1/train/img/2119.png
#   inflating: StrawDI_Db1/train/img/212.png
#   inflating: StrawDI_Db1/train/img/2120.png
#   inflating: StrawDI_Db1/train/img/2122.png
#   inflating: StrawDI_Db1/train/img/2123.png
#   inflating: StrawDI_Db1/train/img/2124.png
#   inflating: StrawDI_Db1/train/img/2125.png
#   inflating: StrawDI_Db1/train/img/2126.png
#   inflating: StrawDI_Db1/train/img/2127.png
#   inflating: StrawDI_Db1/train/img/2128.png
#   inflating: StrawDI_Db1/train/img/2129.png
#   inflating: StrawDI_Db1/train/img/213.png
#   inflating: StrawDI_Db1/train/img/2130.png
#   inflating: StrawDI_Db1/train/img/2131.png
#   inflating: StrawDI_Db1/train/img/2132.png
#   inflating: StrawDI_Db1/train/img/2133.png
#   inflating: StrawDI_Db1/train/img/2134.png
#   inflating: StrawDI_Db1/train/img/2135.png
#   inflating: StrawDI_Db1/train/img/2136.png
#   inflating: StrawDI_Db1/train/img/2137.png
#   inflating: StrawDI_Db1/train/img/2138.png
#   inflating: StrawDI_Db1/train/img/2139.png
#   inflating: StrawDI_Db1/train/img/214.png
#   inflating: StrawDI_Db1/train/img/2140.png
#   inflating: StrawDI_Db1/train/img/2141.png
#   inflating: StrawDI_Db1/train/img/2143.png
#   inflating: StrawDI_Db1/train/img/2144.png
#   inflating: StrawDI_Db1/train/img/2145.png
#   inflating: StrawDI_Db1/train/img/2146.png
#   inflating: StrawDI_Db1/train/img/2147.png
#   inflating: StrawDI_Db1/train/img/2148.png
#   inflating: StrawDI_Db1/train/img/2149.png
#   inflating: StrawDI_Db1/train/img/215.png
#   inflating: StrawDI_Db1/train/img/2150.png
#   inflating: StrawDI_Db1/train/img/2151.png
#   inflating: StrawDI_Db1/train/img/2152.png
#   inflating: StrawDI_Db1/train/img/2153.png
#   inflating: StrawDI_Db1/train/img/2154.png
#   inflating: StrawDI_Db1/train/img/2156.png
#   inflating: StrawDI_Db1/train/img/2157.png
#   inflating: StrawDI_Db1/train/img/2158.png
#   inflating: StrawDI_Db1/train/img/2159.png
#   inflating: StrawDI_Db1/train/img/216.png
#   inflating: StrawDI_Db1/train/img/2160.png
#   inflating: StrawDI_Db1/train/img/2161.png
#   inflating: StrawDI_Db1/train/img/2162.png
#   inflating: StrawDI_Db1/train/img/2163.png
#   inflating: StrawDI_Db1/train/img/2164.png
#   inflating: StrawDI_Db1/train/img/2165.png
#   inflating: StrawDI_Db1/train/img/2166.png
#   inflating: StrawDI_Db1/train/img/2167.png
#   inflating: StrawDI_Db1/train/img/2168.png
#   inflating: StrawDI_Db1/train/img/217.png
#   inflating: StrawDI_Db1/train/img/2170.png
#   inflating: StrawDI_Db1/train/img/2171.png
#   inflating: StrawDI_Db1/train/img/2172.png
#   inflating: StrawDI_Db1/train/img/2173.png
#   inflating: StrawDI_Db1/train/img/2174.png
#   inflating: StrawDI_Db1/train/img/2175.png
#   inflating: StrawDI_Db1/train/img/2176.png
#   inflating: StrawDI_Db1/train/img/2177.png
#   inflating: StrawDI_Db1/train/img/2178.png
#   inflating: StrawDI_Db1/train/img/2179.png
#   inflating: StrawDI_Db1/train/img/218.png
#   inflating: StrawDI_Db1/train/img/2180.png
#   inflating: StrawDI_Db1/train/img/2181.png
#   inflating: StrawDI_Db1/train/img/2182.png
#   inflating: StrawDI_Db1/train/img/2183.png
#   inflating: StrawDI_Db1/train/img/2184.png
#   inflating: StrawDI_Db1/train/img/2185.png
#   inflating: StrawDI_Db1/train/img/2186.png
#   inflating: StrawDI_Db1/train/img/2187.png
#   inflating: StrawDI_Db1/train/img/2188.png
#   inflating: StrawDI_Db1/train/img/2189.png
#   inflating: StrawDI_Db1/train/img/219.png
#   inflating: StrawDI_Db1/train/img/2190.png
#   inflating: StrawDI_Db1/train/img/2191.png
#   inflating: StrawDI_Db1/train/img/2192.png
#   inflating: StrawDI_Db1/train/img/2193.png
#   inflating: StrawDI_Db1/train/img/2194.png
#   inflating: StrawDI_Db1/train/img/2195.png
#   inflating: StrawDI_Db1/train/img/2196.png
#   inflating: StrawDI_Db1/train/img/2197.png
#   inflating: StrawDI_Db1/train/img/2198.png
#   inflating: StrawDI_Db1/train/img/2199.png
#   inflating: StrawDI_Db1/train/img/22.png
#   inflating: StrawDI_Db1/train/img/220.png
#   inflating: StrawDI_Db1/train/img/2200.png
#   inflating: StrawDI_Db1/train/img/2201.png
#   inflating: StrawDI_Db1/train/img/2202.png
#   inflating: StrawDI_Db1/train/img/2203.png
#   inflating: StrawDI_Db1/train/img/2204.png
#   inflating: StrawDI_Db1/train/img/2205.png
#   inflating: StrawDI_Db1/train/img/2206.png
#   inflating: StrawDI_Db1/train/img/2207.png
#   inflating: StrawDI_Db1/train/img/2208.png
#   inflating: StrawDI_Db1/train/img/2209.png
#   inflating: StrawDI_Db1/train/img/221.png
#   inflating: StrawDI_Db1/train/img/2211.png
#   inflating: StrawDI_Db1/train/img/2212.png
#   inflating: StrawDI_Db1/train/img/2213.png
#   inflating: StrawDI_Db1/train/img/2214.png
#   inflating: StrawDI_Db1/train/img/2215.png
#   inflating: StrawDI_Db1/train/img/2216.png
#   inflating: StrawDI_Db1/train/img/2217.png
#   inflating: StrawDI_Db1/train/img/2218.png
#   inflating: StrawDI_Db1/train/img/2219.png
#   inflating: StrawDI_Db1/train/img/222.png
#   inflating: StrawDI_Db1/train/img/2220.png
#   inflating: StrawDI_Db1/train/img/2221.png
#   inflating: StrawDI_Db1/train/img/2222.png
#   inflating: StrawDI_Db1/train/img/2223.png
#   inflating: StrawDI_Db1/train/img/2224.png
#   inflating: StrawDI_Db1/train/img/2225.png
#   inflating: StrawDI_Db1/train/img/2226.png
#   inflating: StrawDI_Db1/train/img/2227.png
#   inflating: StrawDI_Db1/train/img/2228.png
#   inflating: StrawDI_Db1/train/img/2229.png
#   inflating: StrawDI_Db1/train/img/2231.png
#  extracting: StrawDI_Db1/train/img/2232.png
#   inflating: StrawDI_Db1/train/img/2233.png
#   inflating: StrawDI_Db1/train/img/2235.png
#   inflating: StrawDI_Db1/train/img/2237.png
#   inflating: StrawDI_Db1/train/img/2238.png
#   inflating: StrawDI_Db1/train/img/2239.png
#   inflating: StrawDI_Db1/train/img/224.png
#   inflating: StrawDI_Db1/train/img/2240.png
#   inflating: StrawDI_Db1/train/img/2241.png
#   inflating: StrawDI_Db1/train/img/2242.png
#   inflating: StrawDI_Db1/train/img/2243.png
#   inflating: StrawDI_Db1/train/img/2244.png
#   inflating: StrawDI_Db1/train/img/2245.png
#   inflating: StrawDI_Db1/train/img/2246.png
#   inflating: StrawDI_Db1/train/img/2248.png
#   inflating: StrawDI_Db1/train/img/225.png
#   inflating: StrawDI_Db1/train/img/2250.png
#   inflating: StrawDI_Db1/train/img/2251.png
#   inflating: StrawDI_Db1/train/img/2252.png
#   inflating: StrawDI_Db1/train/img/2253.png
#   inflating: StrawDI_Db1/train/img/2254.png
#   inflating: StrawDI_Db1/train/img/2255.png
#   inflating: StrawDI_Db1/train/img/2256.png
#   inflating: StrawDI_Db1/train/img/2257.png
#   inflating: StrawDI_Db1/train/img/2258.png
#   inflating: StrawDI_Db1/train/img/2259.png
#   inflating: StrawDI_Db1/train/img/226.png
#   inflating: StrawDI_Db1/train/img/2260.png
#   inflating: StrawDI_Db1/train/img/2261.png
#   inflating: StrawDI_Db1/train/img/2262.png
#   inflating: StrawDI_Db1/train/img/2263.png
#   inflating: StrawDI_Db1/train/img/2264.png
#   inflating: StrawDI_Db1/train/img/2265.png
#   inflating: StrawDI_Db1/train/img/2266.png
#   inflating: StrawDI_Db1/train/img/2267.png
#   inflating: StrawDI_Db1/train/img/2268.png
#   inflating: StrawDI_Db1/train/img/2269.png
#   inflating: StrawDI_Db1/train/img/227.png
#   inflating: StrawDI_Db1/train/img/2270.png
#   inflating: StrawDI_Db1/train/img/2271.png
#   inflating: StrawDI_Db1/train/img/2272.png
#   inflating: StrawDI_Db1/train/img/2273.png
#   inflating: StrawDI_Db1/train/img/2274.png
#   inflating: StrawDI_Db1/train/img/2275.png
#   inflating: StrawDI_Db1/train/img/2276.png
#   inflating: StrawDI_Db1/train/img/2277.png
#   inflating: StrawDI_Db1/train/img/2278.png
#   inflating: StrawDI_Db1/train/img/2279.png
#   inflating: StrawDI_Db1/train/img/228.png
#   inflating: StrawDI_Db1/train/img/2280.png
#   inflating: StrawDI_Db1/train/img/2281.png
#   inflating: StrawDI_Db1/train/img/2282.png
#   inflating: StrawDI_Db1/train/img/2283.png
#   inflating: StrawDI_Db1/train/img/2284.png
#   inflating: StrawDI_Db1/train/img/2285.png
#   inflating: StrawDI_Db1/train/img/2286.png
#   inflating: StrawDI_Db1/train/img/2287.png
#   inflating: StrawDI_Db1/train/img/2288.png
#   inflating: StrawDI_Db1/train/img/2289.png
#   inflating: StrawDI_Db1/train/img/229.png
#   inflating: StrawDI_Db1/train/img/2291.png
#   inflating: StrawDI_Db1/train/img/2292.png
#   inflating: StrawDI_Db1/train/img/2294.png
#   inflating: StrawDI_Db1/train/img/2296.png
#   inflating: StrawDI_Db1/train/img/2297.png
#   inflating: StrawDI_Db1/train/img/2298.png
#   inflating: StrawDI_Db1/train/img/2299.png
#   inflating: StrawDI_Db1/train/img/23.png
#   inflating: StrawDI_Db1/train/img/230.png
#   inflating: StrawDI_Db1/train/img/2300.png
#   inflating: StrawDI_Db1/train/img/2303.png
#   inflating: StrawDI_Db1/train/img/2305.png
#   inflating: StrawDI_Db1/train/img/2306.png
#   inflating: StrawDI_Db1/train/img/2307.png
#   inflating: StrawDI_Db1/train/img/2308.png
#   inflating: StrawDI_Db1/train/img/2309.png
#   inflating: StrawDI_Db1/train/img/2310.png
#   inflating: StrawDI_Db1/train/img/2311.png
#   inflating: StrawDI_Db1/train/img/2312.png
#   inflating: StrawDI_Db1/train/img/2313.png
#   inflating: StrawDI_Db1/train/img/2314.png
#   inflating: StrawDI_Db1/train/img/2316.png
#   inflating: StrawDI_Db1/train/img/2317.png
#   inflating: StrawDI_Db1/train/img/2318.png
#   inflating: StrawDI_Db1/train/img/2319.png
#   inflating: StrawDI_Db1/train/img/232.png
#   inflating: StrawDI_Db1/train/img/2320.png
#   inflating: StrawDI_Db1/train/img/2321.png
#   inflating: StrawDI_Db1/train/img/2322.png
#   inflating: StrawDI_Db1/train/img/2323.png
#   inflating: StrawDI_Db1/train/img/2324.png
#   inflating: StrawDI_Db1/train/img/2326.png
#   inflating: StrawDI_Db1/train/img/2327.png
#   inflating: StrawDI_Db1/train/img/2328.png
#   inflating: StrawDI_Db1/train/img/2329.png
#   inflating: StrawDI_Db1/train/img/233.png
#   inflating: StrawDI_Db1/train/img/2330.png
#   inflating: StrawDI_Db1/train/img/2331.png
#   inflating: StrawDI_Db1/train/img/2332.png
#   inflating: StrawDI_Db1/train/img/2333.png
#   inflating: StrawDI_Db1/train/img/2334.png
#   inflating: StrawDI_Db1/train/img/2335.png
#   inflating: StrawDI_Db1/train/img/2336.png
#   inflating: StrawDI_Db1/train/img/2337.png
#   inflating: StrawDI_Db1/train/img/2338.png
#   inflating: StrawDI_Db1/train/img/2339.png
#   inflating: StrawDI_Db1/train/img/234.png
#   inflating: StrawDI_Db1/train/img/2340.png
#   inflating: StrawDI_Db1/train/img/2341.png
#   inflating: StrawDI_Db1/train/img/2342.png
#   inflating: StrawDI_Db1/train/img/2343.png
#   inflating: StrawDI_Db1/train/img/2344.png
#   inflating: StrawDI_Db1/train/img/2345.png
#   inflating: StrawDI_Db1/train/img/2346.png
#   inflating: StrawDI_Db1/train/img/2347.png
#   inflating: StrawDI_Db1/train/img/2348.png
#   inflating: StrawDI_Db1/train/img/2349.png
#   inflating: StrawDI_Db1/train/img/235.png
#   inflating: StrawDI_Db1/train/img/2350.png
#   inflating: StrawDI_Db1/train/img/2352.png
#   inflating: StrawDI_Db1/train/img/2353.png
#   inflating: StrawDI_Db1/train/img/2354.png
#   inflating: StrawDI_Db1/train/img/2355.png
#   inflating: StrawDI_Db1/train/img/2356.png
#   inflating: StrawDI_Db1/train/img/2357.png
#   inflating: StrawDI_Db1/train/img/2358.png
#   inflating: StrawDI_Db1/train/img/2359.png
#   inflating: StrawDI_Db1/train/img/236.png
#   inflating: StrawDI_Db1/train/img/2361.png
#   inflating: StrawDI_Db1/train/img/2363.png
#   inflating: StrawDI_Db1/train/img/2365.png
#   inflating: StrawDI_Db1/train/img/2366.png
#   inflating: StrawDI_Db1/train/img/2367.png
#   inflating: StrawDI_Db1/train/img/2368.png
#   inflating: StrawDI_Db1/train/img/2369.png
#   inflating: StrawDI_Db1/train/img/237.png
#   inflating: StrawDI_Db1/train/img/2370.png
#   inflating: StrawDI_Db1/train/img/2371.png
#   inflating: StrawDI_Db1/train/img/2372.png
#   inflating: StrawDI_Db1/train/img/2373.png
#   inflating: StrawDI_Db1/train/img/2374.png
#   inflating: StrawDI_Db1/train/img/2375.png
#   inflating: StrawDI_Db1/train/img/2376.png
#   inflating: StrawDI_Db1/train/img/2378.png
#   inflating: StrawDI_Db1/train/img/2379.png
#   inflating: StrawDI_Db1/train/img/2380.png
#   inflating: StrawDI_Db1/train/img/2381.png
#   inflating: StrawDI_Db1/train/img/2382.png
#   inflating: StrawDI_Db1/train/img/2383.png
#   inflating: StrawDI_Db1/train/img/2385.png
#   inflating: StrawDI_Db1/train/img/2386.png
#   inflating: StrawDI_Db1/train/img/2387.png
#   inflating: StrawDI_Db1/train/img/2388.png
#   inflating: StrawDI_Db1/train/img/2389.png
#   inflating: StrawDI_Db1/train/img/239.png
#   inflating: StrawDI_Db1/train/img/2390.png
#   inflating: StrawDI_Db1/train/img/2391.png
#   inflating: StrawDI_Db1/train/img/2392.png
#   inflating: StrawDI_Db1/train/img/2393.png
#   inflating: StrawDI_Db1/train/img/2394.png
#   inflating: StrawDI_Db1/train/img/2395.png
#   inflating: StrawDI_Db1/train/img/2396.png
#   inflating: StrawDI_Db1/train/img/2397.png
#   inflating: StrawDI_Db1/train/img/2398.png
#   inflating: StrawDI_Db1/train/img/2399.png
#   inflating: StrawDI_Db1/train/img/24.png
#   inflating: StrawDI_Db1/train/img/240.png
#   inflating: StrawDI_Db1/train/img/2400.png
#   inflating: StrawDI_Db1/train/img/2401.png
#   inflating: StrawDI_Db1/train/img/2403.png
#   inflating: StrawDI_Db1/train/img/2404.png
#   inflating: StrawDI_Db1/train/img/2405.png
#   inflating: StrawDI_Db1/train/img/2406.png
#   inflating: StrawDI_Db1/train/img/2407.png
#   inflating: StrawDI_Db1/train/img/2408.png
#   inflating: StrawDI_Db1/train/img/2409.png
#   inflating: StrawDI_Db1/train/img/241.png
#   inflating: StrawDI_Db1/train/img/2411.png
#   inflating: StrawDI_Db1/train/img/2412.png
#   inflating: StrawDI_Db1/train/img/2413.png
#   inflating: StrawDI_Db1/train/img/2414.png
#   inflating: StrawDI_Db1/train/img/2415.png
#   inflating: StrawDI_Db1/train/img/2416.png
#   inflating: StrawDI_Db1/train/img/2417.png
#   inflating: StrawDI_Db1/train/img/2418.png
#   inflating: StrawDI_Db1/train/img/2419.png
#   inflating: StrawDI_Db1/train/img/242.png
#   inflating: StrawDI_Db1/train/img/2420.png
#   inflating: StrawDI_Db1/train/img/2421.png
#   inflating: StrawDI_Db1/train/img/2423.png
#   inflating: StrawDI_Db1/train/img/2424.png
#   inflating: StrawDI_Db1/train/img/2425.png
#   inflating: StrawDI_Db1/train/img/2426.png
#   inflating: StrawDI_Db1/train/img/2427.png
#   inflating: StrawDI_Db1/train/img/2428.png
#   inflating: StrawDI_Db1/train/img/2429.png
#   inflating: StrawDI_Db1/train/img/243.png
#   inflating: StrawDI_Db1/train/img/2430.png
#   inflating: StrawDI_Db1/train/img/2431.png
#   inflating: StrawDI_Db1/train/img/2432.png
#   inflating: StrawDI_Db1/train/img/2433.png
#   inflating: StrawDI_Db1/train/img/2434.png
#   inflating: StrawDI_Db1/train/img/2435.png
#   inflating: StrawDI_Db1/train/img/2436.png
#   inflating: StrawDI_Db1/train/img/2438.png
#   inflating: StrawDI_Db1/train/img/2439.png
#   inflating: StrawDI_Db1/train/img/244.png
#   inflating: StrawDI_Db1/train/img/2440.png
#   inflating: StrawDI_Db1/train/img/2441.png
#   inflating: StrawDI_Db1/train/img/2442.png
#   inflating: StrawDI_Db1/train/img/2444.png
#   inflating: StrawDI_Db1/train/img/2445.png
#   inflating: StrawDI_Db1/train/img/2446.png
#   inflating: StrawDI_Db1/train/img/2447.png
#   inflating: StrawDI_Db1/train/img/2448.png
#   inflating: StrawDI_Db1/train/img/245.png
#   inflating: StrawDI_Db1/train/img/2450.png
#   inflating: StrawDI_Db1/train/img/2451.png
#   inflating: StrawDI_Db1/train/img/2453.png
#   inflating: StrawDI_Db1/train/img/2454.png
#   inflating: StrawDI_Db1/train/img/2455.png
#   inflating: StrawDI_Db1/train/img/2456.png
#   inflating: StrawDI_Db1/train/img/2457.png
#   inflating: StrawDI_Db1/train/img/2458.png
#   inflating: StrawDI_Db1/train/img/2459.png
#   inflating: StrawDI_Db1/train/img/246.png
#   inflating: StrawDI_Db1/train/img/2460.png
#   inflating: StrawDI_Db1/train/img/2462.png
#   inflating: StrawDI_Db1/train/img/2463.png
#   inflating: StrawDI_Db1/train/img/2464.png
#   inflating: StrawDI_Db1/train/img/2465.png
#   inflating: StrawDI_Db1/train/img/2466.png
#   inflating: StrawDI_Db1/train/img/2467.png
#   inflating: StrawDI_Db1/train/img/2468.png
#   inflating: StrawDI_Db1/train/img/2469.png
#   inflating: StrawDI_Db1/train/img/247.png
#   inflating: StrawDI_Db1/train/img/2470.png
#   inflating: StrawDI_Db1/train/img/2471.png
#   inflating: StrawDI_Db1/train/img/2472.png
#   inflating: StrawDI_Db1/train/img/2473.png
#   inflating: StrawDI_Db1/train/img/2474.png
#   inflating: StrawDI_Db1/train/img/2475.png
#   inflating: StrawDI_Db1/train/img/2477.png
#   inflating: StrawDI_Db1/train/img/2479.png
#   inflating: StrawDI_Db1/train/img/248.png
#   inflating: StrawDI_Db1/train/img/2480.png
#   inflating: StrawDI_Db1/train/img/2481.png
#   inflating: StrawDI_Db1/train/img/2482.png
#   inflating: StrawDI_Db1/train/img/2484.png
#   inflating: StrawDI_Db1/train/img/2485.png
#   inflating: StrawDI_Db1/train/img/2486.png
#   inflating: StrawDI_Db1/train/img/2487.png
#   inflating: StrawDI_Db1/train/img/2488.png
#   inflating: StrawDI_Db1/train/img/2489.png
#   inflating: StrawDI_Db1/train/img/249.png
#   inflating: StrawDI_Db1/train/img/2490.png
#   inflating: StrawDI_Db1/train/img/2491.png
#   inflating: StrawDI_Db1/train/img/2492.png
#   inflating: StrawDI_Db1/train/img/2493.png
#   inflating: StrawDI_Db1/train/img/2494.png
#   inflating: StrawDI_Db1/train/img/2495.png
#   inflating: StrawDI_Db1/train/img/2496.png
#   inflating: StrawDI_Db1/train/img/2498.png
#   inflating: StrawDI_Db1/train/img/2499.png
#   inflating: StrawDI_Db1/train/img/25.png
#   inflating: StrawDI_Db1/train/img/250.png
#   inflating: StrawDI_Db1/train/img/2500.png
#   inflating: StrawDI_Db1/train/img/2501.png
#   inflating: StrawDI_Db1/train/img/2502.png
#   inflating: StrawDI_Db1/train/img/2503.png
#   inflating: StrawDI_Db1/train/img/2504.png
#   inflating: StrawDI_Db1/train/img/2505.png
#   inflating: StrawDI_Db1/train/img/2507.png
#   inflating: StrawDI_Db1/train/img/2508.png
#   inflating: StrawDI_Db1/train/img/251.png
#   inflating: StrawDI_Db1/train/img/2510.png
#   inflating: StrawDI_Db1/train/img/2511.png
#   inflating: StrawDI_Db1/train/img/2512.png
#   inflating: StrawDI_Db1/train/img/2513.png
#   inflating: StrawDI_Db1/train/img/2514.png
#   inflating: StrawDI_Db1/train/img/2515.png
#   inflating: StrawDI_Db1/train/img/2516.png
#   inflating: StrawDI_Db1/train/img/2517.png
#   inflating: StrawDI_Db1/train/img/2518.png
#   inflating: StrawDI_Db1/train/img/2519.png
#   inflating: StrawDI_Db1/train/img/252.png
#   inflating: StrawDI_Db1/train/img/2520.png
#   inflating: StrawDI_Db1/train/img/2521.png
#   inflating: StrawDI_Db1/train/img/2522.png
#   inflating: StrawDI_Db1/train/img/2523.png
#   inflating: StrawDI_Db1/train/img/2524.png
#   inflating: StrawDI_Db1/train/img/2525.png
#   inflating: StrawDI_Db1/train/img/2526.png
#   inflating: StrawDI_Db1/train/img/2527.png
#   inflating: StrawDI_Db1/train/img/2528.png
#   inflating: StrawDI_Db1/train/img/253.png
#   inflating: StrawDI_Db1/train/img/2530.png
#   inflating: StrawDI_Db1/train/img/2531.png
#   inflating: StrawDI_Db1/train/img/2533.png
#   inflating: StrawDI_Db1/train/img/2534.png
#   inflating: StrawDI_Db1/train/img/2535.png
#   inflating: StrawDI_Db1/train/img/2536.png
#   inflating: StrawDI_Db1/train/img/2537.png
#   inflating: StrawDI_Db1/train/img/2538.png
#   inflating: StrawDI_Db1/train/img/2539.png
#   inflating: StrawDI_Db1/train/img/254.png
#   inflating: StrawDI_Db1/train/img/2540.png
#   inflating: StrawDI_Db1/train/img/2541.png
#   inflating: StrawDI_Db1/train/img/2542.png
#   inflating: StrawDI_Db1/train/img/2543.png
#   inflating: StrawDI_Db1/train/img/2544.png
#   inflating: StrawDI_Db1/train/img/2545.png
#   inflating: StrawDI_Db1/train/img/2546.png
#   inflating: StrawDI_Db1/train/img/2547.png
#   inflating: StrawDI_Db1/train/img/2548.png
#   inflating: StrawDI_Db1/train/img/2549.png
#   inflating: StrawDI_Db1/train/img/2551.png
#   inflating: StrawDI_Db1/train/img/2552.png
#   inflating: StrawDI_Db1/train/img/2553.png
#   inflating: StrawDI_Db1/train/img/2554.png
#   inflating: StrawDI_Db1/train/img/2555.png
#   inflating: StrawDI_Db1/train/img/2556.png
#   inflating: StrawDI_Db1/train/img/2557.png
#   inflating: StrawDI_Db1/train/img/2558.png
#   inflating: StrawDI_Db1/train/img/2559.png
#   inflating: StrawDI_Db1/train/img/256.png
#   inflating: StrawDI_Db1/train/img/2560.png
#   inflating: StrawDI_Db1/train/img/2562.png
#   inflating: StrawDI_Db1/train/img/2563.png
#   inflating: StrawDI_Db1/train/img/2564.png
#   inflating: StrawDI_Db1/train/img/2565.png
#   inflating: StrawDI_Db1/train/img/2566.png
#   inflating: StrawDI_Db1/train/img/2567.png
#   inflating: StrawDI_Db1/train/img/2568.png
#   inflating: StrawDI_Db1/train/img/2569.png
#   inflating: StrawDI_Db1/train/img/257.png
#   inflating: StrawDI_Db1/train/img/2570.png
#   inflating: StrawDI_Db1/train/img/2571.png
#   inflating: StrawDI_Db1/train/img/2572.png
#   inflating: StrawDI_Db1/train/img/2573.png
#   inflating: StrawDI_Db1/train/img/2574.png
#   inflating: StrawDI_Db1/train/img/2575.png
#   inflating: StrawDI_Db1/train/img/2576.png
#   inflating: StrawDI_Db1/train/img/2578.png
#   inflating: StrawDI_Db1/train/img/2579.png
#   inflating: StrawDI_Db1/train/img/258.png
#   inflating: StrawDI_Db1/train/img/2580.png
#   inflating: StrawDI_Db1/train/img/2581.png
#   inflating: StrawDI_Db1/train/img/2583.png
#   inflating: StrawDI_Db1/train/img/2584.png
#   inflating: StrawDI_Db1/train/img/2585.png
#   inflating: StrawDI_Db1/train/img/2586.png
#   inflating: StrawDI_Db1/train/img/2587.png
#   inflating: StrawDI_Db1/train/img/2588.png
#   inflating: StrawDI_Db1/train/img/2589.png
#   inflating: StrawDI_Db1/train/img/259.png
#   inflating: StrawDI_Db1/train/img/2590.png
#   inflating: StrawDI_Db1/train/img/2591.png
#   inflating: StrawDI_Db1/train/img/2592.png
#   inflating: StrawDI_Db1/train/img/2593.png
#   inflating: StrawDI_Db1/train/img/2594.png
#   inflating: StrawDI_Db1/train/img/2595.png
#   inflating: StrawDI_Db1/train/img/2596.png
#   inflating: StrawDI_Db1/train/img/2597.png
#   inflating: StrawDI_Db1/train/img/2598.png
#   inflating: StrawDI_Db1/train/img/2599.png
#   inflating: StrawDI_Db1/train/img/26.png
#   inflating: StrawDI_Db1/train/img/260.png
#   inflating: StrawDI_Db1/train/img/2600.png
#   inflating: StrawDI_Db1/train/img/2601.png
#   inflating: StrawDI_Db1/train/img/2602.png
#   inflating: StrawDI_Db1/train/img/2604.png
#   inflating: StrawDI_Db1/train/img/2605.png
#   inflating: StrawDI_Db1/train/img/2606.png
#   inflating: StrawDI_Db1/train/img/2607.png
#   inflating: StrawDI_Db1/train/img/2608.png
#   inflating: StrawDI_Db1/train/img/2609.png
#   inflating: StrawDI_Db1/train/img/261.png
#   inflating: StrawDI_Db1/train/img/2610.png
#   inflating: StrawDI_Db1/train/img/2612.png
#   inflating: StrawDI_Db1/train/img/2613.png
#   inflating: StrawDI_Db1/train/img/2614.png
#   inflating: StrawDI_Db1/train/img/2615.png
#   inflating: StrawDI_Db1/train/img/2616.png
#   inflating: StrawDI_Db1/train/img/2617.png
#   inflating: StrawDI_Db1/train/img/2618.png
#   inflating: StrawDI_Db1/train/img/2619.png
#   inflating: StrawDI_Db1/train/img/262.png
#   inflating: StrawDI_Db1/train/img/2620.png
#   inflating: StrawDI_Db1/train/img/2621.png
#   inflating: StrawDI_Db1/train/img/2622.png
#   inflating: StrawDI_Db1/train/img/2623.png
#   inflating: StrawDI_Db1/train/img/2624.png
#   inflating: StrawDI_Db1/train/img/2625.png
#   inflating: StrawDI_Db1/train/img/2626.png
#   inflating: StrawDI_Db1/train/img/2627.png
#   inflating: StrawDI_Db1/train/img/2628.png
#   inflating: StrawDI_Db1/train/img/2629.png
#   inflating: StrawDI_Db1/train/img/263.png
#   inflating: StrawDI_Db1/train/img/2630.png
#   inflating: StrawDI_Db1/train/img/2631.png
#   inflating: StrawDI_Db1/train/img/2632.png
#   inflating: StrawDI_Db1/train/img/2633.png
#   inflating: StrawDI_Db1/train/img/2634.png
#   inflating: StrawDI_Db1/train/img/2635.png
#   inflating: StrawDI_Db1/train/img/2636.png
#   inflating: StrawDI_Db1/train/img/2637.png
#   inflating: StrawDI_Db1/train/img/2638.png
#   inflating: StrawDI_Db1/train/img/2639.png
#   inflating: StrawDI_Db1/train/img/264.png
#   inflating: StrawDI_Db1/train/img/2640.png
#   inflating: StrawDI_Db1/train/img/2641.png
#   inflating: StrawDI_Db1/train/img/2642.png
#   inflating: StrawDI_Db1/train/img/2643.png
#   inflating: StrawDI_Db1/train/img/2644.png
#   inflating: StrawDI_Db1/train/img/2646.png
#   inflating: StrawDI_Db1/train/img/2648.png
#   inflating: StrawDI_Db1/train/img/265.png
#   inflating: StrawDI_Db1/train/img/2650.png
#   inflating: StrawDI_Db1/train/img/2653.png
#   inflating: StrawDI_Db1/train/img/2654.png
#   inflating: StrawDI_Db1/train/img/2655.png
#   inflating: StrawDI_Db1/train/img/2657.png
#   inflating: StrawDI_Db1/train/img/2658.png
#   inflating: StrawDI_Db1/train/img/2659.png
#   inflating: StrawDI_Db1/train/img/266.png
#   inflating: StrawDI_Db1/train/img/2660.png
#   inflating: StrawDI_Db1/train/img/2664.png
#   inflating: StrawDI_Db1/train/img/2665.png
#   inflating: StrawDI_Db1/train/img/2666.png
#   inflating: StrawDI_Db1/train/img/2667.png
#   inflating: StrawDI_Db1/train/img/2668.png
#   inflating: StrawDI_Db1/train/img/2669.png
#   inflating: StrawDI_Db1/train/img/267.png
#   inflating: StrawDI_Db1/train/img/2670.png
#   inflating: StrawDI_Db1/train/img/2671.png
#   inflating: StrawDI_Db1/train/img/2672.png
#   inflating: StrawDI_Db1/train/img/2673.png
#   inflating: StrawDI_Db1/train/img/2674.png
#   inflating: StrawDI_Db1/train/img/2675.png
#   inflating: StrawDI_Db1/train/img/2676.png
#   inflating: StrawDI_Db1/train/img/2677.png
#   inflating: StrawDI_Db1/train/img/2678.png
#   inflating: StrawDI_Db1/train/img/2679.png
#   inflating: StrawDI_Db1/train/img/268.png
#   inflating: StrawDI_Db1/train/img/2680.png
#   inflating: StrawDI_Db1/train/img/2681.png
#   inflating: StrawDI_Db1/train/img/2682.png
#   inflating: StrawDI_Db1/train/img/2683.png
#   inflating: StrawDI_Db1/train/img/2684.png
#   inflating: StrawDI_Db1/train/img/2685.png
#   inflating: StrawDI_Db1/train/img/2686.png
#   inflating: StrawDI_Db1/train/img/2687.png
#   inflating: StrawDI_Db1/train/img/2688.png
#   inflating: StrawDI_Db1/train/img/2689.png
#   inflating: StrawDI_Db1/train/img/269.png
#   inflating: StrawDI_Db1/train/img/2691.png
#   inflating: StrawDI_Db1/train/img/2692.png
#   inflating: StrawDI_Db1/train/img/2693.png
#   inflating: StrawDI_Db1/train/img/2694.png
#   inflating: StrawDI_Db1/train/img/2695.png
#   inflating: StrawDI_Db1/train/img/2696.png
#   inflating: StrawDI_Db1/train/img/2697.png
#   inflating: StrawDI_Db1/train/img/2698.png
#   inflating: StrawDI_Db1/train/img/2699.png
#   inflating: StrawDI_Db1/train/img/27.png
#   inflating: StrawDI_Db1/train/img/270.png
#   inflating: StrawDI_Db1/train/img/2700.png
#   inflating: StrawDI_Db1/train/img/2702.png
#   inflating: StrawDI_Db1/train/img/2703.png
#   inflating: StrawDI_Db1/train/img/2704.png
#   inflating: StrawDI_Db1/train/img/2705.png
#   inflating: StrawDI_Db1/train/img/2706.png
#   inflating: StrawDI_Db1/train/img/2707.png
#   inflating: StrawDI_Db1/train/img/2708.png
#   inflating: StrawDI_Db1/train/img/2709.png
#   inflating: StrawDI_Db1/train/img/271.png
#   inflating: StrawDI_Db1/train/img/2710.png
#   inflating: StrawDI_Db1/train/img/2711.png
#   inflating: StrawDI_Db1/train/img/2712.png
#   inflating: StrawDI_Db1/train/img/2713.png
#   inflating: StrawDI_Db1/train/img/2714.png
#   inflating: StrawDI_Db1/train/img/2715.png
#   inflating: StrawDI_Db1/train/img/2716.png
#   inflating: StrawDI_Db1/train/img/2717.png
#   inflating: StrawDI_Db1/train/img/2719.png
#   inflating: StrawDI_Db1/train/img/272.png
#   inflating: StrawDI_Db1/train/img/2720.png
#   inflating: StrawDI_Db1/train/img/2721.png
#   inflating: StrawDI_Db1/train/img/2722.png
#   inflating: StrawDI_Db1/train/img/2723.png
#   inflating: StrawDI_Db1/train/img/2724.png
#   inflating: StrawDI_Db1/train/img/2725.png
#   inflating: StrawDI_Db1/train/img/2726.png
#   inflating: StrawDI_Db1/train/img/2727.png
#   inflating: StrawDI_Db1/train/img/2728.png
#   inflating: StrawDI_Db1/train/img/2729.png
#   inflating: StrawDI_Db1/train/img/273.png
#   inflating: StrawDI_Db1/train/img/2730.png
#   inflating: StrawDI_Db1/train/img/2732.png
#   inflating: StrawDI_Db1/train/img/2733.png
#   inflating: StrawDI_Db1/train/img/2735.png
#   inflating: StrawDI_Db1/train/img/2736.png
#   inflating: StrawDI_Db1/train/img/2737.png
#   inflating: StrawDI_Db1/train/img/2738.png
#   inflating: StrawDI_Db1/train/img/2739.png
#   inflating: StrawDI_Db1/train/img/274.png
#   inflating: StrawDI_Db1/train/img/2740.png
#   inflating: StrawDI_Db1/train/img/2741.png
#   inflating: StrawDI_Db1/train/img/2742.png
#   inflating: StrawDI_Db1/train/img/2743.png
#   inflating: StrawDI_Db1/train/img/2744.png
#   inflating: StrawDI_Db1/train/img/2745.png
#   inflating: StrawDI_Db1/train/img/2747.png
#   inflating: StrawDI_Db1/train/img/2748.png
#   inflating: StrawDI_Db1/train/img/2749.png
#   inflating: StrawDI_Db1/train/img/275.png
#   inflating: StrawDI_Db1/train/img/2750.png
#   inflating: StrawDI_Db1/train/img/2751.png
#   inflating: StrawDI_Db1/train/img/2752.png
#   inflating: StrawDI_Db1/train/img/2753.png
#   inflating: StrawDI_Db1/train/img/2754.png
#   inflating: StrawDI_Db1/train/img/2755.png
#   inflating: StrawDI_Db1/train/img/2756.png
#   inflating: StrawDI_Db1/train/img/2757.png
#   inflating: StrawDI_Db1/train/img/2758.png
#   inflating: StrawDI_Db1/train/img/2759.png
#   inflating: StrawDI_Db1/train/img/276.png
#   inflating: StrawDI_Db1/train/img/2760.png
#   inflating: StrawDI_Db1/train/img/2761.png
#   inflating: StrawDI_Db1/train/img/2762.png
#   inflating: StrawDI_Db1/train/img/2763.png
#   inflating: StrawDI_Db1/train/img/2764.png
#   inflating: StrawDI_Db1/train/img/2765.png
#   inflating: StrawDI_Db1/train/img/2766.png
#   inflating: StrawDI_Db1/train/img/2767.png
#   inflating: StrawDI_Db1/train/img/2768.png
#   inflating: StrawDI_Db1/train/img/2769.png
#   inflating: StrawDI_Db1/train/img/2770.png
#   inflating: StrawDI_Db1/train/img/2771.png
#   inflating: StrawDI_Db1/train/img/2772.png
#   inflating: StrawDI_Db1/train/img/2773.png
#   inflating: StrawDI_Db1/train/img/2774.png
#   inflating: StrawDI_Db1/train/img/2775.png
#   inflating: StrawDI_Db1/train/img/2777.png
#   inflating: StrawDI_Db1/train/img/2778.png
#   inflating: StrawDI_Db1/train/img/2779.png
#   inflating: StrawDI_Db1/train/img/278.png
#   inflating: StrawDI_Db1/train/img/2781.png
#   inflating: StrawDI_Db1/train/img/2782.png
#   inflating: StrawDI_Db1/train/img/2783.png
#   inflating: StrawDI_Db1/train/img/2784.png
#   inflating: StrawDI_Db1/train/img/2785.png
#   inflating: StrawDI_Db1/train/img/2786.png
#   inflating: StrawDI_Db1/train/img/2787.png
#   inflating: StrawDI_Db1/train/img/2788.png
#   inflating: StrawDI_Db1/train/img/2789.png
#   inflating: StrawDI_Db1/train/img/279.png
#   inflating: StrawDI_Db1/train/img/2790.png
#   inflating: StrawDI_Db1/train/img/2791.png
#   inflating: StrawDI_Db1/train/img/2792.png
#   inflating: StrawDI_Db1/train/img/2793.png
#   inflating: StrawDI_Db1/train/img/2794.png
#   inflating: StrawDI_Db1/train/img/2795.png
#   inflating: StrawDI_Db1/train/img/2797.png
#   inflating: StrawDI_Db1/train/img/2798.png
#   inflating: StrawDI_Db1/train/img/2799.png
#   inflating: StrawDI_Db1/train/img/28.png
#   inflating: StrawDI_Db1/train/img/280.png
#   inflating: StrawDI_Db1/train/img/2800.png
#   inflating: StrawDI_Db1/train/img/2801.png
#   inflating: StrawDI_Db1/train/img/2802.png
#   inflating: StrawDI_Db1/train/img/2803.png
#   inflating: StrawDI_Db1/train/img/2804.png
#   inflating: StrawDI_Db1/train/img/2805.png
#   inflating: StrawDI_Db1/train/img/2806.png
#   inflating: StrawDI_Db1/train/img/2808.png
#   inflating: StrawDI_Db1/train/img/2809.png
#   inflating: StrawDI_Db1/train/img/281.png
#   inflating: StrawDI_Db1/train/img/2810.png
#   inflating: StrawDI_Db1/train/img/2811.png
#   inflating: StrawDI_Db1/train/img/2812.png
#   inflating: StrawDI_Db1/train/img/2813.png
#   inflating: StrawDI_Db1/train/img/2815.png
#   inflating: StrawDI_Db1/train/img/2816.png
#   inflating: StrawDI_Db1/train/img/2817.png
#   inflating: StrawDI_Db1/train/img/2818.png
#   inflating: StrawDI_Db1/train/img/2819.png
#   inflating: StrawDI_Db1/train/img/282.png
#   inflating: StrawDI_Db1/train/img/2820.png
#   inflating: StrawDI_Db1/train/img/2821.png
#   inflating: StrawDI_Db1/train/img/2822.png
#   inflating: StrawDI_Db1/train/img/2824.png
#   inflating: StrawDI_Db1/train/img/2825.png
#   inflating: StrawDI_Db1/train/img/2826.png
#   inflating: StrawDI_Db1/train/img/2827.png
#   inflating: StrawDI_Db1/train/img/2828.png
#   inflating: StrawDI_Db1/train/img/2829.png
#   inflating: StrawDI_Db1/train/img/283.png
#   inflating: StrawDI_Db1/train/img/2830.png
#   inflating: StrawDI_Db1/train/img/2831.png
#   inflating: StrawDI_Db1/train/img/2832.png
# ...
#   inflating: StrawDI_Db1/train/label/848.png
#   inflating: StrawDI_Db1/train/label/849.png
#   inflating: StrawDI_Db1/train/label/85.png
#   inflating: StrawDI_Db1/train/label/850.png
#   inflating: StrawDI_Db1/train/label/851.png
#   inflating: StrawDI_Db1/train/label/852.png
#   inflating: StrawDI_Db1/train/label/853.png
#   inflating: StrawDI_Db1/train/label/854.png
#   inflating: StrawDI_Db1/train/label/855.png
#   inflating: StrawDI_Db1/train/label/857.png
#   inflating: StrawDI_Db1/train/label/859.png
#   inflating: StrawDI_Db1/train/label/86.png
#   inflating: StrawDI_Db1/train/label/860.png
#   inflating: StrawDI_Db1/train/label/861.png
#   inflating: StrawDI_Db1/train/label/862.png
#   inflating: StrawDI_Db1/train/label/863.png
#   inflating: StrawDI_Db1/train/label/864.png
#   inflating: StrawDI_Db1/train/label/865.png
#   inflating: StrawDI_Db1/train/label/866.png
#   inflating: StrawDI_Db1/train/label/867.png
#   inflating: StrawDI_Db1/train/label/868.png
#   inflating: StrawDI_Db1/train/label/87.png
#   inflating: StrawDI_Db1/train/label/870.png
#   inflating: StrawDI_Db1/train/label/871.png
#   inflating: StrawDI_Db1/train/label/872.png
#   inflating: StrawDI_Db1/train/label/873.png
#   inflating: StrawDI_Db1/train/label/874.png
#   inflating: StrawDI_Db1/train/label/875.png
#   inflating: StrawDI_Db1/train/label/876.png
#   inflating: StrawDI_Db1/train/label/877.png
#   inflating: StrawDI_Db1/train/label/879.png
#   inflating: StrawDI_Db1/train/label/88.png
#   inflating: StrawDI_Db1/train/label/880.png
#   inflating: StrawDI_Db1/train/label/881.png
#   inflating: StrawDI_Db1/train/label/882.png
#   inflating: StrawDI_Db1/train/label/883.png
#   inflating: StrawDI_Db1/train/label/884.png
#   inflating: StrawDI_Db1/train/label/885.png
#   inflating: StrawDI_Db1/train/label/886.png
#   inflating: StrawDI_Db1/train/label/887.png
#   inflating: StrawDI_Db1/train/label/889.png
#   inflating: StrawDI_Db1/train/label/89.png
#   inflating: StrawDI_Db1/train/label/890.png
#   inflating: StrawDI_Db1/train/label/892.png
#   inflating: StrawDI_Db1/train/label/893.png
#   inflating: StrawDI_Db1/train/label/894.png
#   inflating: StrawDI_Db1/train/label/895.png
#   inflating: StrawDI_Db1/train/label/897.png
#   inflating: StrawDI_Db1/train/label/898.png
#   inflating: StrawDI_Db1/train/label/899.png
#   inflating: StrawDI_Db1/train/label/9.png
#   inflating: StrawDI_Db1/train/label/90.png
#   inflating: StrawDI_Db1/train/label/900.png
#   inflating: StrawDI_Db1/train/label/901.png
#   inflating: StrawDI_Db1/train/label/902.png
#   inflating: StrawDI_Db1/train/label/903.png
#   inflating: StrawDI_Db1/train/label/904.png
#   inflating: StrawDI_Db1/train/label/906.png
#   inflating: StrawDI_Db1/train/label/907.png
#   inflating: StrawDI_Db1/train/label/908.png
#   inflating: StrawDI_Db1/train/label/909.png
#   inflating: StrawDI_Db1/train/label/91.png
#   inflating: StrawDI_Db1/train/label/910.png
#   inflating: StrawDI_Db1/train/label/911.png
#   inflating: StrawDI_Db1/train/label/912.png
#   inflating: StrawDI_Db1/train/label/913.png
#   inflating: StrawDI_Db1/train/label/914.png
#   inflating: StrawDI_Db1/train/label/915.png
#   inflating: StrawDI_Db1/train/label/917.png
#   inflating: StrawDI_Db1/train/label/918.png
#   inflating: StrawDI_Db1/train/label/919.png
#   inflating: StrawDI_Db1/train/label/921.png
#   inflating: StrawDI_Db1/train/label/922.png
#   inflating: StrawDI_Db1/train/label/923.png
#   inflating: StrawDI_Db1/train/label/924.png
#   inflating: StrawDI_Db1/train/label/925.png
#   inflating: StrawDI_Db1/train/label/927.png
#   inflating: StrawDI_Db1/train/label/928.png
#   inflating: StrawDI_Db1/train/label/929.png
#   inflating: StrawDI_Db1/train/label/93.png
#   inflating: StrawDI_Db1/train/label/930.png
#   inflating: StrawDI_Db1/train/label/931.png
#   inflating: StrawDI_Db1/train/label/932.png
#   inflating: StrawDI_Db1/train/label/933.png
#   inflating: StrawDI_Db1/train/label/934.png
#   inflating: StrawDI_Db1/train/label/935.png
#   inflating: StrawDI_Db1/train/label/936.png
#   inflating: StrawDI_Db1/train/label/937.png
#   inflating: StrawDI_Db1/train/label/939.png
#   inflating: StrawDI_Db1/train/label/94.png
#   inflating: StrawDI_Db1/train/label/940.png
#   inflating: StrawDI_Db1/train/label/941.png
#   inflating: StrawDI_Db1/train/label/943.png
#   inflating: StrawDI_Db1/train/label/944.png
#   inflating: StrawDI_Db1/train/label/945.png
#   inflating: StrawDI_Db1/train/label/946.png
#   inflating: StrawDI_Db1/train/label/947.png
#   inflating: StrawDI_Db1/train/label/948.png
#   inflating: StrawDI_Db1/train/label/95.png
#   inflating: StrawDI_Db1/train/label/951.png
#   inflating: StrawDI_Db1/train/label/953.png
#   inflating: StrawDI_Db1/train/label/954.png
#   inflating: StrawDI_Db1/train/label/955.png
#   inflating: StrawDI_Db1/train/label/956.png
#   inflating: StrawDI_Db1/train/label/957.png
#   inflating: StrawDI_Db1/train/label/958.png
#   inflating: StrawDI_Db1/train/label/959.png
#   inflating: StrawDI_Db1/train/label/96.png
#   inflating: StrawDI_Db1/train/label/960.png
#   inflating: StrawDI_Db1/train/label/961.png
#   inflating: StrawDI_Db1/train/label/962.png
#   inflating: StrawDI_Db1/train/label/963.png
#   inflating: StrawDI_Db1/train/label/964.png
#   inflating: StrawDI_Db1/train/label/965.png
#   inflating: StrawDI_Db1/train/label/966.png
#   inflating: StrawDI_Db1/train/label/968.png
#   inflating: StrawDI_Db1/train/label/969.png
#   inflating: StrawDI_Db1/train/label/97.png
#   inflating: StrawDI_Db1/train/label/970.png
#   inflating: StrawDI_Db1/train/label/971.png
#   inflating: StrawDI_Db1/train/label/972.png
#   inflating: StrawDI_Db1/train/label/973.png
#   inflating: StrawDI_Db1/train/label/974.png
#   inflating: StrawDI_Db1/train/label/975.png
#   inflating: StrawDI_Db1/train/label/976.png
#   inflating: StrawDI_Db1/train/label/977.png
#   inflating: StrawDI_Db1/train/label/978.png
#   inflating: StrawDI_Db1/train/label/979.png
#   inflating: StrawDI_Db1/train/label/98.png
#   inflating: StrawDI_Db1/train/label/981.png
#   inflating: StrawDI_Db1/train/label/982.png
#   inflating: StrawDI_Db1/train/label/983.png
#   inflating: StrawDI_Db1/train/label/984.png
#   inflating: StrawDI_Db1/train/label/985.png
#   inflating: StrawDI_Db1/train/label/986.png
#   inflating: StrawDI_Db1/train/label/987.png
#   inflating: StrawDI_Db1/train/label/988.png
#   inflating: StrawDI_Db1/train/label/989.png
#   inflating: StrawDI_Db1/train/label/99.png
#   inflating: StrawDI_Db1/train/label/990.png
#   inflating: StrawDI_Db1/train/label/991.png
#   inflating: StrawDI_Db1/train/label/992.png
#   inflating: StrawDI_Db1/train/label/993.png
#   inflating: StrawDI_Db1/train/label/994.png
#   inflating: StrawDI_Db1/train/label/996.png
#   inflating: StrawDI_Db1/train/label/997.png
#   inflating: StrawDI_Db1/train/label/998.png
#   inflating: StrawDI_Db1/train/label/999.png
#    creating: StrawDI_Db1/val/
#    creating: StrawDI_Db1/val/img/
#   inflating: StrawDI_Db1/val/img/1002.png
#   inflating: StrawDI_Db1/val/img/1029.png
#   inflating: StrawDI_Db1/val/img/108.png
#   inflating: StrawDI_Db1/val/img/1099.png
#   inflating: StrawDI_Db1/val/img/1104.png
#   inflating: StrawDI_Db1/val/img/1112.png
#   inflating: StrawDI_Db1/val/img/113.png
#   inflating: StrawDI_Db1/val/img/1147.png
#   inflating: StrawDI_Db1/val/img/117.png
#   inflating: StrawDI_Db1/val/img/1215.png
#   inflating: StrawDI_Db1/val/img/1272.png
#   inflating: StrawDI_Db1/val/img/1274.png
#   inflating: StrawDI_Db1/val/img/1286.png
#   inflating: StrawDI_Db1/val/img/1360.png
#   inflating: StrawDI_Db1/val/img/1367.png
#   inflating: StrawDI_Db1/val/img/138.png
#   inflating: StrawDI_Db1/val/img/1426.png
#   inflating: StrawDI_Db1/val/img/1478.png
#   inflating: StrawDI_Db1/val/img/1531.png
#   inflating: StrawDI_Db1/val/img/1561.png
#   inflating: StrawDI_Db1/val/img/1603.png
#   inflating: StrawDI_Db1/val/img/1667.png
#   inflating: StrawDI_Db1/val/img/1673.png
#   inflating: StrawDI_Db1/val/img/1685.png
#   inflating: StrawDI_Db1/val/img/1686.png
#   inflating: StrawDI_Db1/val/img/1716.png
#   inflating: StrawDI_Db1/val/img/1717.png
#   inflating: StrawDI_Db1/val/img/1733.png
#   inflating: StrawDI_Db1/val/img/1740.png
#   inflating: StrawDI_Db1/val/img/1753.png
#   inflating: StrawDI_Db1/val/img/1783.png
#   inflating: StrawDI_Db1/val/img/1792.png
#   inflating: StrawDI_Db1/val/img/1803.png
#   inflating: StrawDI_Db1/val/img/1813.png
#   inflating: StrawDI_Db1/val/img/1852.png
#   inflating: StrawDI_Db1/val/img/192.png
#   inflating: StrawDI_Db1/val/img/1943.png
#  extracting: StrawDI_Db1/val/img/1979.png
#   inflating: StrawDI_Db1/val/img/2094.png
#   inflating: StrawDI_Db1/val/img/2105.png
#   inflating: StrawDI_Db1/val/img/2121.png
#   inflating: StrawDI_Db1/val/img/2169.png
#   inflating: StrawDI_Db1/val/img/2230.png
#   inflating: StrawDI_Db1/val/img/2236.png
#   inflating: StrawDI_Db1/val/img/2247.png
#   inflating: StrawDI_Db1/val/img/2295.png
#   inflating: StrawDI_Db1/val/img/231.png
#   inflating: StrawDI_Db1/val/img/2325.png
#   inflating: StrawDI_Db1/val/img/2351.png
#   inflating: StrawDI_Db1/val/img/2360.png
#   inflating: StrawDI_Db1/val/img/2437.png
#   inflating: StrawDI_Db1/val/img/2476.png
#   inflating: StrawDI_Db1/val/img/2497.png
#   inflating: StrawDI_Db1/val/img/2506.png
#   inflating: StrawDI_Db1/val/img/2529.png
#   inflating: StrawDI_Db1/val/img/2561.png
#   inflating: StrawDI_Db1/val/img/2577.png
#   inflating: StrawDI_Db1/val/img/2645.png
#   inflating: StrawDI_Db1/val/img/2647.png
#   inflating: StrawDI_Db1/val/img/2663.png
#   inflating: StrawDI_Db1/val/img/2746.png
#   inflating: StrawDI_Db1/val/img/2780.png
#   inflating: StrawDI_Db1/val/img/2864.png
#   inflating: StrawDI_Db1/val/img/2867.png
#   inflating: StrawDI_Db1/val/img/2970.png
#   inflating: StrawDI_Db1/val/img/2989.png
#   inflating: StrawDI_Db1/val/img/2997.png
#   inflating: StrawDI_Db1/val/img/3026.png
#   inflating: StrawDI_Db1/val/img/3063.png
#   inflating: StrawDI_Db1/val/img/3064.png
#   inflating: StrawDI_Db1/val/img/3067.png
#   inflating: StrawDI_Db1/val/img/332.png
#   inflating: StrawDI_Db1/val/img/363.png
#   inflating: StrawDI_Db1/val/img/380.png
#   inflating: StrawDI_Db1/val/img/404.png
#   inflating: StrawDI_Db1/val/img/431.png
#   inflating: StrawDI_Db1/val/img/451.png
#   inflating: StrawDI_Db1/val/img/471.png
#   inflating: StrawDI_Db1/val/img/49.png
#   inflating: StrawDI_Db1/val/img/501.png
#   inflating: StrawDI_Db1/val/img/526.png
#   inflating: StrawDI_Db1/val/img/533.png
#   inflating: StrawDI_Db1/val/img/544.png
#   inflating: StrawDI_Db1/val/img/567.png
#   inflating: StrawDI_Db1/val/img/587.png
#   inflating: StrawDI_Db1/val/img/66.png
#   inflating: StrawDI_Db1/val/img/678.png
#   inflating: StrawDI_Db1/val/img/7.png
#   inflating: StrawDI_Db1/val/img/710.png
#   inflating: StrawDI_Db1/val/img/745.png
#   inflating: StrawDI_Db1/val/img/759.png
#   inflating: StrawDI_Db1/val/img/821.png
#   inflating: StrawDI_Db1/val/img/824.png
#   inflating: StrawDI_Db1/val/img/856.png
#   inflating: StrawDI_Db1/val/img/878.png
#   inflating: StrawDI_Db1/val/img/891.png
#   inflating: StrawDI_Db1/val/img/896.png
#   inflating: StrawDI_Db1/val/img/916.png
#   inflating: StrawDI_Db1/val/img/949.png
#   inflating: StrawDI_Db1/val/img/967.png
#    creating: StrawDI_Db1/val/label/
#   inflating: StrawDI_Db1/val/label/1002.png
#   inflating: StrawDI_Db1/val/label/1029.png
#   inflating: StrawDI_Db1/val/label/108.png
#   inflating: StrawDI_Db1/val/label/1099.png
#   inflating: StrawDI_Db1/val/label/1104.png
#   inflating: StrawDI_Db1/val/label/1112.png
#   inflating: StrawDI_Db1/val/label/113.png
#   inflating: StrawDI_Db1/val/label/1147.png
#   inflating: StrawDI_Db1/val/label/117.png
#   inflating: StrawDI_Db1/val/label/1215.png
#   inflating: StrawDI_Db1/val/label/1272.png
#   inflating: StrawDI_Db1/val/label/1274.png
#   inflating: StrawDI_Db1/val/label/1286.png
#   inflating: StrawDI_Db1/val/label/1360.png
#   inflating: StrawDI_Db1/val/label/1367.png
#   inflating: StrawDI_Db1/val/label/138.png
#   inflating: StrawDI_Db1/val/label/1426.png
#   inflating: StrawDI_Db1/val/label/1478.png
#   inflating: StrawDI_Db1/val/label/1531.png
#   inflating: StrawDI_Db1/val/label/1561.png
#   inflating: StrawDI_Db1/val/label/1603.png
#   inflating: StrawDI_Db1/val/label/1667.png
#   inflating: StrawDI_Db1/val/label/1673.png
#   inflating: StrawDI_Db1/val/label/1685.png
#   inflating: StrawDI_Db1/val/label/1686.png
#   inflating: StrawDI_Db1/val/label/1716.png
#   inflating: StrawDI_Db1/val/label/1717.png
#   inflating: StrawDI_Db1/val/label/1733.png
#   inflating: StrawDI_Db1/val/label/1740.png
#   inflating: StrawDI_Db1/val/label/1753.png
#   inflating: StrawDI_Db1/val/label/1783.png
#   inflating: StrawDI_Db1/val/label/1792.png
#   inflating: StrawDI_Db1/val/label/1803.png
#   inflating: StrawDI_Db1/val/label/1813.png
#   inflating: StrawDI_Db1/val/label/1852.png
#   inflating: StrawDI_Db1/val/label/192.png
#   inflating: StrawDI_Db1/val/label/1943.png
#   inflating: StrawDI_Db1/val/label/1979.png
#   inflating: StrawDI_Db1/val/label/2094.png
#   inflating: StrawDI_Db1/val/label/2105.png
#   inflating: StrawDI_Db1/val/label/2121.png
#   inflating: StrawDI_Db1/val/label/2169.png
#   inflating: StrawDI_Db1/val/label/2230.png
#   inflating: StrawDI_Db1/val/label/2236.png
#   inflating: StrawDI_Db1/val/label/2247.png
#   inflating: StrawDI_Db1/val/label/2295.png
#   inflating: StrawDI_Db1/val/label/231.png
#   inflating: StrawDI_Db1/val/label/2325.png
#   inflating: StrawDI_Db1/val/label/2351.png
#   inflating: StrawDI_Db1/val/label/2360.png
#   inflating: StrawDI_Db1/val/label/2437.png
#   inflating: StrawDI_Db1/val/label/2476.png
#   inflating: StrawDI_Db1/val/label/2497.png
#   inflating: StrawDI_Db1/val/label/2506.png
#   inflating: StrawDI_Db1/val/label/2529.png
#   inflating: StrawDI_Db1/val/label/2561.png
#   inflating: StrawDI_Db1/val/label/2577.png
#   inflating: StrawDI_Db1/val/label/2645.png
#   inflating: StrawDI_Db1/val/label/2647.png
#   inflating: StrawDI_Db1/val/label/2663.png
#   inflating: StrawDI_Db1/val/label/2746.png
#   inflating: StrawDI_Db1/val/label/2780.png
#   inflating: StrawDI_Db1/val/label/2864.png
#   inflating: StrawDI_Db1/val/label/2867.png
#   inflating: StrawDI_Db1/val/label/2970.png
#   inflating: StrawDI_Db1/val/label/2989.png
#   inflating: StrawDI_Db1/val/label/2997.png
#   inflating: StrawDI_Db1/val/label/3026.png
#   inflating: StrawDI_Db1/val/label/3063.png
#   inflating: StrawDI_Db1/val/label/3064.png
#   inflating: StrawDI_Db1/val/label/3067.png
#   inflating: StrawDI_Db1/val/label/332.png
#   inflating: StrawDI_Db1/val/label/363.png
#   inflating: StrawDI_Db1/val/label/380.png
#   inflating: StrawDI_Db1/val/label/404.png
#   inflating: StrawDI_Db1/val/label/431.png
#   inflating: StrawDI_Db1/val/label/451.png
#   inflating: StrawDI_Db1/val/label/471.png
#   inflating: StrawDI_Db1/val/label/49.png
#   inflating: StrawDI_Db1/val/label/501.png
#   inflating: StrawDI_Db1/val/label/526.png
#   inflating: StrawDI_Db1/val/label/533.png
#   inflating: StrawDI_Db1/val/label/544.png
#   inflating: StrawDI_Db1/val/label/567.png
#   inflating: StrawDI_Db1/val/label/587.png
#   inflating: StrawDI_Db1/val/label/66.png
#   inflating: StrawDI_Db1/val/label/678.png
#   inflating: StrawDI_Db1/val/label/7.png
#   inflating: StrawDI_Db1/val/label/710.png
#   inflating: StrawDI_Db1/val/label/745.png
#   inflating: StrawDI_Db1/val/label/759.png
#   inflating: StrawDI_Db1/val/label/821.png
#   inflating: StrawDI_Db1/val/label/824.png
#   inflating: StrawDI_Db1/val/label/856.png
#   inflating: StrawDI_Db1/val/label/878.png
#   inflating: StrawDI_Db1/val/label/891.png
#   inflating: StrawDI_Db1/val/label/896.png
#   inflating: StrawDI_Db1/val/label/916.png
#   inflating: StrawDI_Db1/val/label/949.png
#   inflating: StrawDI_Db1/val/label/967.png

# %%
! mv /content/StrawDI_Db1 /content/dataset

# %% [markdown]
# ## Transform to Coco Format annotations

# %% [markdown]
# * Train dataset

# %%
from PIL import Image
import numpy as np
from skimage import measure
from shapely.geometry import Polygon, MultiPolygon
import json
import os


def create_sub_masks(mask_image):
    width, height = mask_image.size

    # Initialize a dictionary of sub-masks indexed by RGB colors
    sub_masks = {}
    for x in range(width):
        for y in range(height):
            # Get the RGB values of the pixel
            pixel = mask_image.getpixel((x, y))[:3]

            # If the pixel is not black...
            if pixel != (0, 0, 0):
                # Check to see if we've created a sub-mask...
                pixel_str = str(pixel)
                sub_mask = sub_masks.get(pixel_str)
                if sub_mask is None:
                   # Create a sub-mask (one bit per pixel) and add to the dictionary
                    # Note: we add 1 pixel of padding in each direction
                    # because the contours module doesn't handle cases
                    # where pixels bleed to the edge of the image
                    sub_masks[pixel_str] = Image.new('1', (width+2, height+2))

                # Set the pixel value to 1 (default is 0), accounting for padding
                sub_masks[pixel_str].putpixel((x+1, y+1), 1)

    return sub_masks


def create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd):
    # Find contours (boundary lines) around each sub-mask
    # Note: there could be multiple contours if the object
    # is partially occluded. (E.g. an elephant behind a tree)
    contours = measure.find_contours(np.array(sub_mask), 0.5, positive_orientation='low')

    segmentations = []
    polygons = []
    for contour in contours:
        # Flip from (row, col) representation to (x, y)
        # and subtract the padding pixel
        for i in range(len(contour)):
            row, col = contour[i]
            contour[i] = (col - 1, row - 1)

        # Make a polygon and simplify it
        poly = Polygon(contour)
        poly = poly.simplify(1.0, preserve_topology=False)
        polygons.append(poly)
        segmentation = np.array(poly.exterior.coords)
        segmentation = np.maximum(segmentation, 0).ravel().tolist()
        segmentations.append(segmentation)

    # Combine the polygons to calculate the bounding box and area
    multi_poly = MultiPolygon(polygons)
    if multi_poly.bounds == ():
        return "skip"
    x, y, max_x, max_y = multi_poly.bounds
    # x = max(0, x)
    # y = max(0, y)
    width = max_x - x
    height = max_y - y
    bbox = (x, y, width, height)
    area = multi_poly.area

    annotation = {
        'segmentation': segmentations,
        'iscrowd': is_crowd,
        'image_id': image_id,
        'category_id': category_id,
        'id': annotation_id,
        'bbox': bbox,
        'area': area
    }

    return annotation


def get_name(root, mode_folder=True):
    for root, dirs, file in os.walk(root):
        if mode_folder:
            return sorted(dirs)
        else:
            return sorted(file)


def get_annotation(mask_image_root):
    dataset = {"info": {"year": 2022, "version": "2022", "description": "Strawberry", "contributor": "Crespo", "url": "",
                        "date_created": "2022.01.29"},
               "license": {"id": 1, "url": "", "name": "Crespo"},
               "images": [],
               "annotations": [],
               "categories": []}
    class_index = {0: "strawberry"}
    for s, k in enumerate(list(class_index.keys())):
        dataset["categories"].append({"id": k, "name": class_index[k], "supercategory": "fruit"})

    is_crowd = 0

    # These ids will be automatically increased as we go
    annotation_id = 0
    image_id = 0

    # Create the annotations
    for i, root in enumerate(mask_image_root):
        try:
          #print(i)
          mask_image = Image.open(rrr + root)
          try:
            image_id = int(root.split(".")[0])
          except:
            image_id += 0
          mask_image  = mask_image.convert("RGB")
          #print(root)
          weight, height = mask_image.size
          file_name = root.split("/")[-1].split("_")[-1]
          #print(file_name)
          dataset["images"].append({"license": 1,
                                    "file_name": file_name,
                                    #"id": i,
                                    "id": image_id,
                                    "width": weight,
                                    "height": height})
          sub_masks = create_sub_masks(mask_image)
          for color, sub_mask in sub_masks.items():
              category_id = 0
              annotation = create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd)
              if annotation == "skip":
                  continue
              dataset["annotations"].append(annotation)
              annotation_id += 1
          #image_id += 1
        except:
          print(root)
          continue
    with open("train.json", "w") as f:
        json.dump(dataset, f)


rrr = "/content/dataset/train/label/"
all_root = get_name(rrr, mode_folder=False)
get_annotation(all_root)
# Out:
# 933.png

# %% [markdown]
# * Val dataset

# %%
from PIL import Image
import numpy as np
from skimage import measure
from shapely.geometry import Polygon, MultiPolygon
import json
import os


def create_sub_masks(mask_image):
    width, height = mask_image.size

    # Initialize a dictionary of sub-masks indexed by RGB colors
    sub_masks = {}
    for x in range(width):
        for y in range(height):
            # Get the RGB values of the pixel
            pixel = mask_image.getpixel((x, y))[:3]

            # If the pixel is not black...
            if pixel != (0, 0, 0):
                # Check to see if we've created a sub-mask...
                pixel_str = str(pixel)
                sub_mask = sub_masks.get(pixel_str)
                if sub_mask is None:
                   # Create a sub-mask (one bit per pixel) and add to the dictionary
                    # Note: we add 1 pixel of padding in each direction
                    # because the contours module doesn't handle cases
                    # where pixels bleed to the edge of the image
                    sub_masks[pixel_str] = Image.new('1', (width+2, height+2))

                # Set the pixel value to 1 (default is 0), accounting for padding
                sub_masks[pixel_str].putpixel((x+1, y+1), 1)

    return sub_masks


def create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd):
    # Find contours (boundary lines) around each sub-mask
    # Note: there could be multiple contours if the object
    # is partially occluded. (E.g. an elephant behind a tree)
    contours = measure.find_contours(np.array(sub_mask), 0.5, positive_orientation='low')

    segmentations = []
    polygons = []
    for contour in contours:
        # Flip from (row, col) representation to (x, y)
        # and subtract the padding pixel
        for i in range(len(contour)):
            row, col = contour[i]
            contour[i] = (col - 1, row - 1)

        # Make a polygon and simplify it
        poly = Polygon(contour)
        poly = poly.simplify(1.0, preserve_topology=False)
        polygons.append(poly)
        segmentation = np.array(poly.exterior.coords)
        segmentation = np.maximum(segmentation, 0).ravel().tolist()
        segmentations.append(segmentation)

    # Combine the polygons to calculate the bounding box and area
    multi_poly = MultiPolygon(polygons)
    if multi_poly.bounds == ():
        return "skip"
    x, y, max_x, max_y = multi_poly.bounds
    # x = max(0, x)
    # y = max(0, y)
    width = max_x - x
    height = max_y - y
    bbox = (x, y, width, height)
    area = multi_poly.area

    annotation = {
        'segmentation': segmentations,
        'iscrowd': is_crowd,
        'image_id': image_id,
        'category_id': category_id,
        'id': annotation_id,
        'bbox': bbox,
        'area': area
    }

    return annotation


def get_name(root, mode_folder=True):
    for root, dirs, file in os.walk(root):
        if mode_folder:
            return sorted(dirs)
        else:
            return sorted(file)


def get_annotation(mask_image_root):
    dataset = {"info": {"year": 2022, "version": "2022", "description": "Strawberry", "contributor": "Crespo", "url": "",
                        "date_created": "2022.01.29"},
               "license": {"id": 1, "url": "", "name": "Crespo"},
               "images": [],
               "annotations": [],
               "categories": []}
    class_index = {0: "strawberry"}
    for s, k in enumerate(list(class_index.keys())):
        dataset["categories"].append({"id": k, "name": class_index[k], "supercategory": "fruit"})

    is_crowd = 0

    # These ids will be automatically increased as we go
    annotation_id = 0
    image_id = 0

    # Create the annotations
    for i, root in enumerate(mask_image_root):
        try:
          #print(i)
          mask_image = Image.open(rrr + root)
          try:
            image_id = int(root.split(".")[0])
          except:
            image_id += 0
          mask_image  = mask_image.convert("RGB")
          #print(root)
          weight, height = mask_image.size
          file_name = root.split("/")[-1].split("_")[-1]
          #print(file_name)
          dataset["images"].append({"license": 1,
                                    "file_name": file_name,
                                    #"id": i,
                                    "id": image_id,
                                    "width": weight,
                                    "height": height})
          sub_masks = create_sub_masks(mask_image)
          for color, sub_mask in sub_masks.items():
              category_id = 0
              annotation = create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd)
              if annotation == "skip":
                  continue
              dataset["annotations"].append(annotation)
              annotation_id += 1
          #image_id += 1
        except:
          print(root)
          continue
    with open("val.json", "w") as f:
        json.dump(dataset, f)


rrr = "/content/dataset/val/label/"
all_root = get_name(rrr, mode_folder=False)
get_annotation(all_root)

# %% [markdown]
# * Test dataset

# %%
from PIL import Image
import numpy as np
from skimage import measure
from shapely.geometry import Polygon, MultiPolygon
import json
import os


def create_sub_masks(mask_image):
    width, height = mask_image.size

    # Initialize a dictionary of sub-masks indexed by RGB colors
    sub_masks = {}
    for x in range(width):
        for y in range(height):
            # Get the RGB values of the pixel
            pixel = mask_image.getpixel((x, y))[:3]

            # If the pixel is not black...
            if pixel != (0, 0, 0):
                # Check to see if we've created a sub-mask...
                pixel_str = str(pixel)
                sub_mask = sub_masks.get(pixel_str)
                if sub_mask is None:
                   # Create a sub-mask (one bit per pixel) and add to the dictionary
                    # Note: we add 1 pixel of padding in each direction
                    # because the contours module doesn't handle cases
                    # where pixels bleed to the edge of the image
                    sub_masks[pixel_str] = Image.new('1', (width+2, height+2))

                # Set the pixel value to 1 (default is 0), accounting for padding
                sub_masks[pixel_str].putpixel((x+1, y+1), 1)

    return sub_masks


def create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd):
    # Find contours (boundary lines) around each sub-mask
    # Note: there could be multiple contours if the object
    # is partially occluded. (E.g. an elephant behind a tree)
    contours = measure.find_contours(np.array(sub_mask), 0.5, positive_orientation='low')

    segmentations = []
    polygons = []
    for contour in contours:
        # Flip from (row, col) representation to (x, y)
        # and subtract the padding pixel
        for i in range(len(contour)):
            row, col = contour[i]
            contour[i] = (col - 1, row - 1)

        # Make a polygon and simplify it
        poly = Polygon(contour)
        poly = poly.simplify(1.0, preserve_topology=False)
        polygons.append(poly)
        segmentation = np.array(poly.exterior.coords)
        segmentation = np.maximum(segmentation, 0).ravel().tolist()
        segmentations.append(segmentation)

    # Combine the polygons to calculate the bounding box and area
    multi_poly = MultiPolygon(polygons)
    if multi_poly.bounds == ():
        return "skip"
    x, y, max_x, max_y = multi_poly.bounds
    # x = max(0, x)
    # y = max(0, y)
    width = max_x - x
    height = max_y - y
    bbox = (x, y, width, height)
    area = multi_poly.area

    annotation = {
        'segmentation': segmentations,
        'iscrowd': is_crowd,
        'image_id': image_id,
        'category_id': category_id,
        'id': annotation_id,
        'bbox': bbox,
        'area': area
    }

    return annotation


def get_name(root, mode_folder=True):
    for root, dirs, file in os.walk(root):
        if mode_folder:
            return sorted(dirs)
        else:
            return sorted(file)


def get_annotation(mask_image_root):
    dataset = {"info": {"year": 2022, "version": "2022", "description": "Strawberry", "contributor": "Crespo", "url": "",
                        "date_created": "2022.01.29"},
               "license": {"id": 1, "url": "", "name": "Crespo"},
               "images": [],
               "annotations": [],
               "categories": []}
    class_index = {0: "strawberry"}
    for s, k in enumerate(list(class_index.keys())):
        dataset["categories"].append({"id": k, "name": class_index[k], "supercategory": "fruit"})

    is_crowd = 0

    # These ids will be automatically increased as we go
    annotation_id = 0
    image_id = 0

    # Create the annotations
    for i, root in enumerate(mask_image_root):
        try:
          #print(i)
          mask_image = Image.open(rrr + root)
          try:
            image_id = int(root.split(".")[0])
          except:
            image_id += 0
          mask_image  = mask_image.convert("RGB")
          #print(root)
          weight, height = mask_image.size
          file_name = root.split("/")[-1].split("_")[-1]
          #print(file_name)
          dataset["images"].append({"license": 1,
                                    "file_name": file_name,
                                    #"id": i,
                                    "id": image_id,
                                    "width": weight,
                                    "height": height})
          sub_masks = create_sub_masks(mask_image)
          for color, sub_mask in sub_masks.items():
              category_id = 0
              annotation = create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd)
              if annotation == "skip":
                  continue
              dataset["annotations"].append(annotation)
              annotation_id += 1
          #image_id += 1
        except:
          print(root)
          continue
    with open("test.json", "w") as f:
        json.dump(dataset, f)


rrr = "/content/dataset/test/label/"
all_root = get_name(rrr, mode_folder=False)
get_annotation(all_root)

# %% [markdown]
# ## Copy Jsons to Drive

# %%
# !cp train.json /content/gdrive/Shareddrives/Universidad/CV_strawberry_project/strawberry_detection_fruit/dataset/COCO_FORMAT_ANNOTATIONS
# !cp val.json /content/gdrive/Shareddrives/Universidad/CV_strawberry_project/strawberry_detection_fruit/dataset/COCO_FORMAT_ANNOTATIONS
# !cp test.json /content/gdrive/Shareddrives/Universidad/CV_strawberry_project/strawberry_detection_fruit/dataset/COCO_FORMAT_ANNOTATIONS

# %% [markdown]
# ## Visualize the masks from the COCO formar annotations.

# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = ['blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink', 'gold',
                       'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                       'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                       'magenta', 'sienna', 'maroon']

        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()

        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()

    def display_info(self):
        print('Dataset Info:')
        print('=============')
        if self.info is None:
            return
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))

        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

    def display_licenses(self):
        print('Licenses:')
        print('=========')

        if self.licenses is None:
            return
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(
                        req, str(req_type)))
            print('')
        print('')

    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(
                    cat_id, self.categories[cat_id]['name']))
            print('')

    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))

        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))

        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))

        else:
            # image_path = os.path.join(self.image_dir, image['file_name'])
            image_path = "{}/{}".format(self.image_dir, image['file_name'])
            image = PILImage.open(image_path)

        # Calculate the size and adjusted display size
        max_width = 600
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height

        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        bbox_categories = {}
        print('  segmentations ({}):'.format(
            len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(
                            trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height)
                                      * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})

                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1  # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(
                                    full_lines_to_insert * adjusted_ratio)
                                rle_list.append(
                                    {'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})

                            # Insert bottom line
                            rle_list.append(
                                {'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(
                        segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(
                        str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['id']] = self.colors[i]
            else:
                poly_colors[segm['id']] = 'white'

            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] +
                           bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(
                bbox_points).lstrip('[').rstrip(']')
            bbox_categories[segm['id']] = self.categories[segm['category_id']]
            # Print details
            print('    {}:{}:{}'.format(
                segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))

        # Draw segmentation polygons on image
        html = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(
            image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(
            adjusted_width, adjusted_height)

        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(
                        points, fill_color, stroke_color)

        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(
                        x, y, w, h, fill_color, stroke_color)

        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                x, y = [int(i) for i in points.split()[:2]]
                html += '<text x="{}" y="{}" fill="yellow">{}</text>'.format(
                    x, y, bbox_categories[seg_id]["name"])
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(
                    points, fill_color, stroke_color)

        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html

    def process_info(self):
        self.info = self.coco.get('info')

    def process_licenses(self):
        self.licenses = self.coco.get('licenses')

    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['id']
            super_category = category['supercategory']

            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                # Create a new set with the category id
                self.super_categories[super_category] = {cat_id}
            else:
                self.super_categories[super_category] |= {
                    cat_id}  # Add category id to the set

    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image

    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %% [markdown]
# ### See labels from train dataset

# %%
annotation_path = "/content/train.json"
image_dir = "/content/dataset/train/label"

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
#   year: 2022
#   version: 2022
#   description: Strawberry
#   contributor: Crespo
#   url:
#   date_created: 2022.01.29
#
# Licenses:
# =========
# Categories:
# =========
#   super_category: fruit
#     id 0: strawberry

# %%
for k, v in coco_dataset.images.items():
    print(k, v)
# Out:
# 1 {'license': 1, 'file_name': '1.png', 'id': 1, 'width': 1008, 'height': 756}
# 10 {'license': 1, 'file_name': '10.png', 'id': 10, 'width': 1008, 'height': 756}
# 100 {'license': 1, 'file_name': '100.png', 'id': 100, 'width': 1008, 'height': 756}
# 1000 {'license': 1, 'file_name': '1000.png', 'id': 1000, 'width': 1008, 'height': 756}
# 1001 {'license': 1, 'file_name': '1001.png', 'id': 1001, 'width': 1008, 'height': 756}
# 1003 {'license': 1, 'file_name': '1003.png', 'id': 1003, 'width': 1008, 'height': 756}
# 1004 {'license': 1, 'file_name': '1004.png', 'id': 1004, 'width': 1008, 'height': 756}
# 1005 {'license': 1, 'file_name': '1005.png', 'id': 1005, 'width': 1008, 'height': 756}
# 1006 {'license': 1, 'file_name': '1006.png', 'id': 1006, 'width': 1008, 'height': 756}
# 1007 {'license': 1, 'file_name': '1007.png', 'id': 1007, 'width': 1008, 'height': 756}
# 1008 {'license': 1, 'file_name': '1008.png', 'id': 1008, 'width': 1008, 'height': 756}
# 1009 {'license': 1, 'file_name': '1009.png', 'id': 1009, 'width': 1008, 'height': 756}
# 101 {'license': 1, 'file_name': '101.png', 'id': 101, 'width': 1008, 'height': 756}
# 1010 {'license': 1, 'file_name': '1010.png', 'id': 1010, 'width': 1008, 'height': 756}
# 1011 {'license': 1, 'file_name': '1011.png', 'id': 1011, 'width': 1008, 'height': 756}
# 1012 {'license': 1, 'file_name': '1012.png', 'id': 1012, 'width': 1008, 'height': 756}
# 1013 {'license': 1, 'file_name': '1013.png', 'id': 1013, 'width': 1008, 'height': 756}
# 1014 {'license': 1, 'file_name': '1014.png', 'id': 1014, 'width': 1008, 'height': 756}
# 1015 {'license': 1, 'file_name': '1015.png', 'id': 1015, 'width': 1008, 'height': 756}
# 1016 {'license': 1, 'file_name': '1016.png', 'id': 1016, 'width': 1008, 'height': 756}
# 1018 {'license': 1, 'file_name': '1018.png', 'id': 1018, 'width': 1008, 'height': 756}
# 1019 {'license': 1, 'file_name': '1019.png', 'id': 1019, 'width': 1008, 'height': 756}
# 102 {'license': 1, 'file_name': '102.png', 'id': 102, 'width': 1008, 'height': 756}
# 1020 {'license': 1, 'file_name': '1020.png', 'id': 1020, 'width': 1008, 'height': 756}
# 1021 {'license': 1, 'file_name': '1021.png', 'id': 1021, 'width': 1008, 'height': 756}
# 1022 {'license': 1, 'file_name': '1022.png', 'id': 1022, 'width': 1008, 'height': 756}
# 1023 {'license': 1, 'file_name': '1023.png', 'id': 1023, 'width': 1008, 'height': 756}
# 1024 {'license': 1, 'file_name': '1024.png', 'id': 1024, 'width': 1008, 'height': 756}
# 1025 {'license': 1, 'file_name': '1025.png', 'id': 1025, 'width': 1008, 'height': 756}
# 1027 {'license': 1, 'file_name': '1027.png', 'id': 1027, 'width': 1008, 'height': 756}
# 103 {'license': 1, 'file_name': '103.png', 'id': 103, 'width': 1008, 'height': 756}
# 1030 {'license': 1, 'file_name': '1030.png', 'id': 1030, 'width': 1008, 'height': 756}
# 1031 {'license': 1, 'file_name': '1031.png', 'id': 1031, 'width': 1008, 'height': 756}
# 1032 {'license': 1, 'file_name': '1032.png', 'id': 1032, 'width': 1008, 'height': 756}
# 1034 {'license': 1, 'file_name': '1034.png', 'id': 1034, 'width': 1008, 'height': 756}
# 1035 {'license': 1, 'file_name': '1035.png', 'id': 1035, 'width': 1008, 'height': 756}
# 1036 {'license': 1, 'file_name': '1036.png', 'id': 1036, 'width': 1008, 'height': 756}
# 1037 {'license': 1, 'file_name': '1037.png', 'id': 1037, 'width': 1008, 'height': 756}
# 1038 {'license': 1, 'file_name': '1038.png', 'id': 1038, 'width': 1008, 'height': 756}
# 1039 {'license': 1, 'file_name': '1039.png', 'id': 1039, 'width': 1008, 'height': 756}
# 104 {'license': 1, 'file_name': '104.png', 'id': 104, 'width': 1008, 'height': 756}
# 1040 {'license': 1, 'file_name': '1040.png', 'id': 1040, 'width': 1008, 'height': 756}
# 1041 {'license': 1, 'file_name': '1041.png', 'id': 1041, 'width': 1008, 'height': 756}
# 1042 {'license': 1, 'file_name': '1042.png', 'id': 1042, 'width': 1008, 'height': 756}
# 1043 {'license': 1, 'file_name': '1043.png', 'id': 1043, 'width': 1008, 'height': 756}
# 1044 {'license': 1, 'file_name': '1044.png', 'id': 1044, 'width': 1008, 'height': 756}
# 1045 {'license': 1, 'file_name': '1045.png', 'id': 1045, 'width': 1008, 'height': 756}
# 1046 {'license': 1, 'file_name': '1046.png', 'id': 1046, 'width': 1008, 'height': 756}
# 1047 {'license': 1, 'file_name': '1047.png', 'id': 1047, 'width': 1008, 'height': 756}
# 1048 {'license': 1, 'file_name': '1048.png', 'id': 1048, 'width': 1008, 'height': 756}
# 1049 {'license': 1, 'file_name': '1049.png', 'id': 1049, 'width': 1008, 'height': 756}
# 105 {'license': 1, 'file_name': '105.png', 'id': 105, 'width': 1008, 'height': 756}
# 1050 {'license': 1, 'file_name': '1050.png', 'id': 1050, 'width': 1008, 'height': 756}
# 1051 {'license': 1, 'file_name': '1051.png', 'id': 1051, 'width': 1008, 'height': 756}
# 1052 {'license': 1, 'file_name': '1052.png', 'id': 1052, 'width': 1008, 'height': 756}
# 1053 {'license': 1, 'file_name': '1053.png', 'id': 1053, 'width': 1008, 'height': 756}
# 1054 {'license': 1, 'file_name': '1054.png', 'id': 1054, 'width': 1008, 'height': 756}
# 1055 {'license': 1, 'file_name': '1055.png', 'id': 1055, 'width': 1008, 'height': 756}
# 1056 {'license': 1, 'file_name': '1056.png', 'id': 1056, 'width': 1008, 'height': 756}
# 1057 {'license': 1, 'file_name': '1057.png', 'id': 1057, 'width': 1008, 'height': 756}
# 1058 {'license': 1, 'file_name': '1058.png', 'id': 1058, 'width': 1008, 'height': 756}
# 1059 {'license': 1, 'file_name': '1059.png', 'id': 1059, 'width': 1008, 'height': 756}
# 106 {'license': 1, 'file_name': '106.png', 'id': 106, 'width': 1008, 'height': 756}
# 1060 {'license': 1, 'file_name': '1060.png', 'id': 1060, 'width': 1008, 'height': 756}
# 1061 {'license': 1, 'file_name': '1061.png', 'id': 1061, 'width': 1008, 'height': 756}
# 1062 {'license': 1, 'file_name': '1062.png', 'id': 1062, 'width': 1008, 'height': 756}
# 1063 {'license': 1, 'file_name': '1063.png', 'id': 1063, 'width': 1008, 'height': 756}
# 1064 {'license': 1, 'file_name': '1064.png', 'id': 1064, 'width': 1008, 'height': 756}
# 1065 {'license': 1, 'file_name': '1065.png', 'id': 1065, 'width': 1008, 'height': 756}
# 1066 {'license': 1, 'file_name': '1066.png', 'id': 1066, 'width': 1008, 'height': 756}
# 1067 {'license': 1, 'file_name': '1067.png', 'id': 1067, 'width': 1008, 'height': 756}
# 1068 {'license': 1, 'file_name': '1068.png', 'id': 1068, 'width': 1008, 'height': 756}
# 1069 {'license': 1, 'file_name': '1069.png', 'id': 1069, 'width': 1008, 'height': 756}
# 107 {'license': 1, 'file_name': '107.png', 'id': 107, 'width': 1008, 'height': 756}
# 1070 {'license': 1, 'file_name': '1070.png', 'id': 1070, 'width': 1008, 'height': 756}
# 1071 {'license': 1, 'file_name': '1071.png', 'id': 1071, 'width': 1008, 'height': 756}
# 1072 {'license': 1, 'file_name': '1072.png', 'id': 1072, 'width': 1008, 'height': 756}
# 1073 {'license': 1, 'file_name': '1073.png', 'id': 1073, 'width': 1008, 'height': 756}
# 1074 {'license': 1, 'file_name': '1074.png', 'id': 1074, 'width': 1008, 'height': 756}
# 1075 {'license': 1, 'file_name': '1075.png', 'id': 1075, 'width': 1008, 'height': 756}
# 1076 {'license': 1, 'file_name': '1076.png', 'id': 1076, 'width': 1008, 'height': 756}
# 1077 {'license': 1, 'file_name': '1077.png', 'id': 1077, 'width': 1008, 'height': 756}
# 1078 {'license': 1, 'file_name': '1078.png', 'id': 1078, 'width': 1008, 'height': 756}
# 1079 {'license': 1, 'file_name': '1079.png', 'id': 1079, 'width': 1008, 'height': 756}
# 1081 {'license': 1, 'file_name': '1081.png', 'id': 1081, 'width': 1008, 'height': 756}
# 1082 {'license': 1, 'file_name': '1082.png', 'id': 1082, 'width': 1008, 'height': 756}
# 1083 {'license': 1, 'file_name': '1083.png', 'id': 1083, 'width': 1008, 'height': 756}
# 1084 {'license': 1, 'file_name': '1084.png', 'id': 1084, 'width': 1008, 'height': 756}
# 1085 {'license': 1, 'file_name': '1085.png', 'id': 1085, 'width': 1008, 'height': 756}
# 1086 {'license': 1, 'file_name': '1086.png', 'id': 1086, 'width': 1008, 'height': 756}
# 1088 {'license': 1, 'file_name': '1088.png', 'id': 1088, 'width': 1008, 'height': 756}
# 1089 {'license': 1, 'file_name': '1089.png', 'id': 1089, 'width': 1008, 'height': 756}
# 109 {'license': 1, 'file_name': '109.png', 'id': 109, 'width': 1008, 'height': 756}
# 1090 {'license': 1, 'file_name': '1090.png', 'id': 1090, 'width': 1008, 'height': 756}
# 1091 {'license': 1, 'file_name': '1091.png', 'id': 1091, 'width': 1008, 'height': 756}
# 1092 {'license': 1, 'file_name': '1092.png', 'id': 1092, 'width': 1008, 'height': 756}
# 1093 {'license': 1, 'file_name': '1093.png', 'id': 1093, 'width': 1008, 'height': 756}
# 1094 {'license': 1, 'file_name': '1094.png', 'id': 1094, 'width': 1008, 'height': 756}
# 1095 {'license': 1, 'file_name': '1095.png', 'id': 1095, 'width': 1008, 'height': 756}
# 1096 {'license': 1, 'file_name': '1096.png', 'id': 1096, 'width': 1008, 'height': 756}
# 1097 {'license': 1, 'file_name': '1097.png', 'id': 1097, 'width': 1008, 'height': 756}
# 1098 {'license': 1, 'file_name': '1098.png', 'id': 1098, 'width': 1008, 'height': 756}
# 11 {'license': 1, 'file_name': '11.png', 'id': 11, 'width': 1008, 'height': 756}
# 110 {'license': 1, 'file_name': '110.png', 'id': 110, 'width': 1008, 'height': 756}
# 1100 {'license': 1, 'file_name': '1100.png', 'id': 1100, 'width': 1008, 'height': 756}
# 1101 {'license': 1, 'file_name': '1101.png', 'id': 1101, 'width': 1008, 'height': 756}
# 1102 {'license': 1, 'file_name': '1102.png', 'id': 1102, 'width': 1008, 'height': 756}
# 1103 {'license': 1, 'file_name': '1103.png', 'id': 1103, 'width': 1008, 'height': 756}
# 1105 {'license': 1, 'file_name': '1105.png', 'id': 1105, 'width': 1008, 'height': 756}
# 1106 {'license': 1, 'file_name': '1106.png', 'id': 1106, 'width': 1008, 'height': 756}
# 1107 {'license': 1, 'file_name': '1107.png', 'id': 1107, 'width': 1008, 'height': 756}
# 111 {'license': 1, 'file_name': '111.png', 'id': 111, 'width': 1008, 'height': 756}
# 1110 {'license': 1, 'file_name': '1110.png', 'id': 1110, 'width': 1008, 'height': 756}
# 1111 {'license': 1, 'file_name': '1111.png', 'id': 1111, 'width': 1008, 'height': 756}
# 1113 {'license': 1, 'file_name': '1113.png', 'id': 1113, 'width': 1008, 'height': 756}
# 1114 {'license': 1, 'file_name': '1114.png', 'id': 1114, 'width': 1008, 'height': 756}
# 1115 {'license': 1, 'file_name': '1115.png', 'id': 1115, 'width': 1008, 'height': 756}
# 1116 {'license': 1, 'file_name': '1116.png', 'id': 1116, 'width': 1008, 'height': 756}
# 1117 {'license': 1, 'file_name': '1117.png', 'id': 1117, 'width': 1008, 'height': 756}
# 1118 {'license': 1, 'file_name': '1118.png', 'id': 1118, 'width': 1008, 'height': 756}
# 1119 {'license': 1, 'file_name': '1119.png', 'id': 1119, 'width': 1008, 'height': 756}
# 112 {'license': 1, 'file_name': '112.png', 'id': 112, 'width': 1008, 'height': 756}
# 1120 {'license': 1, 'file_name': '1120.png', 'id': 1120, 'width': 1008, 'height': 756}
# 1121 {'license': 1, 'file_name': '1121.png', 'id': 1121, 'width': 1008, 'height': 756}
# 1122 {'license': 1, 'file_name': '1122.png', 'id': 1122, 'width': 1008, 'height': 756}
# 1123 {'license': 1, 'file_name': '1123.png', 'id': 1123, 'width': 1008, 'height': 756}
# 1124 {'license': 1, 'file_name': '1124.png', 'id': 1124, 'width': 1008, 'height': 756}
# 1125 {'license': 1, 'file_name': '1125.png', 'id': 1125, 'width': 1008, 'height': 756}
# 1126 {'license': 1, 'file_name': '1126.png', 'id': 1126, 'width': 1008, 'height': 756}
# 1127 {'license': 1, 'file_name': '1127.png', 'id': 1127, 'width': 1008, 'height': 756}
# 1128 {'license': 1, 'file_name': '1128.png', 'id': 1128, 'width': 1008, 'height': 756}
# 1129 {'license': 1, 'file_name': '1129.png', 'id': 1129, 'width': 1008, 'height': 756}
# 1130 {'license': 1, 'file_name': '1130.png', 'id': 1130, 'width': 1008, 'height': 756}
# 1131 {'license': 1, 'file_name': '1131.png', 'id': 1131, 'width': 1008, 'height': 756}
# 1132 {'license': 1, 'file_name': '1132.png', 'id': 1132, 'width': 1008, 'height': 756}
# 1133 {'license': 1, 'file_name': '1133.png', 'id': 1133, 'width': 1008, 'height': 756}
# 1134 {'license': 1, 'file_name': '1134.png', 'id': 1134, 'width': 1008, 'height': 756}
# 1136 {'license': 1, 'file_name': '1136.png', 'id': 1136, 'width': 1008, 'height': 756}
# 1137 {'license': 1, 'file_name': '1137.png', 'id': 1137, 'width': 1008, 'height': 756}
# 1138 {'license': 1, 'file_name': '1138.png', 'id': 1138, 'width': 1008, 'height': 756}
# 1139 {'license': 1, 'file_name': '1139.png', 'id': 1139, 'width': 1008, 'height': 756}
# 114 {'license': 1, 'file_name': '114.png', 'id': 114, 'width': 1008, 'height': 756}
# 1140 {'license': 1, 'file_name': '1140.png', 'id': 1140, 'width': 1008, 'height': 756}
# 1141 {'license': 1, 'file_name': '1141.png', 'id': 1141, 'width': 1008, 'height': 756}
# 1142 {'license': 1, 'file_name': '1142.png', 'id': 1142, 'width': 1008, 'height': 756}
# 1143 {'license': 1, 'file_name': '1143.png', 'id': 1143, 'width': 1008, 'height': 756}
# 1144 {'license': 1, 'file_name': '1144.png', 'id': 1144, 'width': 1008, 'height': 756}
# 1145 {'license': 1, 'file_name': '1145.png', 'id': 1145, 'width': 1008, 'height': 756}
# 1146 {'license': 1, 'file_name': '1146.png', 'id': 1146, 'width': 1008, 'height': 756}
# 1148 {'license': 1, 'file_name': '1148.png', 'id': 1148, 'width': 1008, 'height': 756}
# 1149 {'license': 1, 'file_name': '1149.png', 'id': 1149, 'width': 1008, 'height': 756}
# 115 {'license': 1, 'file_name': '115.png', 'id': 115, 'width': 1008, 'height': 756}
# 1150 {'license': 1, 'file_name': '1150.png', 'id': 1150, 'width': 1008, 'height': 756}
# 1152 {'license': 1, 'file_name': '1152.png', 'id': 1152, 'width': 1008, 'height': 756}
# 1153 {'license': 1, 'file_name': '1153.png', 'id': 1153, 'width': 1008, 'height': 756}
# 1154 {'license': 1, 'file_name': '1154.png', 'id': 1154, 'width': 1008, 'height': 756}
# 1157 {'license': 1, 'file_name': '1157.png', 'id': 1157, 'width': 1008, 'height': 756}
# 1158 {'license': 1, 'file_name': '1158.png', 'id': 1158, 'width': 1008, 'height': 756}
# 1159 {'license': 1, 'file_name': '1159.png', 'id': 1159, 'width': 1008, 'height': 756}
# 116 {'license': 1, 'file_name': '116.png', 'id': 116, 'width': 1008, 'height': 756}
# 1160 {'license': 1, 'file_name': '1160.png', 'id': 1160, 'width': 1008, 'height': 756}
# 1161 {'license': 1, 'file_name': '1161.png', 'id': 1161, 'width': 1008, 'height': 756}
# 1162 {'license': 1, 'file_name': '1162.png', 'id': 1162, 'width': 1008, 'height': 756}
# 1163 {'license': 1, 'file_name': '1163.png', 'id': 1163, 'width': 1008, 'height': 756}
# 1164 {'license': 1, 'file_name': '1164.png', 'id': 1164, 'width': 1008, 'height': 756}
# 1165 {'license': 1, 'file_name': '1165.png', 'id': 1165, 'width': 1008, 'height': 756}
# 1166 {'license': 1, 'file_name': '1166.png', 'id': 1166, 'width': 1008, 'height': 756}
# 1167 {'license': 1, 'file_name': '1167.png', 'id': 1167, 'width': 1008, 'height': 756}
# 1168 {'license': 1, 'file_name': '1168.png', 'id': 1168, 'width': 1008, 'height': 756}
# 1169 {'license': 1, 'file_name': '1169.png', 'id': 1169, 'width': 1008, 'height': 756}
# 1170 {'license': 1, 'file_name': '1170.png', 'id': 1170, 'width': 1008, 'height': 756}
# 1171 {'license': 1, 'file_name': '1171.png', 'id': 1171, 'width': 1008, 'height': 756}
# 1172 {'license': 1, 'file_name': '1172.png', 'id': 1172, 'width': 1008, 'height': 756}
# 1173 {'license': 1, 'file_name': '1173.png', 'id': 1173, 'width': 1008, 'height': 756}
# 1174 {'license': 1, 'file_name': '1174.png', 'id': 1174, 'width': 1008, 'height': 756}
# 1175 {'license': 1, 'file_name': '1175.png', 'id': 1175, 'width': 1008, 'height': 756}
# 1176 {'license': 1, 'file_name': '1176.png', 'id': 1176, 'width': 1008, 'height': 756}
# 1177 {'license': 1, 'file_name': '1177.png', 'id': 1177, 'width': 1008, 'height': 756}
# 1178 {'license': 1, 'file_name': '1178.png', 'id': 1178, 'width': 1008, 'height': 756}
# 1179 {'license': 1, 'file_name': '1179.png', 'id': 1179, 'width': 1008, 'height': 756}
# 118 {'license': 1, 'file_name': '118.png', 'id': 118, 'width': 1008, 'height': 756}
# 1180 {'license': 1, 'file_name': '1180.png', 'id': 1180, 'width': 1008, 'height': 756}
# 1181 {'license': 1, 'file_name': '1181.png', 'id': 1181, 'width': 1008, 'height': 756}
# 1182 {'license': 1, 'file_name': '1182.png', 'id': 1182, 'width': 1008, 'height': 756}
# 1183 {'license': 1, 'file_name': '1183.png', 'id': 1183, 'width': 1008, 'height': 756}
# 1184 {'license': 1, 'file_name': '1184.png', 'id': 1184, 'width': 1008, 'height': 756}
# 1185 {'license': 1, 'file_name': '1185.png', 'id': 1185, 'width': 1008, 'height': 756}
# 1186 {'license': 1, 'file_name': '1186.png', 'id': 1186, 'width': 1008, 'height': 756}
# 1187 {'license': 1, 'file_name': '1187.png', 'id': 1187, 'width': 1008, 'height': 756}
# 1188 {'license': 1, 'file_name': '1188.png', 'id': 1188, 'width': 1008, 'height': 756}
# 1189 {'license': 1, 'file_name': '1189.png', 'id': 1189, 'width': 1008, 'height': 756}
# 119 {'license': 1, 'file_name': '119.png', 'id': 119, 'width': 1008, 'height': 756}
# 1190 {'license': 1, 'file_name': '1190.png', 'id': 1190, 'width': 1008, 'height': 756}
# 1191 {'license': 1, 'file_name': '1191.png', 'id': 1191, 'width': 1008, 'height': 756}
# 1192 {'license': 1, 'file_name': '1192.png', 'id': 1192, 'width': 1008, 'height': 756}
# 1193 {'license': 1, 'file_name': '1193.png', 'id': 1193, 'width': 1008, 'height': 756}
# 1194 {'license': 1, 'file_name': '1194.png', 'id': 1194, 'width': 1008, 'height': 756}
# 1195 {'license': 1, 'file_name': '1195.png', 'id': 1195, 'width': 1008, 'height': 756}
# 1196 {'license': 1, 'file_name': '1196.png', 'id': 1196, 'width': 1008, 'height': 756}
# 1197 {'license': 1, 'file_name': '1197.png', 'id': 1197, 'width': 1008, 'height': 756}
# 1198 {'license': 1, 'file_name': '1198.png', 'id': 1198, 'width': 1008, 'height': 756}
# 1199 {'license': 1, 'file_name': '1199.png', 'id': 1199, 'width': 1008, 'height': 756}
# 12 {'license': 1, 'file_name': '12.png', 'id': 12, 'width': 1008, 'height': 756}
# 120 {'license': 1, 'file_name': '120.png', 'id': 120, 'width': 1008, 'height': 756}
# 1200 {'license': 1, 'file_name': '1200.png', 'id': 1200, 'width': 1008, 'height': 756}
# 1201 {'license': 1, 'file_name': '1201.png', 'id': 1201, 'width': 1008, 'height': 756}
# 1202 {'license': 1, 'file_name': '1202.png', 'id': 1202, 'width': 1008, 'height': 756}
# 1203 {'license': 1, 'file_name': '1203.png', 'id': 1203, 'width': 1008, 'height': 756}
# 1204 {'license': 1, 'file_name': '1204.png', 'id': 1204, 'width': 1008, 'height': 756}
# 1205 {'license': 1, 'file_name': '1205.png', 'id': 1205, 'width': 1008, 'height': 756}
# 1206 {'license': 1, 'file_name': '1206.png', 'id': 1206, 'width': 1008, 'height': 756}
# 1207 {'license': 1, 'file_name': '1207.png', 'id': 1207, 'width': 1008, 'height': 756}
# 1208 {'license': 1, 'file_name': '1208.png', 'id': 1208, 'width': 1008, 'height': 756}
# 1209 {'license': 1, 'file_name': '1209.png', 'id': 1209, 'width': 1008, 'height': 756}
# 121 {'license': 1, 'file_name': '121.png', 'id': 121, 'width': 1008, 'height': 756}
# 1210 {'license': 1, 'file_name': '1210.png', 'id': 1210, 'width': 1008, 'height': 756}
# 1211 {'license': 1, 'file_name': '1211.png', 'id': 1211, 'width': 1008, 'height': 756}
# 1212 {'license': 1, 'file_name': '1212.png', 'id': 1212, 'width': 1008, 'height': 756}
# 1213 {'license': 1, 'file_name': '1213.png', 'id': 1213, 'width': 1008, 'height': 756}
# 1214 {'license': 1, 'file_name': '1214.png', 'id': 1214, 'width': 1008, 'height': 756}
# 1216 {'license': 1, 'file_name': '1216.png', 'id': 1216, 'width': 1008, 'height': 756}
# 1217 {'license': 1, 'file_name': '1217.png', 'id': 1217, 'width': 1008, 'height': 756}
# 1219 {'license': 1, 'file_name': '1219.png', 'id': 1219, 'width': 1008, 'height': 756}
# 122 {'license': 1, 'file_name': '122.png', 'id': 122, 'width': 1008, 'height': 756}
# 1220 {'license': 1, 'file_name': '1220.png', 'id': 1220, 'width': 1008, 'height': 756}
# 1221 {'license': 1, 'file_name': '1221.png', 'id': 1221, 'width': 1008, 'height': 756}
# 1222 {'license': 1, 'file_name': '1222.png', 'id': 1222, 'width': 1008, 'height': 756}
# 1223 {'license': 1, 'file_name': '1223.png', 'id': 1223, 'width': 1008, 'height': 756}
# 1224 {'license': 1, 'file_name': '1224.png', 'id': 1224, 'width': 1008, 'height': 756}
# 1225 {'license': 1, 'file_name': '1225.png', 'id': 1225, 'width': 1008, 'height': 756}
# 1226 {'license': 1, 'file_name': '1226.png', 'id': 1226, 'width': 1008, 'height': 756}
# 1227 {'license': 1, 'file_name': '1227.png', 'id': 1227, 'width': 1008, 'height': 756}
# 1228 {'license': 1, 'file_name': '1228.png', 'id': 1228, 'width': 1008, 'height': 756}
# 1229 {'license': 1, 'file_name': '1229.png', 'id': 1229, 'width': 1008, 'height': 756}
# 123 {'license': 1, 'file_name': '123.png', 'id': 123, 'width': 1008, 'height': 756}
# 1230 {'license': 1, 'file_name': '1230.png', 'id': 1230, 'width': 1008, 'height': 756}
# 1231 {'license': 1, 'file_name': '1231.png', 'id': 1231, 'width': 1008, 'height': 756}
# 1232 {'license': 1, 'file_name': '1232.png', 'id': 1232, 'width': 1008, 'height': 756}
# 1234 {'license': 1, 'file_name': '1234.png', 'id': 1234, 'width': 1008, 'height': 756}
# 1235 {'license': 1, 'file_name': '1235.png', 'id': 1235, 'width': 1008, 'height': 756}
# 1236 {'license': 1, 'file_name': '1236.png', 'id': 1236, 'width': 1008, 'height': 756}
# 1237 {'license': 1, 'file_name': '1237.png', 'id': 1237, 'width': 1008, 'height': 756}
# 1238 {'license': 1, 'file_name': '1238.png', 'id': 1238, 'width': 1008, 'height': 756}
# 1239 {'license': 1, 'file_name': '1239.png', 'id': 1239, 'width': 1008, 'height': 756}
# 124 {'license': 1, 'file_name': '124.png', 'id': 124, 'width': 1008, 'height': 756}
# 1240 {'license': 1, 'file_name': '1240.png', 'id': 1240, 'width': 1008, 'height': 756}
# 1241 {'license': 1, 'file_name': '1241.png', 'id': 1241, 'width': 1008, 'height': 756}
# 1242 {'license': 1, 'file_name': '1242.png', 'id': 1242, 'width': 1008, 'height': 756}
# 1243 {'license': 1, 'file_name': '1243.png', 'id': 1243, 'width': 1008, 'height': 756}
# 1244 {'license': 1, 'file_name': '1244.png', 'id': 1244, 'width': 1008, 'height': 756}
# 1245 {'license': 1, 'file_name': '1245.png', 'id': 1245, 'width': 1008, 'height': 756}
# 1246 {'license': 1, 'file_name': '1246.png', 'id': 1246, 'width': 1008, 'height': 756}
# 1247 {'license': 1, 'file_name': '1247.png', 'id': 1247, 'width': 1008, 'height': 756}
# 1248 {'license': 1, 'file_name': '1248.png', 'id': 1248, 'width': 1008, 'height': 756}
# 1249 {'license': 1, 'file_name': '1249.png', 'id': 1249, 'width': 1008, 'height': 756}
# 125 {'license': 1, 'file_name': '125.png', 'id': 125, 'width': 1008, 'height': 756}
# 1250 {'license': 1, 'file_name': '1250.png', 'id': 1250, 'width': 1008, 'height': 756}
# 1252 {'license': 1, 'file_name': '1252.png', 'id': 1252, 'width': 1008, 'height': 756}
# 1253 {'license': 1, 'file_name': '1253.png', 'id': 1253, 'width': 1008, 'height': 756}
# 1254 {'license': 1, 'file_name': '1254.png', 'id': 1254, 'width': 1008, 'height': 756}
# 1255 {'license': 1, 'file_name': '1255.png', 'id': 1255, 'width': 1008, 'height': 756}
# 1256 {'license': 1, 'file_name': '1256.png', 'id': 1256, 'width': 1008, 'height': 756}
# 1257 {'license': 1, 'file_name': '1257.png', 'id': 1257, 'width': 1008, 'height': 756}
# 1258 {'license': 1, 'file_name': '1258.png', 'id': 1258, 'width': 1008, 'height': 756}
# 1259 {'license': 1, 'file_name': '1259.png', 'id': 1259, 'width': 1008, 'height': 756}
# 126 {'license': 1, 'file_name': '126.png', 'id': 126, 'width': 1008, 'height': 756}
# 1260 {'license': 1, 'file_name': '1260.png', 'id': 1260, 'width': 1008, 'height': 756}
# 1261 {'license': 1, 'file_name': '1261.png', 'id': 1261, 'width': 1008, 'height': 756}
# 1262 {'license': 1, 'file_name': '1262.png', 'id': 1262, 'width': 1008, 'height': 756}
# 1264 {'license': 1, 'file_name': '1264.png', 'id': 1264, 'width': 1008, 'height': 756}
# 1265 {'license': 1, 'file_name': '1265.png', 'id': 1265, 'width': 1008, 'height': 756}
# 1266 {'license': 1, 'file_name': '1266.png', 'id': 1266, 'width': 1008, 'height': 756}
# 1267 {'license': 1, 'file_name': '1267.png', 'id': 1267, 'width': 1008, 'height': 756}
# 1268 {'license': 1, 'file_name': '1268.png', 'id': 1268, 'width': 1008, 'height': 756}
# 1269 {'license': 1, 'file_name': '1269.png', 'id': 1269, 'width': 1008, 'height': 756}
# 1270 {'license': 1, 'file_name': '1270.png', 'id': 1270, 'width': 1008, 'height': 756}
# 1273 {'license': 1, 'file_name': '1273.png', 'id': 1273, 'width': 1008, 'height': 756}
# 1275 {'license': 1, 'file_name': '1275.png', 'id': 1275, 'width': 1008, 'height': 756}
# 1276 {'license': 1, 'file_name': '1276.png', 'id': 1276, 'width': 1008, 'height': 756}
# 1277 {'license': 1, 'file_name': '1277.png', 'id': 1277, 'width': 1008, 'height': 756}
# 1278 {'license': 1, 'file_name': '1278.png', 'id': 1278, 'width': 1008, 'height': 756}
# 1279 {'license': 1, 'file_name': '1279.png', 'id': 1279, 'width': 1008, 'height': 756}
# 128 {'license': 1, 'file_name': '128.png', 'id': 128, 'width': 1008, 'height': 756}
# 1280 {'license': 1, 'file_name': '1280.png', 'id': 1280, 'width': 1008, 'height': 756}
# 1281 {'license': 1, 'file_name': '1281.png', 'id': 1281, 'width': 1008, 'height': 756}
# 1282 {'license': 1, 'file_name': '1282.png', 'id': 1282, 'width': 1008, 'height': 756}
# 1283 {'license': 1, 'file_name': '1283.png', 'id': 1283, 'width': 1008, 'height': 756}
# 1284 {'license': 1, 'file_name': '1284.png', 'id': 1284, 'width': 1008, 'height': 756}
# 1285 {'license': 1, 'file_name': '1285.png', 'id': 1285, 'width': 1008, 'height': 756}
# 1287 {'license': 1, 'file_name': '1287.png', 'id': 1287, 'width': 1008, 'height': 756}
# 1288 {'license': 1, 'file_name': '1288.png', 'id': 1288, 'width': 1008, 'height': 756}
# 1289 {'license': 1, 'file_name': '1289.png', 'id': 1289, 'width': 1008, 'height': 756}
# 129 {'license': 1, 'file_name': '129.png', 'id': 129, 'width': 1008, 'height': 756}
# 1290 {'license': 1, 'file_name': '1290.png', 'id': 1290, 'width': 1008, 'height': 756}
# 1292 {'license': 1, 'file_name': '1292.png', 'id': 1292, 'width': 1008, 'height': 756}
# 1293 {'license': 1, 'file_name': '1293.png', 'id': 1293, 'width': 1008, 'height': 756}
# 1294 {'license': 1, 'file_name': '1294.png', 'id': 1294, 'width': 1008, 'height': 756}
# 1295 {'license': 1, 'file_name': '1295.png', 'id': 1295, 'width': 1008, 'height': 756}
# 1296 {'license': 1, 'file_name': '1296.png', 'id': 1296, 'width': 1008, 'height': 756}
# 1297 {'license': 1, 'file_name': '1297.png', 'id': 1297, 'width': 1008, 'height': 756}
# 1298 {'license': 1, 'file_name': '1298.png', 'id': 1298, 'width': 1008, 'height': 756}
# 13 {'license': 1, 'file_name': '13.png', 'id': 13, 'width': 1008, 'height': 756}
# 130 {'license': 1, 'file_name': '130.png', 'id': 130, 'width': 1008, 'height': 756}
# 1300 {'license': 1, 'file_name': '1300.png', 'id': 1300, 'width': 1008, 'height': 756}
# 1301 {'license': 1, 'file_name': '1301.png', 'id': 1301, 'width': 1008, 'height': 756}
# 1302 {'license': 1, 'file_name': '1302.png', 'id': 1302, 'width': 1008, 'height': 756}
# 1303 {'license': 1, 'file_name': '1303.png', 'id': 1303, 'width': 1008, 'height': 756}
# 1304 {'license': 1, 'file_name': '1304.png', 'id': 1304, 'width': 1008, 'height': 756}
# 1305 {'license': 1, 'file_name': '1305.png', 'id': 1305, 'width': 1008, 'height': 756}
# 1306 {'license': 1, 'file_name': '1306.png', 'id': 1306, 'width': 1008, 'height': 756}
# 1308 {'license': 1, 'file_name': '1308.png', 'id': 1308, 'width': 1008, 'height': 756}
# 1309 {'license': 1, 'file_name': '1309.png', 'id': 1309, 'width': 1008, 'height': 756}
# 131 {'license': 1, 'file_name': '131.png', 'id': 131, 'width': 1008, 'height': 756}
# 1310 {'license': 1, 'file_name': '1310.png', 'id': 1310, 'width': 1008, 'height': 756}
# 1311 {'license': 1, 'file_name': '1311.png', 'id': 1311, 'width': 1008, 'height': 756}
# 1312 {'license': 1, 'file_name': '1312.png', 'id': 1312, 'width': 1008, 'height': 756}
# 1313 {'license': 1, 'file_name': '1313.png', 'id': 1313, 'width': 1008, 'height': 756}
# 1314 {'license': 1, 'file_name': '1314.png', 'id': 1314, 'width': 1008, 'height': 756}
# 1315 {'license': 1, 'file_name': '1315.png', 'id': 1315, 'width': 1008, 'height': 756}
# 1316 {'license': 1, 'file_name': '1316.png', 'id': 1316, 'width': 1008, 'height': 756}
# 1317 {'license': 1, 'file_name': '1317.png', 'id': 1317, 'width': 1008, 'height': 756}
# 1318 {'license': 1, 'file_name': '1318.png', 'id': 1318, 'width': 1008, 'height': 756}
# 1319 {'license': 1, 'file_name': '1319.png', 'id': 1319, 'width': 1008, 'height': 756}
# 132 {'license': 1, 'file_name': '132.png', 'id': 132, 'width': 1008, 'height': 756}
# 1320 {'license': 1, 'file_name': '1320.png', 'id': 1320, 'width': 1008, 'height': 756}
# 1321 {'license': 1, 'file_name': '1321.png', 'id': 1321, 'width': 1008, 'height': 756}
# 1322 {'license': 1, 'file_name': '1322.png', 'id': 1322, 'width': 1008, 'height': 756}
# 1324 {'license': 1, 'file_name': '1324.png', 'id': 1324, 'width': 1008, 'height': 756}
# 1325 {'license': 1, 'file_name': '1325.png', 'id': 1325, 'width': 1008, 'height': 756}
# 1326 {'license': 1, 'file_name': '1326.png', 'id': 1326, 'width': 1008, 'height': 756}
# 1327 {'license': 1, 'file_name': '1327.png', 'id': 1327, 'width': 1008, 'height': 756}
# 1328 {'license': 1, 'file_name': '1328.png', 'id': 1328, 'width': 1008, 'height': 756}
# 1329 {'license': 1, 'file_name': '1329.png', 'id': 1329, 'width': 1008, 'height': 756}
# 133 {'license': 1, 'file_name': '133.png', 'id': 133, 'width': 1008, 'height': 756}
# 1330 {'license': 1, 'file_name': '1330.png', 'id': 1330, 'width': 1008, 'height': 756}
# 1331 {'license': 1, 'file_name': '1331.png', 'id': 1331, 'width': 1008, 'height': 756}
# 1332 {'license': 1, 'file_name': '1332.png', 'id': 1332, 'width': 1008, 'height': 756}
# 1333 {'license': 1, 'file_name': '1333.png', 'id': 1333, 'width': 1008, 'height': 756}
# 1334 {'license': 1, 'file_name': '1334.png', 'id': 1334, 'width': 1008, 'height': 756}
# 1335 {'license': 1, 'file_name': '1335.png', 'id': 1335, 'width': 1008, 'height': 756}
# 1336 {'license': 1, 'file_name': '1336.png', 'id': 1336, 'width': 1008, 'height': 756}
# 1337 {'license': 1, 'file_name': '1337.png', 'id': 1337, 'width': 1008, 'height': 756}
# 1338 {'license': 1, 'file_name': '1338.png', 'id': 1338, 'width': 1008, 'height': 756}
# 1339 {'license': 1, 'file_name': '1339.png', 'id': 1339, 'width': 1008, 'height': 756}
# 134 {'license': 1, 'file_name': '134.png', 'id': 134, 'width': 1008, 'height': 756}
# 1340 {'license': 1, 'file_name': '1340.png', 'id': 1340, 'width': 1008, 'height': 756}
# 1341 {'license': 1, 'file_name': '1341.png', 'id': 1341, 'width': 1008, 'height': 756}
# 1342 {'license': 1, 'file_name': '1342.png', 'id': 1342, 'width': 1008, 'height': 756}
# 1343 {'license': 1, 'file_name': '1343.png', 'id': 1343, 'width': 1008, 'height': 756}
# 1344 {'license': 1, 'file_name': '1344.png', 'id': 1344, 'width': 1008, 'height': 756}
# 1345 {'license': 1, 'file_name': '1345.png', 'id': 1345, 'width': 1008, 'height': 756}
# 1346 {'license': 1, 'file_name': '1346.png', 'id': 1346, 'width': 1008, 'height': 756}
# 1347 {'license': 1, 'file_name': '1347.png', 'id': 1347, 'width': 1008, 'height': 756}
# 1348 {'license': 1, 'file_name': '1348.png', 'id': 1348, 'width': 1008, 'height': 756}
# 1349 {'license': 1, 'file_name': '1349.png', 'id': 1349, 'width': 1008, 'height': 756}
# 135 {'license': 1, 'file_name': '135.png', 'id': 135, 'width': 1008, 'height': 756}
# 1350 {'license': 1, 'file_name': '1350.png', 'id': 1350, 'width': 1008, 'height': 756}
# 1351 {'license': 1, 'file_name': '1351.png', 'id': 1351, 'width': 1008, 'height': 756}
# 1352 {'license': 1, 'file_name': '1352.png', 'id': 1352, 'width': 1008, 'height': 756}
# 1353 {'license': 1, 'file_name': '1353.png', 'id': 1353, 'width': 1008, 'height': 756}
# 1354 {'license': 1, 'file_name': '1354.png', 'id': 1354, 'width': 1008, 'height': 756}
# 1356 {'license': 1, 'file_name': '1356.png', 'id': 1356, 'width': 1008, 'height': 756}
# 1357 {'license': 1, 'file_name': '1357.png', 'id': 1357, 'width': 1008, 'height': 756}
# 1358 {'license': 1, 'file_name': '1358.png', 'id': 1358, 'width': 1008, 'height': 756}
# 1359 {'license': 1, 'file_name': '1359.png', 'id': 1359, 'width': 1008, 'height': 756}
# 136 {'license': 1, 'file_name': '136.png', 'id': 136, 'width': 1008, 'height': 756}
# 1361 {'license': 1, 'file_name': '1361.png', 'id': 1361, 'width': 1008, 'height': 756}
# 1362 {'license': 1, 'file_name': '1362.png', 'id': 1362, 'width': 1008, 'height': 756}
# 1363 {'license': 1, 'file_name': '1363.png', 'id': 1363, 'width': 1008, 'height': 756}
# 1364 {'license': 1, 'file_name': '1364.png', 'id': 1364, 'width': 1008, 'height': 756}
# 1365 {'license': 1, 'file_name': '1365.png', 'id': 1365, 'width': 1008, 'height': 756}
# 1368 {'license': 1, 'file_name': '1368.png', 'id': 1368, 'width': 1008, 'height': 756}
# 1369 {'license': 1, 'file_name': '1369.png', 'id': 1369, 'width': 1008, 'height': 756}
# 137 {'license': 1, 'file_name': '137.png', 'id': 137, 'width': 1008, 'height': 756}
# 1370 {'license': 1, 'file_name': '1370.png', 'id': 1370, 'width': 1008, 'height': 756}
# 1371 {'license': 1, 'file_name': '1371.png', 'id': 1371, 'width': 1008, 'height': 756}
# 1372 {'license': 1, 'file_name': '1372.png', 'id': 1372, 'width': 1008, 'height': 756}
# 1373 {'license': 1, 'file_name': '1373.png', 'id': 1373, 'width': 1008, 'height': 756}
# 1374 {'license': 1, 'file_name': '1374.png', 'id': 1374, 'width': 1008, 'height': 756}
# 1375 {'license': 1, 'file_name': '1375.png', 'id': 1375, 'width': 1008, 'height': 756}
# 1376 {'license': 1, 'file_name': '1376.png', 'id': 1376, 'width': 1008, 'height': 756}
# 1377 {'license': 1, 'file_name': '1377.png', 'id': 1377, 'width': 1008, 'height': 756}
# 1378 {'license': 1, 'file_name': '1378.png', 'id': 1378, 'width': 1008, 'height': 756}
# 1379 {'license': 1, 'file_name': '1379.png', 'id': 1379, 'width': 1008, 'height': 756}
# 1380 {'license': 1, 'file_name': '1380.png', 'id': 1380, 'width': 1008, 'height': 756}
# 1381 {'license': 1, 'file_name': '1381.png', 'id': 1381, 'width': 1008, 'height': 756}
# 1382 {'license': 1, 'file_name': '1382.png', 'id': 1382, 'width': 1008, 'height': 756}
# 1383 {'license': 1, 'file_name': '1383.png', 'id': 1383, 'width': 1008, 'height': 756}
# 1384 {'license': 1, 'file_name': '1384.png', 'id': 1384, 'width': 1008, 'height': 756}
# 1385 {'license': 1, 'file_name': '1385.png', 'id': 1385, 'width': 1008, 'height': 756}
# 1386 {'license': 1, 'file_name': '1386.png', 'id': 1386, 'width': 1008, 'height': 756}
# 1387 {'license': 1, 'file_name': '1387.png', 'id': 1387, 'width': 1008, 'height': 756}
# 1388 {'license': 1, 'file_name': '1388.png', 'id': 1388, 'width': 1008, 'height': 756}
# 1389 {'license': 1, 'file_name': '1389.png', 'id': 1389, 'width': 1008, 'height': 756}
# 139 {'license': 1, 'file_name': '139.png', 'id': 139, 'width': 1008, 'height': 756}
# 1390 {'license': 1, 'file_name': '1390.png', 'id': 1390, 'width': 1008, 'height': 756}
# 1391 {'license': 1, 'file_name': '1391.png', 'id': 1391, 'width': 1008, 'height': 756}
# 1392 {'license': 1, 'file_name': '1392.png', 'id': 1392, 'width': 1008, 'height': 756}
# 1393 {'license': 1, 'file_name': '1393.png', 'id': 1393, 'width': 1008, 'height': 756}
# 1394 {'license': 1, 'file_name': '1394.png', 'id': 1394, 'width': 1008, 'height': 756}
# 1396 {'license': 1, 'file_name': '1396.png', 'id': 1396, 'width': 1008, 'height': 756}
# 1397 {'license': 1, 'file_name': '1397.png', 'id': 1397, 'width': 1008, 'height': 756}
# 1398 {'license': 1, 'file_name': '1398.png', 'id': 1398, 'width': 1008, 'height': 756}
# 1399 {'license': 1, 'file_name': '1399.png', 'id': 1399, 'width': 1008, 'height': 756}
# 14 {'license': 1, 'file_name': '14.png', 'id': 14, 'width': 1008, 'height': 756}
# 140 {'license': 1, 'file_name': '140.png', 'id': 140, 'width': 1008, 'height': 756}
# 1400 {'license': 1, 'file_name': '1400.png', 'id': 1400, 'width': 1008, 'height': 756}
# 1402 {'license': 1, 'file_name': '1402.png', 'id': 1402, 'width': 1008, 'height': 756}
# 1403 {'license': 1, 'file_name': '1403.png', 'id': 1403, 'width': 1008, 'height': 756}
# 1404 {'license': 1, 'file_name': '1404.png', 'id': 1404, 'width': 1008, 'height': 756}
# 1406 {'license': 1, 'file_name': '1406.png', 'id': 1406, 'width': 1008, 'height': 756}
# 1407 {'license': 1, 'file_name': '1407.png', 'id': 1407, 'width': 1008, 'height': 756}
# 1408 {'license': 1, 'file_name': '1408.png', 'id': 1408, 'width': 1008, 'height': 756}
# 1409 {'license': 1, 'file_name': '1409.png', 'id': 1409, 'width': 1008, 'height': 756}
# 141 {'license': 1, 'file_name': '141.png', 'id': 141, 'width': 1008, 'height': 756}
# 1410 {'license': 1, 'file_name': '1410.png', 'id': 1410, 'width': 1008, 'height': 756}
# 1411 {'license': 1, 'file_name': '1411.png', 'id': 1411, 'width': 1008, 'height': 756}
# 1413 {'license': 1, 'file_name': '1413.png', 'id': 1413, 'width': 1008, 'height': 756}
# 1414 {'license': 1, 'file_name': '1414.png', 'id': 1414, 'width': 1008, 'height': 756}
# 1415 {'license': 1, 'file_name': '1415.png', 'id': 1415, 'width': 1008, 'height': 756}
# 1416 {'license': 1, 'file_name': '1416.png', 'id': 1416, 'width': 1008, 'height': 756}
# 1417 {'license': 1, 'file_name': '1417.png', 'id': 1417, 'width': 1008, 'height': 756}
# 1418 {'license': 1, 'file_name': '1418.png', 'id': 1418, 'width': 1008, 'height': 756}
# 1419 {'license': 1, 'file_name': '1419.png', 'id': 1419, 'width': 1008, 'height': 756}
# 142 {'license': 1, 'file_name': '142.png', 'id': 142, 'width': 1008, 'height': 756}
# 1420 {'license': 1, 'file_name': '1420.png', 'id': 1420, 'width': 1008, 'height': 756}
# 1421 {'license': 1, 'file_name': '1421.png', 'id': 1421, 'width': 1008, 'height': 756}
# 1422 {'license': 1, 'file_name': '1422.png', 'id': 1422, 'width': 1008, 'height': 756}
# 1423 {'license': 1, 'file_name': '1423.png', 'id': 1423, 'width': 1008, 'height': 756}
# 1424 {'license': 1, 'file_name': '1424.png', 'id': 1424, 'width': 1008, 'height': 756}
# 1425 {'license': 1, 'file_name': '1425.png', 'id': 1425, 'width': 1008, 'height': 756}
# 1427 {'license': 1, 'file_name': '1427.png', 'id': 1427, 'width': 1008, 'height': 756}
# 1428 {'license': 1, 'file_name': '1428.png', 'id': 1428, 'width': 1008, 'height': 756}
# 1429 {'license': 1, 'file_name': '1429.png', 'id': 1429, 'width': 1008, 'height': 756}
# 143 {'license': 1, 'file_name': '143.png', 'id': 143, 'width': 1008, 'height': 756}
# 1430 {'license': 1, 'file_name': '1430.png', 'id': 1430, 'width': 1008, 'height': 756}
# 1431 {'license': 1, 'file_name': '1431.png', 'id': 1431, 'width': 1008, 'height': 756}
# 1432 {'license': 1, 'file_name': '1432.png', 'id': 1432, 'width': 1008, 'height': 756}
# 1433 {'license': 1, 'file_name': '1433.png', 'id': 1433, 'width': 1008, 'height': 756}
# 1434 {'license': 1, 'file_name': '1434.png', 'id': 1434, 'width': 1008, 'height': 756}
# 1435 {'license': 1, 'file_name': '1435.png', 'id': 1435, 'width': 1008, 'height': 756}
# 1436 {'license': 1, 'file_name': '1436.png', 'id': 1436, 'width': 1008, 'height': 756}
# 1437 {'license': 1, 'file_name': '1437.png', 'id': 1437, 'width': 1008, 'height': 756}
# 1438 {'license': 1, 'file_name': '1438.png', 'id': 1438, 'width': 1008, 'height': 756}
# 1439 {'license': 1, 'file_name': '1439.png', 'id': 1439, 'width': 1008, 'height': 756}
# 144 {'license': 1, 'file_name': '144.png', 'id': 144, 'width': 1008, 'height': 756}
# 1440 {'license': 1, 'file_name': '1440.png', 'id': 1440, 'width': 1008, 'height': 756}
# 1441 {'license': 1, 'file_name': '1441.png', 'id': 1441, 'width': 1008, 'height': 756}
# 1442 {'license': 1, 'file_name': '1442.png', 'id': 1442, 'width': 1008, 'height': 756}
# 1443 {'license': 1, 'file_name': '1443.png', 'id': 1443, 'width': 1008, 'height': 756}
# 1444 {'license': 1, 'file_name': '1444.png', 'id': 1444, 'width': 1008, 'height': 756}
# 1445 {'license': 1, 'file_name': '1445.png', 'id': 1445, 'width': 1008, 'height': 756}
# 1446 {'license': 1, 'file_name': '1446.png', 'id': 1446, 'width': 1008, 'height': 756}
# 1447 {'license': 1, 'file_name': '1447.png', 'id': 1447, 'width': 1008, 'height': 756}
# 1448 {'license': 1, 'file_name': '1448.png', 'id': 1448, 'width': 1008, 'height': 756}
# 1449 {'license': 1, 'file_name': '1449.png', 'id': 1449, 'width': 1008, 'height': 756}
# 145 {'license': 1, 'file_name': '145.png', 'id': 145, 'width': 1008, 'height': 756}
# 1450 {'license': 1, 'file_name': '1450.png', 'id': 1450, 'width': 1008, 'height': 756}
# 1451 {'license': 1, 'file_name': '1451.png', 'id': 1451, 'width': 1008, 'height': 756}
# 1452 {'license': 1, 'file_name': '1452.png', 'id': 1452, 'width': 1008, 'height': 756}
# 1453 {'license': 1, 'file_name': '1453.png', 'id': 1453, 'width': 1008, 'height': 756}
# 1454 {'license': 1, 'file_name': '1454.png', 'id': 1454, 'width': 1008, 'height': 756}
# 1455 {'license': 1, 'file_name': '1455.png', 'id': 1455, 'width': 1008, 'height': 756}
# 1456 {'license': 1, 'file_name': '1456.png', 'id': 1456, 'width': 1008, 'height': 756}
# 1457 {'license': 1, 'file_name': '1457.png', 'id': 1457, 'width': 1008, 'height': 756}
# 1458 {'license': 1, 'file_name': '1458.png', 'id': 1458, 'width': 1008, 'height': 756}
# 1459 {'license': 1, 'file_name': '1459.png', 'id': 1459, 'width': 1008, 'height': 756}
# 146 {'license': 1, 'file_name': '146.png', 'id': 146, 'width': 1008, 'height': 756}
# 1460 {'license': 1, 'file_name': '1460.png', 'id': 1460, 'width': 1008, 'height': 756}
# 1461 {'license': 1, 'file_name': '1461.png', 'id': 1461, 'width': 1008, 'height': 756}
# 1462 {'license': 1, 'file_name': '1462.png', 'id': 1462, 'width': 1008, 'height': 756}
# 1463 {'license': 1, 'file_name': '1463.png', 'id': 1463, 'width': 1008, 'height': 756}
# 1464 {'license': 1, 'file_name': '1464.png', 'id': 1464, 'width': 1008, 'height': 756}
# 1465 {'license': 1, 'file_name': '1465.png', 'id': 1465, 'width': 1008, 'height': 756}
# 1466 {'license': 1, 'file_name': '1466.png', 'id': 1466, 'width': 1008, 'height': 756}
# 1468 {'license': 1, 'file_name': '1468.png', 'id': 1468, 'width': 1008, 'height': 756}
# 1469 {'license': 1, 'file_name': '1469.png', 'id': 1469, 'width': 1008, 'height': 756}
# 147 {'license': 1, 'file_name': '147.png', 'id': 147, 'width': 1008, 'height': 756}
# 1470 {'license': 1, 'file_name': '1470.png', 'id': 1470, 'width': 1008, 'height': 756}
# 1471 {'license': 1, 'file_name': '1471.png', 'id': 1471, 'width': 1008, 'height': 756}
# 1472 {'license': 1, 'file_name': '1472.png', 'id': 1472, 'width': 1008, 'height': 756}
# 1473 {'license': 1, 'file_name': '1473.png', 'id': 1473, 'width': 1008, 'height': 756}
# 1474 {'license': 1, 'file_name': '1474.png', 'id': 1474, 'width': 1008, 'height': 756}
# 1475 {'license': 1, 'file_name': '1475.png', 'id': 1475, 'width': 1008, 'height': 756}
# 1476 {'license': 1, 'file_name': '1476.png', 'id': 1476, 'width': 1008, 'height': 756}
# 1477 {'license': 1, 'file_name': '1477.png', 'id': 1477, 'width': 1008, 'height': 756}
# 1479 {'license': 1, 'file_name': '1479.png', 'id': 1479, 'width': 1008, 'height': 756}
# 148 {'license': 1, 'file_name': '148.png', 'id': 148, 'width': 1008, 'height': 756}
# 1480 {'license': 1, 'file_name': '1480.png', 'id': 1480, 'width': 1008, 'height': 756}
# 1481 {'license': 1, 'file_name': '1481.png', 'id': 1481, 'width': 1008, 'height': 756}
# 1482 {'license': 1, 'file_name': '1482.png', 'id': 1482, 'width': 1008, 'height': 756}
# 1483 {'license': 1, 'file_name': '1483.png', 'id': 1483, 'width': 1008, 'height': 756}
# 1484 {'license': 1, 'file_name': '1484.png', 'id': 1484, 'width': 1008, 'height': 756}
# 1485 {'license': 1, 'file_name': '1485.png', 'id': 1485, 'width': 1008, 'height': 756}
# 1486 {'license': 1, 'file_name': '1486.png', 'id': 1486, 'width': 1008, 'height': 756}
# 1487 {'license': 1, 'file_name': '1487.png', 'id': 1487, 'width': 1008, 'height': 756}
# 1488 {'license': 1, 'file_name': '1488.png', 'id': 1488, 'width': 1008, 'height': 756}
# 1489 {'license': 1, 'file_name': '1489.png', 'id': 1489, 'width': 1008, 'height': 756}
# 1490 {'license': 1, 'file_name': '1490.png', 'id': 1490, 'width': 1008, 'height': 756}
# 1491 {'license': 1, 'file_name': '1491.png', 'id': 1491, 'width': 1008, 'height': 756}
# 1492 {'license': 1, 'file_name': '1492.png', 'id': 1492, 'width': 1008, 'height': 756}
# 1493 {'license': 1, 'file_name': '1493.png', 'id': 1493, 'width': 1008, 'height': 756}
# 1494 {'license': 1, 'file_name': '1494.png', 'id': 1494, 'width': 1008, 'height': 756}
# 1495 {'license': 1, 'file_name': '1495.png', 'id': 1495, 'width': 1008, 'height': 756}
# 1496 {'license': 1, 'file_name': '1496.png', 'id': 1496, 'width': 1008, 'height': 756}
# 1497 {'license': 1, 'file_name': '1497.png', 'id': 1497, 'width': 1008, 'height': 756}
# 1498 {'license': 1, 'file_name': '1498.png', 'id': 1498, 'width': 1008, 'height': 756}
# 1499 {'license': 1, 'file_name': '1499.png', 'id': 1499, 'width': 1008, 'height': 756}
# 150 {'license': 1, 'file_name': '150.png', 'id': 150, 'width': 1008, 'height': 756}
# 1500 {'license': 1, 'file_name': '1500.png', 'id': 1500, 'width': 1008, 'height': 756}
# 1501 {'license': 1, 'file_name': '1501.png', 'id': 1501, 'width': 1008, 'height': 756}
# 1502 {'license': 1, 'file_name': '1502.png', 'id': 1502, 'width': 1008, 'height': 756}
# 1503 {'license': 1, 'file_name': '1503.png', 'id': 1503, 'width': 1008, 'height': 756}
# 1504 {'license': 1, 'file_name': '1504.png', 'id': 1504, 'width': 1008, 'height': 756}
# 1505 {'license': 1, 'file_name': '1505.png', 'id': 1505, 'width': 1008, 'height': 756}
# 1506 {'license': 1, 'file_name': '1506.png', 'id': 1506, 'width': 1008, 'height': 756}
# 1507 {'license': 1, 'file_name': '1507.png', 'id': 1507, 'width': 1008, 'height': 756}
# 1508 {'license': 1, 'file_name': '1508.png', 'id': 1508, 'width': 1008, 'height': 756}
# 1509 {'license': 1, 'file_name': '1509.png', 'id': 1509, 'width': 1008, 'height': 756}
# 151 {'license': 1, 'file_name': '151.png', 'id': 151, 'width': 1008, 'height': 756}
# 1510 {'license': 1, 'file_name': '1510.png', 'id': 1510, 'width': 1008, 'height': 756}
# 1511 {'license': 1, 'file_name': '1511.png', 'id': 1511, 'width': 1008, 'height': 756}
# 1512 {'license': 1, 'file_name': '1512.png', 'id': 1512, 'width': 1008, 'height': 756}
# 1513 {'license': 1, 'file_name': '1513.png', 'id': 1513, 'width': 1008, 'height': 756}
# 1514 {'license': 1, 'file_name': '1514.png', 'id': 1514, 'width': 1008, 'height': 756}
# 1515 {'license': 1, 'file_name': '1515.png', 'id': 1515, 'width': 1008, 'height': 756}
# 1516 {'license': 1, 'file_name': '1516.png', 'id': 1516, 'width': 1008, 'height': 756}
# 1517 {'license': 1, 'file_name': '1517.png', 'id': 1517, 'width': 1008, 'height': 756}
# 1518 {'license': 1, 'file_name': '1518.png', 'id': 1518, 'width': 1008, 'height': 756}
# 1519 {'license': 1, 'file_name': '1519.png', 'id': 1519, 'width': 1008, 'height': 756}
# 152 {'license': 1, 'file_name': '152.png', 'id': 152, 'width': 1008, 'height': 756}
# 1520 {'license': 1, 'file_name': '1520.png', 'id': 1520, 'width': 1008, 'height': 756}
# 1521 {'license': 1, 'file_name': '1521.png', 'id': 1521, 'width': 1008, 'height': 756}
# 1522 {'license': 1, 'file_name': '1522.png', 'id': 1522, 'width': 1008, 'height': 756}
# 1523 {'license': 1, 'file_name': '1523.png', 'id': 1523, 'width': 1008, 'height': 756}
# 1524 {'license': 1, 'file_name': '1524.png', 'id': 1524, 'width': 1008, 'height': 756}
# 1525 {'license': 1, 'file_name': '1525.png', 'id': 1525, 'width': 1008, 'height': 756}
# 1526 {'license': 1, 'file_name': '1526.png', 'id': 1526, 'width': 1008, 'height': 756}
# 1527 {'license': 1, 'file_name': '1527.png', 'id': 1527, 'width': 1008, 'height': 756}
# 1528 {'license': 1, 'file_name': '1528.png', 'id': 1528, 'width': 1008, 'height': 756}
# 1529 {'license': 1, 'file_name': '1529.png', 'id': 1529, 'width': 1008, 'height': 756}
# 153 {'license': 1, 'file_name': '153.png', 'id': 153, 'width': 1008, 'height': 756}
# 1530 {'license': 1, 'file_name': '1530.png', 'id': 1530, 'width': 1008, 'height': 756}
# 1532 {'license': 1, 'file_name': '1532.png', 'id': 1532, 'width': 1008, 'height': 756}
# 1533 {'license': 1, 'file_name': '1533.png', 'id': 1533, 'width': 1008, 'height': 756}
# 1534 {'license': 1, 'file_name': '1534.png', 'id': 1534, 'width': 1008, 'height': 756}
# 1535 {'license': 1, 'file_name': '1535.png', 'id': 1535, 'width': 1008, 'height': 756}
# 1536 {'license': 1, 'file_name': '1536.png', 'id': 1536, 'width': 1008, 'height': 756}
# 1537 {'license': 1, 'file_name': '1537.png', 'id': 1537, 'width': 1008, 'height': 756}
# 1538 {'license': 1, 'file_name': '1538.png', 'id': 1538, 'width': 1008, 'height': 756}
# 154 {'license': 1, 'file_name': '154.png', 'id': 154, 'width': 1008, 'height': 756}
# 1540 {'license': 1, 'file_name': '1540.png', 'id': 1540, 'width': 1008, 'height': 756}
# 1541 {'license': 1, 'file_name': '1541.png', 'id': 1541, 'width': 1008, 'height': 756}
# ...
# 806 {'license': 1, 'file_name': '806.png', 'id': 806, 'width': 1008, 'height': 756}
# 807 {'license': 1, 'file_name': '807.png', 'id': 807, 'width': 1008, 'height': 756}
# 808 {'license': 1, 'file_name': '808.png', 'id': 808, 'width': 1008, 'height': 756}
# 81 {'license': 1, 'file_name': '81.png', 'id': 81, 'width': 1008, 'height': 756}
# 810 {'license': 1, 'file_name': '810.png', 'id': 810, 'width': 1008, 'height': 756}
# 811 {'license': 1, 'file_name': '811.png', 'id': 811, 'width': 1008, 'height': 756}
# 812 {'license': 1, 'file_name': '812.png', 'id': 812, 'width': 1008, 'height': 756}
# 813 {'license': 1, 'file_name': '813.png', 'id': 813, 'width': 1008, 'height': 756}
# 814 {'license': 1, 'file_name': '814.png', 'id': 814, 'width': 1008, 'height': 756}
# 815 {'license': 1, 'file_name': '815.png', 'id': 815, 'width': 1008, 'height': 756}
# 816 {'license': 1, 'file_name': '816.png', 'id': 816, 'width': 1008, 'height': 756}
# 817 {'license': 1, 'file_name': '817.png', 'id': 817, 'width': 1008, 'height': 756}
# 818 {'license': 1, 'file_name': '818.png', 'id': 818, 'width': 1008, 'height': 756}
# 819 {'license': 1, 'file_name': '819.png', 'id': 819, 'width': 1008, 'height': 756}
# 82 {'license': 1, 'file_name': '82.png', 'id': 82, 'width': 1008, 'height': 756}
# 820 {'license': 1, 'file_name': '820.png', 'id': 820, 'width': 1008, 'height': 756}
# 822 {'license': 1, 'file_name': '822.png', 'id': 822, 'width': 1008, 'height': 756}
# 823 {'license': 1, 'file_name': '823.png', 'id': 823, 'width': 1008, 'height': 756}
# 825 {'license': 1, 'file_name': '825.png', 'id': 825, 'width': 1008, 'height': 756}
# 826 {'license': 1, 'file_name': '826.png', 'id': 826, 'width': 1008, 'height': 756}
# 827 {'license': 1, 'file_name': '827.png', 'id': 827, 'width': 1008, 'height': 756}
# 828 {'license': 1, 'file_name': '828.png', 'id': 828, 'width': 1008, 'height': 756}
# 829 {'license': 1, 'file_name': '829.png', 'id': 829, 'width': 1008, 'height': 756}
# 83 {'license': 1, 'file_name': '83.png', 'id': 83, 'width': 1008, 'height': 756}
# 830 {'license': 1, 'file_name': '830.png', 'id': 830, 'width': 1008, 'height': 756}
# 831 {'license': 1, 'file_name': '831.png', 'id': 831, 'width': 1008, 'height': 756}
# 832 {'license': 1, 'file_name': '832.png', 'id': 832, 'width': 1008, 'height': 756}
# 833 {'license': 1, 'file_name': '833.png', 'id': 833, 'width': 1008, 'height': 756}
# 834 {'license': 1, 'file_name': '834.png', 'id': 834, 'width': 1008, 'height': 756}
# 835 {'license': 1, 'file_name': '835.png', 'id': 835, 'width': 1008, 'height': 756}
# 836 {'license': 1, 'file_name': '836.png', 'id': 836, 'width': 1008, 'height': 756}
# 837 {'license': 1, 'file_name': '837.png', 'id': 837, 'width': 1008, 'height': 756}
# 838 {'license': 1, 'file_name': '838.png', 'id': 838, 'width': 1008, 'height': 756}
# 839 {'license': 1, 'file_name': '839.png', 'id': 839, 'width': 1008, 'height': 756}
# 84 {'license': 1, 'file_name': '84.png', 'id': 84, 'width': 1008, 'height': 756}
# 840 {'license': 1, 'file_name': '840.png', 'id': 840, 'width': 1008, 'height': 756}
# 841 {'license': 1, 'file_name': '841.png', 'id': 841, 'width': 1008, 'height': 756}
# 842 {'license': 1, 'file_name': '842.png', 'id': 842, 'width': 1008, 'height': 756}
# 843 {'license': 1, 'file_name': '843.png', 'id': 843, 'width': 1008, 'height': 756}
# 844 {'license': 1, 'file_name': '844.png', 'id': 844, 'width': 1008, 'height': 756}
# 845 {'license': 1, 'file_name': '845.png', 'id': 845, 'width': 1008, 'height': 756}
# 846 {'license': 1, 'file_name': '846.png', 'id': 846, 'width': 1008, 'height': 756}
# 847 {'license': 1, 'file_name': '847.png', 'id': 847, 'width': 1008, 'height': 756}
# 848 {'license': 1, 'file_name': '848.png', 'id': 848, 'width': 1008, 'height': 756}
# 849 {'license': 1, 'file_name': '849.png', 'id': 849, 'width': 1008, 'height': 756}
# 85 {'license': 1, 'file_name': '85.png', 'id': 85, 'width': 1008, 'height': 756}
# 850 {'license': 1, 'file_name': '850.png', 'id': 850, 'width': 1008, 'height': 756}
# 851 {'license': 1, 'file_name': '851.png', 'id': 851, 'width': 1008, 'height': 756}
# 852 {'license': 1, 'file_name': '852.png', 'id': 852, 'width': 1008, 'height': 756}
# 853 {'license': 1, 'file_name': '853.png', 'id': 853, 'width': 1008, 'height': 756}
# 854 {'license': 1, 'file_name': '854.png', 'id': 854, 'width': 1008, 'height': 756}
# 855 {'license': 1, 'file_name': '855.png', 'id': 855, 'width': 1008, 'height': 756}
# 857 {'license': 1, 'file_name': '857.png', 'id': 857, 'width': 1008, 'height': 756}
# 859 {'license': 1, 'file_name': '859.png', 'id': 859, 'width': 1008, 'height': 756}
# 86 {'license': 1, 'file_name': '86.png', 'id': 86, 'width': 1008, 'height': 756}
# 860 {'license': 1, 'file_name': '860.png', 'id': 860, 'width': 1008, 'height': 756}
# 861 {'license': 1, 'file_name': '861.png', 'id': 861, 'width': 1008, 'height': 756}
# 862 {'license': 1, 'file_name': '862.png', 'id': 862, 'width': 1008, 'height': 756}
# 863 {'license': 1, 'file_name': '863.png', 'id': 863, 'width': 1008, 'height': 756}
# 864 {'license': 1, 'file_name': '864.png', 'id': 864, 'width': 1008, 'height': 756}
# 865 {'license': 1, 'file_name': '865.png', 'id': 865, 'width': 1008, 'height': 756}
# 866 {'license': 1, 'file_name': '866.png', 'id': 866, 'width': 1008, 'height': 756}
# 867 {'license': 1, 'file_name': '867.png', 'id': 867, 'width': 1008, 'height': 756}
# 868 {'license': 1, 'file_name': '868.png', 'id': 868, 'width': 1008, 'height': 756}
# 87 {'license': 1, 'file_name': '87.png', 'id': 87, 'width': 1008, 'height': 756}
# 870 {'license': 1, 'file_name': '870.png', 'id': 870, 'width': 1008, 'height': 756}
# 871 {'license': 1, 'file_name': '871.png', 'id': 871, 'width': 1008, 'height': 756}
# 872 {'license': 1, 'file_name': '872.png', 'id': 872, 'width': 1008, 'height': 756}
# 873 {'license': 1, 'file_name': '873.png', 'id': 873, 'width': 1008, 'height': 756}
# 874 {'license': 1, 'file_name': '874.png', 'id': 874, 'width': 1008, 'height': 756}
# 875 {'license': 1, 'file_name': '875.png', 'id': 875, 'width': 1008, 'height': 756}
# 876 {'license': 1, 'file_name': '876.png', 'id': 876, 'width': 1008, 'height': 756}
# 877 {'license': 1, 'file_name': '877.png', 'id': 877, 'width': 1008, 'height': 756}
# 879 {'license': 1, 'file_name': '879.png', 'id': 879, 'width': 1008, 'height': 756}
# 88 {'license': 1, 'file_name': '88.png', 'id': 88, 'width': 1008, 'height': 756}
# 880 {'license': 1, 'file_name': '880.png', 'id': 880, 'width': 1008, 'height': 756}
# 881 {'license': 1, 'file_name': '881.png', 'id': 881, 'width': 1008, 'height': 756}
# 882 {'license': 1, 'file_name': '882.png', 'id': 882, 'width': 1008, 'height': 756}
# 883 {'license': 1, 'file_name': '883.png', 'id': 883, 'width': 1008, 'height': 756}
# 884 {'license': 1, 'file_name': '884.png', 'id': 884, 'width': 1008, 'height': 756}
# 885 {'license': 1, 'file_name': '885.png', 'id': 885, 'width': 1008, 'height': 756}
# 886 {'license': 1, 'file_name': '886.png', 'id': 886, 'width': 1008, 'height': 756}
# 887 {'license': 1, 'file_name': '887.png', 'id': 887, 'width': 1008, 'height': 756}
# 889 {'license': 1, 'file_name': '889.png', 'id': 889, 'width': 1008, 'height': 756}
# 89 {'license': 1, 'file_name': '89.png', 'id': 89, 'width': 1008, 'height': 756}
# 890 {'license': 1, 'file_name': '890.png', 'id': 890, 'width': 1008, 'height': 756}
# 892 {'license': 1, 'file_name': '892.png', 'id': 892, 'width': 1008, 'height': 756}
# 893 {'license': 1, 'file_name': '893.png', 'id': 893, 'width': 1008, 'height': 756}
# 894 {'license': 1, 'file_name': '894.png', 'id': 894, 'width': 1008, 'height': 756}
# 895 {'license': 1, 'file_name': '895.png', 'id': 895, 'width': 1008, 'height': 756}
# 897 {'license': 1, 'file_name': '897.png', 'id': 897, 'width': 1008, 'height': 756}
# 898 {'license': 1, 'file_name': '898.png', 'id': 898, 'width': 1008, 'height': 756}
# 899 {'license': 1, 'file_name': '899.png', 'id': 899, 'width': 1008, 'height': 756}
# 9 {'license': 1, 'file_name': '9.png', 'id': 9, 'width': 1008, 'height': 756}
# 90 {'license': 1, 'file_name': '90.png', 'id': 90, 'width': 1008, 'height': 756}
# 900 {'license': 1, 'file_name': '900.png', 'id': 900, 'width': 1008, 'height': 756}
# 901 {'license': 1, 'file_name': '901.png', 'id': 901, 'width': 1008, 'height': 756}
# 902 {'license': 1, 'file_name': '902.png', 'id': 902, 'width': 1008, 'height': 756}
# 903 {'license': 1, 'file_name': '903.png', 'id': 903, 'width': 1008, 'height': 756}
# 904 {'license': 1, 'file_name': '904.png', 'id': 904, 'width': 1008, 'height': 756}
# 906 {'license': 1, 'file_name': '906.png', 'id': 906, 'width': 1008, 'height': 756}
# 907 {'license': 1, 'file_name': '907.png', 'id': 907, 'width': 1008, 'height': 756}
# 908 {'license': 1, 'file_name': '908.png', 'id': 908, 'width': 1008, 'height': 756}
# 909 {'license': 1, 'file_name': '909.png', 'id': 909, 'width': 1008, 'height': 756}
# 91 {'license': 1, 'file_name': '91.png', 'id': 91, 'width': 1008, 'height': 756}
# 910 {'license': 1, 'file_name': '910.png', 'id': 910, 'width': 1008, 'height': 756}
# 911 {'license': 1, 'file_name': '911.png', 'id': 911, 'width': 1008, 'height': 756}
# 912 {'license': 1, 'file_name': '912.png', 'id': 912, 'width': 1008, 'height': 756}
# 913 {'license': 1, 'file_name': '913.png', 'id': 913, 'width': 1008, 'height': 756}
# 914 {'license': 1, 'file_name': '914.png', 'id': 914, 'width': 1008, 'height': 756}
# 915 {'license': 1, 'file_name': '915.png', 'id': 915, 'width': 1008, 'height': 756}
# 917 {'license': 1, 'file_name': '917.png', 'id': 917, 'width': 1008, 'height': 756}
# 918 {'license': 1, 'file_name': '918.png', 'id': 918, 'width': 1008, 'height': 756}
# 919 {'license': 1, 'file_name': '919.png', 'id': 919, 'width': 1008, 'height': 756}
# 921 {'license': 1, 'file_name': '921.png', 'id': 921, 'width': 1008, 'height': 756}
# 922 {'license': 1, 'file_name': '922.png', 'id': 922, 'width': 1008, 'height': 756}
# 923 {'license': 1, 'file_name': '923.png', 'id': 923, 'width': 1008, 'height': 756}
# 924 {'license': 1, 'file_name': '924.png', 'id': 924, 'width': 1008, 'height': 756}
# 925 {'license': 1, 'file_name': '925.png', 'id': 925, 'width': 1008, 'height': 756}
# 927 {'license': 1, 'file_name': '927.png', 'id': 927, 'width': 1008, 'height': 756}
# 928 {'license': 1, 'file_name': '928.png', 'id': 928, 'width': 1008, 'height': 756}
# 929 {'license': 1, 'file_name': '929.png', 'id': 929, 'width': 1008, 'height': 756}
# 93 {'license': 1, 'file_name': '93.png', 'id': 93, 'width': 1008, 'height': 756}
# 930 {'license': 1, 'file_name': '930.png', 'id': 930, 'width': 1008, 'height': 756}
# 931 {'license': 1, 'file_name': '931.png', 'id': 931, 'width': 1008, 'height': 756}
# 932 {'license': 1, 'file_name': '932.png', 'id': 932, 'width': 1008, 'height': 756}
# 933 {'license': 1, 'file_name': '933.png', 'id': 933, 'width': 1008, 'height': 756}
# 934 {'license': 1, 'file_name': '934.png', 'id': 934, 'width': 1008, 'height': 756}
# 935 {'license': 1, 'file_name': '935.png', 'id': 935, 'width': 1008, 'height': 756}
# 936 {'license': 1, 'file_name': '936.png', 'id': 936, 'width': 1008, 'height': 756}
# 937 {'license': 1, 'file_name': '937.png', 'id': 937, 'width': 1008, 'height': 756}
# 939 {'license': 1, 'file_name': '939.png', 'id': 939, 'width': 1008, 'height': 756}
# 94 {'license': 1, 'file_name': '94.png', 'id': 94, 'width': 1008, 'height': 756}
# 940 {'license': 1, 'file_name': '940.png', 'id': 940, 'width': 1008, 'height': 756}
# 941 {'license': 1, 'file_name': '941.png', 'id': 941, 'width': 1008, 'height': 756}
# 943 {'license': 1, 'file_name': '943.png', 'id': 943, 'width': 1008, 'height': 756}
# 944 {'license': 1, 'file_name': '944.png', 'id': 944, 'width': 1008, 'height': 756}
# 945 {'license': 1, 'file_name': '945.png', 'id': 945, 'width': 1008, 'height': 756}
# 946 {'license': 1, 'file_name': '946.png', 'id': 946, 'width': 1008, 'height': 756}
# 947 {'license': 1, 'file_name': '947.png', 'id': 947, 'width': 1008, 'height': 756}
# 948 {'license': 1, 'file_name': '948.png', 'id': 948, 'width': 1008, 'height': 756}
# 95 {'license': 1, 'file_name': '95.png', 'id': 95, 'width': 1008, 'height': 756}
# 951 {'license': 1, 'file_name': '951.png', 'id': 951, 'width': 1008, 'height': 756}
# 953 {'license': 1, 'file_name': '953.png', 'id': 953, 'width': 1008, 'height': 756}
# 954 {'license': 1, 'file_name': '954.png', 'id': 954, 'width': 1008, 'height': 756}
# 955 {'license': 1, 'file_name': '955.png', 'id': 955, 'width': 1008, 'height': 756}
# 956 {'license': 1, 'file_name': '956.png', 'id': 956, 'width': 1008, 'height': 756}
# 957 {'license': 1, 'file_name': '957.png', 'id': 957, 'width': 1008, 'height': 756}
# 958 {'license': 1, 'file_name': '958.png', 'id': 958, 'width': 1008, 'height': 756}
# 959 {'license': 1, 'file_name': '959.png', 'id': 959, 'width': 1008, 'height': 756}
# 96 {'license': 1, 'file_name': '96.png', 'id': 96, 'width': 1008, 'height': 756}
# 960 {'license': 1, 'file_name': '960.png', 'id': 960, 'width': 1008, 'height': 756}
# 961 {'license': 1, 'file_name': '961.png', 'id': 961, 'width': 1008, 'height': 756}
# 962 {'license': 1, 'file_name': '962.png', 'id': 962, 'width': 1008, 'height': 756}
# 963 {'license': 1, 'file_name': '963.png', 'id': 963, 'width': 1008, 'height': 756}
# 964 {'license': 1, 'file_name': '964.png', 'id': 964, 'width': 1008, 'height': 756}
# 965 {'license': 1, 'file_name': '965.png', 'id': 965, 'width': 1008, 'height': 756}
# 966 {'license': 1, 'file_name': '966.png', 'id': 966, 'width': 1008, 'height': 756}
# 968 {'license': 1, 'file_name': '968.png', 'id': 968, 'width': 1008, 'height': 756}
# 969 {'license': 1, 'file_name': '969.png', 'id': 969, 'width': 1008, 'height': 756}
# 97 {'license': 1, 'file_name': '97.png', 'id': 97, 'width': 1008, 'height': 756}
# 970 {'license': 1, 'file_name': '970.png', 'id': 970, 'width': 1008, 'height': 756}
# 971 {'license': 1, 'file_name': '971.png', 'id': 971, 'width': 1008, 'height': 756}
# 972 {'license': 1, 'file_name': '972.png', 'id': 972, 'width': 1008, 'height': 756}
# 973 {'license': 1, 'file_name': '973.png', 'id': 973, 'width': 1008, 'height': 756}
# 974 {'license': 1, 'file_name': '974.png', 'id': 974, 'width': 1008, 'height': 756}
# 975 {'license': 1, 'file_name': '975.png', 'id': 975, 'width': 1008, 'height': 756}
# 976 {'license': 1, 'file_name': '976.png', 'id': 976, 'width': 1008, 'height': 756}
# 977 {'license': 1, 'file_name': '977.png', 'id': 977, 'width': 1008, 'height': 756}
# 978 {'license': 1, 'file_name': '978.png', 'id': 978, 'width': 1008, 'height': 756}
# 979 {'license': 1, 'file_name': '979.png', 'id': 979, 'width': 1008, 'height': 756}
# 98 {'license': 1, 'file_name': '98.png', 'id': 98, 'width': 1008, 'height': 756}
# 981 {'license': 1, 'file_name': '981.png', 'id': 981, 'width': 1008, 'height': 756}
# 982 {'license': 1, 'file_name': '982.png', 'id': 982, 'width': 1008, 'height': 756}
# 983 {'license': 1, 'file_name': '983.png', 'id': 983, 'width': 1008, 'height': 756}
# 984 {'license': 1, 'file_name': '984.png', 'id': 984, 'width': 1008, 'height': 756}
# 985 {'license': 1, 'file_name': '985.png', 'id': 985, 'width': 1008, 'height': 756}
# 986 {'license': 1, 'file_name': '986.png', 'id': 986, 'width': 1008, 'height': 756}
# 987 {'license': 1, 'file_name': '987.png', 'id': 987, 'width': 1008, 'height': 756}
# 988 {'license': 1, 'file_name': '988.png', 'id': 988, 'width': 1008, 'height': 756}
# 989 {'license': 1, 'file_name': '989.png', 'id': 989, 'width': 1008, 'height': 756}
# 99 {'license': 1, 'file_name': '99.png', 'id': 99, 'width': 1008, 'height': 756}
# 990 {'license': 1, 'file_name': '990.png', 'id': 990, 'width': 1008, 'height': 756}
# 991 {'license': 1, 'file_name': '991.png', 'id': 991, 'width': 1008, 'height': 756}
# 992 {'license': 1, 'file_name': '992.png', 'id': 992, 'width': 1008, 'height': 756}
# 993 {'license': 1, 'file_name': '993.png', 'id': 993, 'width': 1008, 'height': 756}
# 994 {'license': 1, 'file_name': '994.png', 'id': 994, 'width': 1008, 'height': 756}
# 996 {'license': 1, 'file_name': '996.png', 'id': 996, 'width': 1008, 'height': 756}
# 997 {'license': 1, 'file_name': '997.png', 'id': 997, 'width': 1008, 'height': 756}
# 998 {'license': 1, 'file_name': '998.png', 'id': 998, 'width': 1008, 'height': 756}
# 999 {'license': 1, 'file_name': '999.png', 'id': 999, 'width': 1008, 'height': 756}

# %%
html = coco_dataset.display_image(990, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   license: 1
#   file_name: 990.png
#   id: 990
#   width: 1008
#   height: 756
#   segmentations (5):
#     16182:blue:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     16183:purple:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     16184:red:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     16185:green:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     16186:orange:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
# <div class="container" style="position:relative;"><img src="/content/dataset/train/label/990.png" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="450.0"><polygon points=" 0 19  0 19  0  0 18  0 18  4 13 11  6 18  0 19" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="146 227 129 225 108 226  93 224  88 222  80 216  80 207  88 199 100 190
#  110 181 119 177 125 171 136 166 150 167 162 174 166 179 167 186 171 197
#  172 207 167 216 155 223 146 227" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="163 169 156 165 155 158 161 147 163 144 172 138 178 136 178 135 166 131
#  150 131 146 133 144 133 146 123 146  97 139 100 126 130 122 125 122 123
#  126 110 132  97 139  90 147  85 151  83 161  82 183  85 197  91 208 103
#  211 108 205 123 193 145 198 146 179 147 173 152 165 161 163 169" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="213 148 202 145 212 125 216 118 220 126 221 140 213 148" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="314 190 298 190 292 189 281 183 270 160 265 147 262 136 259 117 260  92
#  262  83 268  72 275  65 280  61 292  58 300  53 304  53 324  53 332  56
#  341  58 350  63 357  71 358  76 363  86 365  97 364 107 361 117 343 154
#  332 173 324 183 314 190" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="413 299 404 298 395 293 389 287 385 282 381 274 372 266 368 259 363 247
#  363 242 365 233 369 225 376 219 386 215 396 212 403 212 415 216 421 222
#  426 232 427 237 427 258 425 284 420 295 417 297 413 299" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><text x="0" y="0" fill="yellow">strawberry</text><polygon points=" 0  0 18  0 18 19  0 19  0  0" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="80" y="166" fill="yellow">strawberry</text><polygon points=" 80 166 172 166 172 227  80 227  80 166" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="122" y="82" fill="yellow">strawberry</text><polygon points="122  82 221  82 221 169 122 169 122  82" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="259" y="53" fill="yellow">strawberry</text><polygon points="259  53 365  53 365 190 259 190 259  53" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /><text x="363" y="212" fill="yellow">strawberry</text><polygon points="363 212 427 212 427 299 363 299 363 212" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>

# %% [markdown]
# ### See labels from val dataset

# %%
annotation_path = "/content/val.json"
image_dir = "/content/dataset/val/label"

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
#   year: 2022
#   version: 2022
#   description: Strawberry
#   contributor: Crespo
#   url:
#   date_created: 2022.01.29
#
# Licenses:
# =========
# Categories:
# =========
#   super_category: fruit
#     id 0: strawberry

# %%
for k, v in coco_dataset.images.items():
    print(k, v)
# Out:
# 1002 {'license': 1, 'file_name': '1002.png', 'id': 1002, 'width': 1008, 'height': 756}
# 1029 {'license': 1, 'file_name': '1029.png', 'id': 1029, 'width': 1008, 'height': 756}
# 108 {'license': 1, 'file_name': '108.png', 'id': 108, 'width': 1008, 'height': 756}
# 1099 {'license': 1, 'file_name': '1099.png', 'id': 1099, 'width': 1008, 'height': 756}
# 1104 {'license': 1, 'file_name': '1104.png', 'id': 1104, 'width': 1008, 'height': 756}
# 1112 {'license': 1, 'file_name': '1112.png', 'id': 1112, 'width': 1008, 'height': 756}
# 113 {'license': 1, 'file_name': '113.png', 'id': 113, 'width': 1008, 'height': 756}
# 1147 {'license': 1, 'file_name': '1147.png', 'id': 1147, 'width': 1008, 'height': 756}
# 117 {'license': 1, 'file_name': '117.png', 'id': 117, 'width': 1008, 'height': 756}
# 1215 {'license': 1, 'file_name': '1215.png', 'id': 1215, 'width': 1008, 'height': 756}
# 1272 {'license': 1, 'file_name': '1272.png', 'id': 1272, 'width': 1008, 'height': 756}
# 1274 {'license': 1, 'file_name': '1274.png', 'id': 1274, 'width': 1008, 'height': 756}
# 1286 {'license': 1, 'file_name': '1286.png', 'id': 1286, 'width': 1008, 'height': 756}
# 1360 {'license': 1, 'file_name': '1360.png', 'id': 1360, 'width': 1008, 'height': 756}
# 1367 {'license': 1, 'file_name': '1367.png', 'id': 1367, 'width': 1008, 'height': 756}
# 138 {'license': 1, 'file_name': '138.png', 'id': 138, 'width': 1008, 'height': 756}
# 1426 {'license': 1, 'file_name': '1426.png', 'id': 1426, 'width': 1008, 'height': 756}
# 1478 {'license': 1, 'file_name': '1478.png', 'id': 1478, 'width': 1008, 'height': 756}
# 1531 {'license': 1, 'file_name': '1531.png', 'id': 1531, 'width': 1008, 'height': 756}
# 1561 {'license': 1, 'file_name': '1561.png', 'id': 1561, 'width': 1008, 'height': 756}
# 1603 {'license': 1, 'file_name': '1603.png', 'id': 1603, 'width': 1008, 'height': 756}
# 1667 {'license': 1, 'file_name': '1667.png', 'id': 1667, 'width': 1008, 'height': 756}
# 1673 {'license': 1, 'file_name': '1673.png', 'id': 1673, 'width': 1008, 'height': 756}
# 1685 {'license': 1, 'file_name': '1685.png', 'id': 1685, 'width': 1008, 'height': 756}
# 1686 {'license': 1, 'file_name': '1686.png', 'id': 1686, 'width': 1008, 'height': 756}
# 1716 {'license': 1, 'file_name': '1716.png', 'id': 1716, 'width': 1008, 'height': 756}
# 1717 {'license': 1, 'file_name': '1717.png', 'id': 1717, 'width': 1008, 'height': 756}
# 1733 {'license': 1, 'file_name': '1733.png', 'id': 1733, 'width': 1008, 'height': 756}
# 1740 {'license': 1, 'file_name': '1740.png', 'id': 1740, 'width': 1008, 'height': 756}
# 1753 {'license': 1, 'file_name': '1753.png', 'id': 1753, 'width': 1008, 'height': 756}
# 1783 {'license': 1, 'file_name': '1783.png', 'id': 1783, 'width': 1008, 'height': 756}
# 1792 {'license': 1, 'file_name': '1792.png', 'id': 1792, 'width': 1008, 'height': 756}
# 1803 {'license': 1, 'file_name': '1803.png', 'id': 1803, 'width': 1008, 'height': 756}
# 1813 {'license': 1, 'file_name': '1813.png', 'id': 1813, 'width': 1008, 'height': 756}
# 1852 {'license': 1, 'file_name': '1852.png', 'id': 1852, 'width': 1008, 'height': 756}
# 192 {'license': 1, 'file_name': '192.png', 'id': 192, 'width': 1008, 'height': 756}
# 1943 {'license': 1, 'file_name': '1943.png', 'id': 1943, 'width': 1008, 'height': 756}
# 1979 {'license': 1, 'file_name': '1979.png', 'id': 1979, 'width': 1008, 'height': 756}
# 2094 {'license': 1, 'file_name': '2094.png', 'id': 2094, 'width': 1008, 'height': 756}
# 2105 {'license': 1, 'file_name': '2105.png', 'id': 2105, 'width': 1008, 'height': 756}
# 2121 {'license': 1, 'file_name': '2121.png', 'id': 2121, 'width': 1008, 'height': 756}
# 2169 {'license': 1, 'file_name': '2169.png', 'id': 2169, 'width': 1008, 'height': 756}
# 2230 {'license': 1, 'file_name': '2230.png', 'id': 2230, 'width': 1008, 'height': 756}
# 2236 {'license': 1, 'file_name': '2236.png', 'id': 2236, 'width': 1008, 'height': 756}
# 2247 {'license': 1, 'file_name': '2247.png', 'id': 2247, 'width': 1008, 'height': 756}
# 2295 {'license': 1, 'file_name': '2295.png', 'id': 2295, 'width': 1008, 'height': 756}
# 231 {'license': 1, 'file_name': '231.png', 'id': 231, 'width': 1008, 'height': 756}
# 2325 {'license': 1, 'file_name': '2325.png', 'id': 2325, 'width': 1008, 'height': 756}
# 2351 {'license': 1, 'file_name': '2351.png', 'id': 2351, 'width': 1008, 'height': 756}
# 2360 {'license': 1, 'file_name': '2360.png', 'id': 2360, 'width': 1008, 'height': 756}
# 2437 {'license': 1, 'file_name': '2437.png', 'id': 2437, 'width': 1008, 'height': 756}
# 2476 {'license': 1, 'file_name': '2476.png', 'id': 2476, 'width': 1008, 'height': 756}
# 2497 {'license': 1, 'file_name': '2497.png', 'id': 2497, 'width': 1008, 'height': 756}
# 2506 {'license': 1, 'file_name': '2506.png', 'id': 2506, 'width': 1008, 'height': 756}
# 2529 {'license': 1, 'file_name': '2529.png', 'id': 2529, 'width': 1008, 'height': 756}
# 2561 {'license': 1, 'file_name': '2561.png', 'id': 2561, 'width': 1008, 'height': 756}
# 2577 {'license': 1, 'file_name': '2577.png', 'id': 2577, 'width': 1008, 'height': 756}
# 2645 {'license': 1, 'file_name': '2645.png', 'id': 2645, 'width': 1008, 'height': 756}
# 2647 {'license': 1, 'file_name': '2647.png', 'id': 2647, 'width': 1008, 'height': 756}
# 2663 {'license': 1, 'file_name': '2663.png', 'id': 2663, 'width': 1008, 'height': 756}
# 2746 {'license': 1, 'file_name': '2746.png', 'id': 2746, 'width': 1008, 'height': 756}
# 2780 {'license': 1, 'file_name': '2780.png', 'id': 2780, 'width': 1008, 'height': 756}
# 2864 {'license': 1, 'file_name': '2864.png', 'id': 2864, 'width': 1008, 'height': 756}
# 2867 {'license': 1, 'file_name': '2867.png', 'id': 2867, 'width': 1008, 'height': 756}
# 2970 {'license': 1, 'file_name': '2970.png', 'id': 2970, 'width': 1008, 'height': 756}
# 2989 {'license': 1, 'file_name': '2989.png', 'id': 2989, 'width': 1008, 'height': 756}
# 2997 {'license': 1, 'file_name': '2997.png', 'id': 2997, 'width': 1008, 'height': 756}
# 3026 {'license': 1, 'file_name': '3026.png', 'id': 3026, 'width': 1008, 'height': 756}
# 3063 {'license': 1, 'file_name': '3063.png', 'id': 3063, 'width': 1008, 'height': 756}
# 3064 {'license': 1, 'file_name': '3064.png', 'id': 3064, 'width': 1008, 'height': 756}
# 3067 {'license': 1, 'file_name': '3067.png', 'id': 3067, 'width': 1008, 'height': 756}
# 332 {'license': 1, 'file_name': '332.png', 'id': 332, 'width': 1008, 'height': 756}
# 363 {'license': 1, 'file_name': '363.png', 'id': 363, 'width': 1008, 'height': 756}
# 380 {'license': 1, 'file_name': '380.png', 'id': 380, 'width': 1008, 'height': 756}
# 404 {'license': 1, 'file_name': '404.png', 'id': 404, 'width': 1008, 'height': 756}
# 431 {'license': 1, 'file_name': '431.png', 'id': 431, 'width': 1008, 'height': 756}
# 451 {'license': 1, 'file_name': '451.png', 'id': 451, 'width': 1008, 'height': 756}
# 471 {'license': 1, 'file_name': '471.png', 'id': 471, 'width': 1008, 'height': 756}
# 49 {'license': 1, 'file_name': '49.png', 'id': 49, 'width': 1008, 'height': 756}
# 501 {'license': 1, 'file_name': '501.png', 'id': 501, 'width': 1008, 'height': 756}
# 526 {'license': 1, 'file_name': '526.png', 'id': 526, 'width': 1008, 'height': 756}
# 533 {'license': 1, 'file_name': '533.png', 'id': 533, 'width': 1008, 'height': 756}
# 544 {'license': 1, 'file_name': '544.png', 'id': 544, 'width': 1008, 'height': 756}
# 567 {'license': 1, 'file_name': '567.png', 'id': 567, 'width': 1008, 'height': 756}
# 587 {'license': 1, 'file_name': '587.png', 'id': 587, 'width': 1008, 'height': 756}
# 66 {'license': 1, 'file_name': '66.png', 'id': 66, 'width': 1008, 'height': 756}
# 678 {'license': 1, 'file_name': '678.png', 'id': 678, 'width': 1008, 'height': 756}
# 7 {'license': 1, 'file_name': '7.png', 'id': 7, 'width': 1008, 'height': 756}
# 710 {'license': 1, 'file_name': '710.png', 'id': 710, 'width': 1008, 'height': 756}
# 745 {'license': 1, 'file_name': '745.png', 'id': 745, 'width': 1008, 'height': 756}
# 759 {'license': 1, 'file_name': '759.png', 'id': 759, 'width': 1008, 'height': 756}
# 821 {'license': 1, 'file_name': '821.png', 'id': 821, 'width': 1008, 'height': 756}
# 824 {'license': 1, 'file_name': '824.png', 'id': 824, 'width': 1008, 'height': 756}
# 856 {'license': 1, 'file_name': '856.png', 'id': 856, 'width': 1008, 'height': 756}
# 878 {'license': 1, 'file_name': '878.png', 'id': 878, 'width': 1008, 'height': 756}
# 891 {'license': 1, 'file_name': '891.png', 'id': 891, 'width': 1008, 'height': 756}
# 896 {'license': 1, 'file_name': '896.png', 'id': 896, 'width': 1008, 'height': 756}
# 916 {'license': 1, 'file_name': '916.png', 'id': 916, 'width': 1008, 'height': 756}
# 949 {'license': 1, 'file_name': '949.png', 'id': 949, 'width': 1008, 'height': 756}
# 967 {'license': 1, 'file_name': '967.png', 'id': 967, 'width': 1008, 'height': 756}

# %%
html = coco_dataset.display_image(967, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   license: 1
#   file_name: 967.png
#   id: 967
#   width: 1008
#   height: 756
#   segmentations (3):
#     569:blue:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     570:purple:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     571:red:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
# <div class="container" style="position:relative;"><img src="/content/dataset/val/label/967.png" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="450.0"><polygon points="134 271 132 271 126 268 119 262 117 257 115 251 115 240 113 235 116 226
#  119 217 131 204 138 200 145 199 155 199 163 197 175 203 187 216 189 220
#  190 225 190 230 187 239 185 244 180 251 173 257 155 265 148 267 139 268
#  134 271" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="258 381 253 380 242 380 228 363 216 339 214 331 206 314 200 293 199 277
#  199 271 203 264 206 254 214 247 222 240 230 236 233 236 248 235 258 233
#  267 233 275 234 283 240 296 255 298 260 300 269 300 286 298 301 296 309
#  291 318 291 324 285 332 275 361 269 370 258 381" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="312 259 304 259 297 256 291 250 286 242 280 238 273 230 264 224 252 213
#  249 204 244 194 244 187 241 184 241 166 247 151 253 142 260 137 264 131
#  269 131 273 127 279 127 288 118 291 114 300 109 305 113 309 118 317 122
#  323 120 329 127 338 131 346 136 350 134 355 144 359 157 358 179 356 194
#  352 207 346 231 336 249 329 253 320 258 312 259" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><text x="113" y="197" fill="yellow">strawberry</text><polygon points="113 197 190 197 190 271 113 271 113 197" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="199" y="233" fill="yellow">strawberry</text><polygon points="199 233 300 233 300 381 199 381 199 233" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="241" y="109" fill="yellow">strawberry</text><polygon points="241 109 359 109 359 259 241 259 241 109" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>

# %% [markdown]
# ### See labels from test dataset

# %%
annotation_path = "/content/test.json"
image_dir = "/content/dataset/test/label"

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
#   year: 2022
#   version: 2022
#   description: Strawberry
#   contributor: Crespo
#   url:
#   date_created: 2022.01.29
#
# Licenses:
# =========
# Categories:
# =========
#   super_category: fruit
#     id 0: strawberry

# %%
for k, v in coco_dataset.images.items():
    print(k, v)
# Out:
# 1017 {'license': 1, 'file_name': '1017.png', 'id': 1017, 'width': 1008, 'height': 756}
# 1026 {'license': 1, 'file_name': '1026.png', 'id': 1026, 'width': 1008, 'height': 756}
# 1028 {'license': 1, 'file_name': '1028.png', 'id': 1028, 'width': 1008, 'height': 756}
# 1033 {'license': 1, 'file_name': '1033.png', 'id': 1033, 'width': 1008, 'height': 756}
# 1080 {'license': 1, 'file_name': '1080.png', 'id': 1080, 'width': 1008, 'height': 756}
# 1087 {'license': 1, 'file_name': '1087.png', 'id': 1087, 'width': 1008, 'height': 756}
# 1108 {'license': 1, 'file_name': '1108.png', 'id': 1108, 'width': 1008, 'height': 756}
# 1135 {'license': 1, 'file_name': '1135.png', 'id': 1135, 'width': 1008, 'height': 756}
# 1151 {'license': 1, 'file_name': '1151.png', 'id': 1151, 'width': 1008, 'height': 756}
# 1155 {'license': 1, 'file_name': '1155.png', 'id': 1155, 'width': 1008, 'height': 756}
# 1156 {'license': 1, 'file_name': '1156.png', 'id': 1156, 'width': 1008, 'height': 756}
# 1218 {'license': 1, 'file_name': '1218.png', 'id': 1218, 'width': 1008, 'height': 756}
# 1233 {'license': 1, 'file_name': '1233.png', 'id': 1233, 'width': 1008, 'height': 756}
# 1251 {'license': 1, 'file_name': '1251.png', 'id': 1251, 'width': 1008, 'height': 756}
# 1263 {'license': 1, 'file_name': '1263.png', 'id': 1263, 'width': 1008, 'height': 756}
# 127 {'license': 1, 'file_name': '127.png', 'id': 127, 'width': 1008, 'height': 756}
# 1271 {'license': 1, 'file_name': '1271.png', 'id': 1271, 'width': 1008, 'height': 756}
# 1291 {'license': 1, 'file_name': '1291.png', 'id': 1291, 'width': 1008, 'height': 756}
# 1299 {'license': 1, 'file_name': '1299.png', 'id': 1299, 'width': 1008, 'height': 756}
# 1307 {'license': 1, 'file_name': '1307.png', 'id': 1307, 'width': 1008, 'height': 756}
# 1323 {'license': 1, 'file_name': '1323.png', 'id': 1323, 'width': 1008, 'height': 756}
# 1355 {'license': 1, 'file_name': '1355.png', 'id': 1355, 'width': 1008, 'height': 756}
# 1366 {'license': 1, 'file_name': '1366.png', 'id': 1366, 'width': 1008, 'height': 756}
# 1395 {'license': 1, 'file_name': '1395.png', 'id': 1395, 'width': 1008, 'height': 756}
# 1401 {'license': 1, 'file_name': '1401.png', 'id': 1401, 'width': 1008, 'height': 756}
# 1405 {'license': 1, 'file_name': '1405.png', 'id': 1405, 'width': 1008, 'height': 756}
# 1412 {'license': 1, 'file_name': '1412.png', 'id': 1412, 'width': 1008, 'height': 756}
# 1467 {'license': 1, 'file_name': '1467.png', 'id': 1467, 'width': 1008, 'height': 756}
# 149 {'license': 1, 'file_name': '149.png', 'id': 149, 'width': 1008, 'height': 756}
# 15 {'license': 1, 'file_name': '15.png', 'id': 15, 'width': 1008, 'height': 756}
# 1539 {'license': 1, 'file_name': '1539.png', 'id': 1539, 'width': 1008, 'height': 756}
# 1547 {'license': 1, 'file_name': '1547.png', 'id': 1547, 'width': 1008, 'height': 756}
# 1570 {'license': 1, 'file_name': '1570.png', 'id': 1570, 'width': 1008, 'height': 756}
# 1578 {'license': 1, 'file_name': '1578.png', 'id': 1578, 'width': 1008, 'height': 756}
# 1580 {'license': 1, 'file_name': '1580.png', 'id': 1580, 'width': 1008, 'height': 756}
# 1587 {'license': 1, 'file_name': '1587.png', 'id': 1587, 'width': 1008, 'height': 756}
# 1609 {'license': 1, 'file_name': '1609.png', 'id': 1609, 'width': 1008, 'height': 756}
# 1612 {'license': 1, 'file_name': '1612.png', 'id': 1612, 'width': 1008, 'height': 756}
# 1621 {'license': 1, 'file_name': '1621.png', 'id': 1621, 'width': 1008, 'height': 756}
# 1628 {'license': 1, 'file_name': '1628.png', 'id': 1628, 'width': 1008, 'height': 756}
# 1633 {'license': 1, 'file_name': '1633.png', 'id': 1633, 'width': 1008, 'height': 756}
# 165 {'license': 1, 'file_name': '165.png', 'id': 165, 'width': 1008, 'height': 756}
# 1669 {'license': 1, 'file_name': '1669.png', 'id': 1669, 'width': 1008, 'height': 756}
# 1670 {'license': 1, 'file_name': '1670.png', 'id': 1670, 'width': 1008, 'height': 756}
# 168 {'license': 1, 'file_name': '168.png', 'id': 168, 'width': 1008, 'height': 756}
# 1681 {'license': 1, 'file_name': '1681.png', 'id': 1681, 'width': 1008, 'height': 756}
# 1694 {'license': 1, 'file_name': '1694.png', 'id': 1694, 'width': 1008, 'height': 756}
# 1695 {'license': 1, 'file_name': '1695.png', 'id': 1695, 'width': 1008, 'height': 756}
# 1704 {'license': 1, 'file_name': '1704.png', 'id': 1704, 'width': 1008, 'height': 756}
# 1715 {'license': 1, 'file_name': '1715.png', 'id': 1715, 'width': 1008, 'height': 756}
# 1773 {'license': 1, 'file_name': '1773.png', 'id': 1773, 'width': 1008, 'height': 756}
# 1778 {'license': 1, 'file_name': '1778.png', 'id': 1778, 'width': 1008, 'height': 756}
# 1784 {'license': 1, 'file_name': '1784.png', 'id': 1784, 'width': 1008, 'height': 756}
# 1838 {'license': 1, 'file_name': '1838.png', 'id': 1838, 'width': 1008, 'height': 756}
# 1863 {'license': 1, 'file_name': '1863.png', 'id': 1863, 'width': 1008, 'height': 756}
# 1873 {'license': 1, 'file_name': '1873.png', 'id': 1873, 'width': 1008, 'height': 756}
# 1884 {'license': 1, 'file_name': '1884.png', 'id': 1884, 'width': 1008, 'height': 756}
# 1899 {'license': 1, 'file_name': '1899.png', 'id': 1899, 'width': 1008, 'height': 756}
# 1907 {'license': 1, 'file_name': '1907.png', 'id': 1907, 'width': 1008, 'height': 756}
# 1922 {'license': 1, 'file_name': '1922.png', 'id': 1922, 'width': 1008, 'height': 756}
# 1928 {'license': 1, 'file_name': '1928.png', 'id': 1928, 'width': 1008, 'height': 756}
# 1941 {'license': 1, 'file_name': '1941.png', 'id': 1941, 'width': 1008, 'height': 756}
# 1946 {'license': 1, 'file_name': '1946.png', 'id': 1946, 'width': 1008, 'height': 756}
# 1948 {'license': 1, 'file_name': '1948.png', 'id': 1948, 'width': 1008, 'height': 756}
# 1957 {'license': 1, 'file_name': '1957.png', 'id': 1957, 'width': 1008, 'height': 756}
# 1992 {'license': 1, 'file_name': '1992.png', 'id': 1992, 'width': 1008, 'height': 756}
# 1996 {'license': 1, 'file_name': '1996.png', 'id': 1996, 'width': 1008, 'height': 756}
# 2013 {'license': 1, 'file_name': '2013.png', 'id': 2013, 'width': 1008, 'height': 756}
# 2024 {'license': 1, 'file_name': '2024.png', 'id': 2024, 'width': 1008, 'height': 756}
# 2059 {'license': 1, 'file_name': '2059.png', 'id': 2059, 'width': 1008, 'height': 756}
# 2067 {'license': 1, 'file_name': '2067.png', 'id': 2067, 'width': 1008, 'height': 756}
# 2085 {'license': 1, 'file_name': '2085.png', 'id': 2085, 'width': 1008, 'height': 756}
# 2093 {'license': 1, 'file_name': '2093.png', 'id': 2093, 'width': 1008, 'height': 756}
# 2108 {'license': 1, 'file_name': '2108.png', 'id': 2108, 'width': 1008, 'height': 756}
# 2114 {'license': 1, 'file_name': '2114.png', 'id': 2114, 'width': 1008, 'height': 756}
# 2116 {'license': 1, 'file_name': '2116.png', 'id': 2116, 'width': 1008, 'height': 756}
# 2142 {'license': 1, 'file_name': '2142.png', 'id': 2142, 'width': 1008, 'height': 756}
# 2155 {'license': 1, 'file_name': '2155.png', 'id': 2155, 'width': 1008, 'height': 756}
# 2210 {'license': 1, 'file_name': '2210.png', 'id': 2210, 'width': 1008, 'height': 756}
# 223 {'license': 1, 'file_name': '223.png', 'id': 223, 'width': 1008, 'height': 756}
# 2234 {'license': 1, 'file_name': '2234.png', 'id': 2234, 'width': 1008, 'height': 756}
# 2249 {'license': 1, 'file_name': '2249.png', 'id': 2249, 'width': 1008, 'height': 756}
# 2290 {'license': 1, 'file_name': '2290.png', 'id': 2290, 'width': 1008, 'height': 756}
# 2293 {'license': 1, 'file_name': '2293.png', 'id': 2293, 'width': 1008, 'height': 756}
# 2301 {'license': 1, 'file_name': '2301.png', 'id': 2301, 'width': 1008, 'height': 756}
# 2302 {'license': 1, 'file_name': '2302.png', 'id': 2302, 'width': 1008, 'height': 756}
# 2304 {'license': 1, 'file_name': '2304.png', 'id': 2304, 'width': 1008, 'height': 756}
# 2315 {'license': 1, 'file_name': '2315.png', 'id': 2315, 'width': 1008, 'height': 756}
# 2362 {'license': 1, 'file_name': '2362.png', 'id': 2362, 'width': 1008, 'height': 756}
# 2364 {'license': 1, 'file_name': '2364.png', 'id': 2364, 'width': 1008, 'height': 756}
# 2377 {'license': 1, 'file_name': '2377.png', 'id': 2377, 'width': 1008, 'height': 756}
# 238 {'license': 1, 'file_name': '238.png', 'id': 238, 'width': 1008, 'height': 756}
# 2384 {'license': 1, 'file_name': '2384.png', 'id': 2384, 'width': 1008, 'height': 756}
# 2402 {'license': 1, 'file_name': '2402.png', 'id': 2402, 'width': 1008, 'height': 756}
# 2410 {'license': 1, 'file_name': '2410.png', 'id': 2410, 'width': 1008, 'height': 756}
# 2422 {'license': 1, 'file_name': '2422.png', 'id': 2422, 'width': 1008, 'height': 756}
# 2443 {'license': 1, 'file_name': '2443.png', 'id': 2443, 'width': 1008, 'height': 756}
# 2449 {'license': 1, 'file_name': '2449.png', 'id': 2449, 'width': 1008, 'height': 756}
# 2452 {'license': 1, 'file_name': '2452.png', 'id': 2452, 'width': 1008, 'height': 756}
# 2461 {'license': 1, 'file_name': '2461.png', 'id': 2461, 'width': 1008, 'height': 756}
# 2478 {'license': 1, 'file_name': '2478.png', 'id': 2478, 'width': 1008, 'height': 756}
# 2483 {'license': 1, 'file_name': '2483.png', 'id': 2483, 'width': 1008, 'height': 756}
# 2509 {'license': 1, 'file_name': '2509.png', 'id': 2509, 'width': 1008, 'height': 756}
# 2532 {'license': 1, 'file_name': '2532.png', 'id': 2532, 'width': 1008, 'height': 756}
# 255 {'license': 1, 'file_name': '255.png', 'id': 255, 'width': 1008, 'height': 756}
# 2550 {'license': 1, 'file_name': '2550.png', 'id': 2550, 'width': 1008, 'height': 756}
# 2582 {'license': 1, 'file_name': '2582.png', 'id': 2582, 'width': 1008, 'height': 756}
# 2603 {'license': 1, 'file_name': '2603.png', 'id': 2603, 'width': 1008, 'height': 756}
# 2611 {'license': 1, 'file_name': '2611.png', 'id': 2611, 'width': 1008, 'height': 756}
# 2649 {'license': 1, 'file_name': '2649.png', 'id': 2649, 'width': 1008, 'height': 756}
# 2651 {'license': 1, 'file_name': '2651.png', 'id': 2651, 'width': 1008, 'height': 756}
# 2652 {'license': 1, 'file_name': '2652.png', 'id': 2652, 'width': 1008, 'height': 756}
# 2656 {'license': 1, 'file_name': '2656.png', 'id': 2656, 'width': 1008, 'height': 756}
# 2661 {'license': 1, 'file_name': '2661.png', 'id': 2661, 'width': 1008, 'height': 756}
# 2662 {'license': 1, 'file_name': '2662.png', 'id': 2662, 'width': 1008, 'height': 756}
# 2690 {'license': 1, 'file_name': '2690.png', 'id': 2690, 'width': 1008, 'height': 756}
# 2701 {'license': 1, 'file_name': '2701.png', 'id': 2701, 'width': 1008, 'height': 756}
# 2718 {'license': 1, 'file_name': '2718.png', 'id': 2718, 'width': 1008, 'height': 756}
# 2731 {'license': 1, 'file_name': '2731.png', 'id': 2731, 'width': 1008, 'height': 756}
# 2734 {'license': 1, 'file_name': '2734.png', 'id': 2734, 'width': 1008, 'height': 756}
# 277 {'license': 1, 'file_name': '277.png', 'id': 277, 'width': 1008, 'height': 756}
# 2776 {'license': 1, 'file_name': '2776.png', 'id': 2776, 'width': 1008, 'height': 756}
# 2796 {'license': 1, 'file_name': '2796.png', 'id': 2796, 'width': 1008, 'height': 756}
# 2807 {'license': 1, 'file_name': '2807.png', 'id': 2807, 'width': 1008, 'height': 756}
# 2814 {'license': 1, 'file_name': '2814.png', 'id': 2814, 'width': 1008, 'height': 756}
# 2823 {'license': 1, 'file_name': '2823.png', 'id': 2823, 'width': 1008, 'height': 756}
# 2904 {'license': 1, 'file_name': '2904.png', 'id': 2904, 'width': 1008, 'height': 756}
# 2913 {'license': 1, 'file_name': '2913.png', 'id': 2913, 'width': 1008, 'height': 756}
# 2916 {'license': 1, 'file_name': '2916.png', 'id': 2916, 'width': 1008, 'height': 756}
# 2923 {'license': 1, 'file_name': '2923.png', 'id': 2923, 'width': 1008, 'height': 756}
# 2933 {'license': 1, 'file_name': '2933.png', 'id': 2933, 'width': 1008, 'height': 756}
# 2941 {'license': 1, 'file_name': '2941.png', 'id': 2941, 'width': 1008, 'height': 756}
# 2950 {'license': 1, 'file_name': '2950.png', 'id': 2950, 'width': 1008, 'height': 756}
# 2957 {'license': 1, 'file_name': '2957.png', 'id': 2957, 'width': 1008, 'height': 756}
# 2965 {'license': 1, 'file_name': '2965.png', 'id': 2965, 'width': 1008, 'height': 756}
# 2972 {'license': 1, 'file_name': '2972.png', 'id': 2972, 'width': 1008, 'height': 756}
# 2976 {'license': 1, 'file_name': '2976.png', 'id': 2976, 'width': 1008, 'height': 756}
# 2980 {'license': 1, 'file_name': '2980.png', 'id': 2980, 'width': 1008, 'height': 756}
# 299 {'license': 1, 'file_name': '299.png', 'id': 299, 'width': 1008, 'height': 756}
# 3035 {'license': 1, 'file_name': '3035.png', 'id': 3035, 'width': 1008, 'height': 756}
# 3048 {'license': 1, 'file_name': '3048.png', 'id': 3048, 'width': 1008, 'height': 756}
# 305 {'license': 1, 'file_name': '305.png', 'id': 305, 'width': 1008, 'height': 756}
# 3056 {'license': 1, 'file_name': '3056.png', 'id': 3056, 'width': 1008, 'height': 756}
# 3057 {'license': 1, 'file_name': '3057.png', 'id': 3057, 'width': 1008, 'height': 756}
# 3058 {'license': 1, 'file_name': '3058.png', 'id': 3058, 'width': 1008, 'height': 756}
# 3079 {'license': 1, 'file_name': '3079.png', 'id': 3079, 'width': 1008, 'height': 756}
# 3099 {'license': 1, 'file_name': '3099.png', 'id': 3099, 'width': 1008, 'height': 756}
# 34 {'license': 1, 'file_name': '34.png', 'id': 34, 'width': 1008, 'height': 756}
# 343 {'license': 1, 'file_name': '343.png', 'id': 343, 'width': 1008, 'height': 756}
# 36 {'license': 1, 'file_name': '36.png', 'id': 36, 'width': 1008, 'height': 756}
# 373 {'license': 1, 'file_name': '373.png', 'id': 373, 'width': 1008, 'height': 756}
# 389 {'license': 1, 'file_name': '389.png', 'id': 389, 'width': 1008, 'height': 756}
# 406 {'license': 1, 'file_name': '406.png', 'id': 406, 'width': 1008, 'height': 756}
# 44 {'license': 1, 'file_name': '44.png', 'id': 44, 'width': 1008, 'height': 756}
# 443 {'license': 1, 'file_name': '443.png', 'id': 443, 'width': 1008, 'height': 756}
# 47 {'license': 1, 'file_name': '47.png', 'id': 47, 'width': 1008, 'height': 756}
# 470 {'license': 1, 'file_name': '470.png', 'id': 470, 'width': 1008, 'height': 756}
# 473 {'license': 1, 'file_name': '473.png', 'id': 473, 'width': 1008, 'height': 756}
# 502 {'license': 1, 'file_name': '502.png', 'id': 502, 'width': 1008, 'height': 756}
# 514 {'license': 1, 'file_name': '514.png', 'id': 514, 'width': 1008, 'height': 756}
# 523 {'license': 1, 'file_name': '523.png', 'id': 523, 'width': 1008, 'height': 756}
# 527 {'license': 1, 'file_name': '527.png', 'id': 527, 'width': 1008, 'height': 756}
# 53 {'license': 1, 'file_name': '53.png', 'id': 53, 'width': 1008, 'height': 756}
# 546 {'license': 1, 'file_name': '546.png', 'id': 546, 'width': 1008, 'height': 756}
# 549 {'license': 1, 'file_name': '549.png', 'id': 549, 'width': 1008, 'height': 756}
# 556 {'license': 1, 'file_name': '556.png', 'id': 556, 'width': 1008, 'height': 756}
# 569 {'license': 1, 'file_name': '569.png', 'id': 569, 'width': 1008, 'height': 756}
# 576 {'license': 1, 'file_name': '576.png', 'id': 576, 'width': 1008, 'height': 756}
# 588 {'license': 1, 'file_name': '588.png', 'id': 588, 'width': 1008, 'height': 756}
# 609 {'license': 1, 'file_name': '609.png', 'id': 609, 'width': 1008, 'height': 756}
# 618 {'license': 1, 'file_name': '618.png', 'id': 618, 'width': 1008, 'height': 756}
# 637 {'license': 1, 'file_name': '637.png', 'id': 637, 'width': 1008, 'height': 756}
# 640 {'license': 1, 'file_name': '640.png', 'id': 640, 'width': 1008, 'height': 756}
# 670 {'license': 1, 'file_name': '670.png', 'id': 670, 'width': 1008, 'height': 756}
# 690 {'license': 1, 'file_name': '690.png', 'id': 690, 'width': 1008, 'height': 756}
# 692 {'license': 1, 'file_name': '692.png', 'id': 692, 'width': 1008, 'height': 756}
# 699 {'license': 1, 'file_name': '699.png', 'id': 699, 'width': 1008, 'height': 756}
# 70 {'license': 1, 'file_name': '70.png', 'id': 70, 'width': 1008, 'height': 756}
# 709 {'license': 1, 'file_name': '709.png', 'id': 709, 'width': 1008, 'height': 756}
# 721 {'license': 1, 'file_name': '721.png', 'id': 721, 'width': 1008, 'height': 756}
# 754 {'license': 1, 'file_name': '754.png', 'id': 754, 'width': 1008, 'height': 756}
# 765 {'license': 1, 'file_name': '765.png', 'id': 765, 'width': 1008, 'height': 756}
# 787 {'license': 1, 'file_name': '787.png', 'id': 787, 'width': 1008, 'height': 756}
# 795 {'license': 1, 'file_name': '795.png', 'id': 795, 'width': 1008, 'height': 756}
# 8 {'license': 1, 'file_name': '8.png', 'id': 8, 'width': 1008, 'height': 756}
# 802 {'license': 1, 'file_name': '802.png', 'id': 802, 'width': 1008, 'height': 756}
# 809 {'license': 1, 'file_name': '809.png', 'id': 809, 'width': 1008, 'height': 756}
# 858 {'license': 1, 'file_name': '858.png', 'id': 858, 'width': 1008, 'height': 756}
# 869 {'license': 1, 'file_name': '869.png', 'id': 869, 'width': 1008, 'height': 756}
# 888 {'license': 1, 'file_name': '888.png', 'id': 888, 'width': 1008, 'height': 756}
# 905 {'license': 1, 'file_name': '905.png', 'id': 905, 'width': 1008, 'height': 756}
# 92 {'license': 1, 'file_name': '92.png', 'id': 92, 'width': 1008, 'height': 756}
# 920 {'license': 1, 'file_name': '920.png', 'id': 920, 'width': 1008, 'height': 756}
# 926 {'license': 1, 'file_name': '926.png', 'id': 926, 'width': 1008, 'height': 756}
# 938 {'license': 1, 'file_name': '938.png', 'id': 938, 'width': 1008, 'height': 756}
# 942 {'license': 1, 'file_name': '942.png', 'id': 942, 'width': 1008, 'height': 756}
# 950 {'license': 1, 'file_name': '950.png', 'id': 950, 'width': 1008, 'height': 756}
# 952 {'license': 1, 'file_name': '952.png', 'id': 952, 'width': 1008, 'height': 756}
# 980 {'license': 1, 'file_name': '980.png', 'id': 980, 'width': 1008, 'height': 756}
# 995 {'license': 1, 'file_name': '995.png', 'id': 995, 'width': 1008, 'height': 756}

# %%
html = coco_dataset.display_image(995, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   license: 1
#   file_name: 995.png
#   id: 995
#   width: 1008
#   height: 756
#   segmentations (8):
#     1124:blue:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     1125:purple:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     1126:red:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     1127:green:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     1128:orange:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     1129:salmon:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     1130:pink:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
#     1131:gold:{'id': 0, 'name': 'strawberry', 'supercategory': 'fruit'}
# <div class="container" style="position:relative;"><img src="/content/dataset/test/label/995.png" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="450.0"><polygon points="192 148 181 145 172 138 170 132 171 127 174 123 186 113 196 108 202 106
#  207 107 211 108 219 111 222 116 222 117 219 120 216 126 217 127 214 131
#  213 131 208 127 199 126 199 130 202 137 209 143 209 145 208 146 193 146
#  189 141 192 148" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="217 165 214 165 212 162 212 157 214 153 216 158 220 158 219 163 217 165" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="303 177 297 174 294 171 299 166 304 156 306 158 304 161 304 164 305 167
#  309 172 306 175 303 177" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="367 242 362 242 357 240 340 224 336 219 330 207 328 199 328 188 329 184
#  336 184 339 183 342 184 348 184 353 181 355 184 357 184 360 183 368 179
#  370 179 376 182 382 189 384 204 379 227 377 233 372 239 367 242" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="430  14 427  12 424  13 427   9 427   7 426   6 421   4 422   6 420   9
#  419   6 416   5 417   0 441   0 439   6 435  11 430  14" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points="499 149 491 149 485 147 481 143 480 138 484 127 489 122 493 121 501 121
#  507 123 512 130 512 136 510 142 506 146 499 149" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><polygon points="" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="486  33 486  33 488  29 486  24 489  25 492  27 490  30 486  33" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="599 186 592 184 588 181 584 173 584 168 586 167 586 165 590 158 592 155
#  597 152 598 152 599 157 599 186" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0.5" /><text x="170" y="106" fill="yellow">strawberry</text><polygon points="170 106 222 106 222 148 170 148 170 106" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="212" y="153" fill="yellow">strawberry</text><polygon points="212 153 220 153 220 165 212 165 212 153" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="294" y="156" fill="yellow">strawberry</text><polygon points="294 156 309 156 309 177 294 177 294 156" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="328" y="179" fill="yellow">strawberry</text><polygon points="328 179 384 179 384 242 328 242 328 179" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /><text x="416" y="0" fill="yellow">strawberry</text><polygon points="416   0 441   0 441  14 416  14 416   0" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0" /><text x="480" y="121" fill="yellow">strawberry</text><polygon points="480 121 512 121 512 149 480 149 480 121" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0" /><text x="486" y="24" fill="yellow">strawberry</text><polygon points="486  24 492  24 492  33 486  33 486  24" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0" /><text x="584" y="152" fill="yellow">strawberry</text><polygon points="584 152 599 152 599 186 584 186 584 152" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>
